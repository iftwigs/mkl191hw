# %% [markdown]
# ### Задание 1

# %%
import re
import regex
import requests 
from pymystem3 import Mystem
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk import sent_tokenize
from pymorphy2 import MorphAnalyzer
from bs4 import BeautifulSoup 
morph = MorphAnalyzer()
mystem = Mystem()

# %%
dir(regex)
# Out:
# ['A',
#  'ASCII',
#  'B',
#  'BESTMATCH',
#  'D',
#  'DEBUG',
#  'DEFAULT_VERSION',
#  'DOTALL',
#  'E',
#  'ENHANCEMATCH',
#  'F',
#  'FULLCASE',
#  'I',
#  'IGNORECASE',
#  'L',
#  'LOCALE',
#  'M',
#  'MULTILINE',
#  'P',
#  'POSIX',
#  'R',
#  'REVERSE',
#  'Regex',
#  'S',
#  'Scanner',
#  'T',
#  'TEMPLATE',
#  'U',
#  'UNICODE',
#  'V0',
#  'V1',
#  'VERBOSE',
#  'VERSION0',
#  'VERSION1',
#  'W',
#  'WORD',
#  'X',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_regex',
#  '_regex_core',
#  'compile',
#  'error',
#  'escape',
#  'findall',
#  'finditer',
#  'fullmatch',
#  'match',
#  'purge',
#  'regex',
#  'search',
#  'split',
#  'splititer',
#  'sub',
#  'subf',
#  'subfn',
#  'subn',
#  'template']

# %%
dir(re)
# Out:
# ['A',
#  'ASCII',
#  'DEBUG',
#  'DOTALL',
#  'I',
#  'IGNORECASE',
#  'L',
#  'LOCALE',
#  'M',
#  'MULTILINE',
#  'RegexFlag',
#  'S',
#  'Scanner',
#  'T',
#  'TEMPLATE',
#  'U',
#  'UNICODE',
#  'VERBOSE',
#  'X',
#  '_MAXCACHE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_alphanum_bytes',
#  '_alphanum_str',
#  '_cache',
#  '_compile',
#  '_compile_repl',
#  '_expand',
#  '_locale',
#  '_pattern_type',
#  '_pickle',
#  '_subx',
#  'compile',
#  'copyreg',
#  'enum',
#  'error',
#  'escape',
#  'findall',
#  'finditer',
#  'fullmatch',
#  'functools',
#  'match',
#  'purge',
#  'search',
#  'split',
#  'sre_compile',
#  'sre_parse',
#  'sub',
#  'subn',
#  'template']

# %% [markdown]
# Я просмотрела документацию по re и regex, а также попробовала их на практике, но не смогла найти какое-либо значимое преимущество у regex.

# %% [markdown]
# ### Задание 2

# %%
URL = "http://gramota.ru/class/coach/punct/45_177"
r = requests.get(URL) 
bs=BeautifulSoup(r.text, "html5lib") 
  
soup = BeautifulSoup(" ".join([p.text for p in bs.find_all("p")]), "html5lib").get_text().replace("\xa0", " ")
#print(soup)
soup2 = BeautifulSoup(" ".join([div.text for div in bs.find_all("li")]), "html5lib").get_text().replace("\xa0", " ")
#print(soup2)
soup3 = soup + soup2
print(soup3[:1000])
# Out:
# Наши награды Спор, дискуссия, диспут и полемика...
#
# Эти синонимичные понятия часто сбивают нас с толку. В чём же разница? И что такое жуска? Спор, дискуссия, диспут и полемика Проверка слова:   Выберите правильные варианты ответов. Для проверки выполненного задания нажмите кнопку «Проверить». Обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. Обстоятельства поясняют сказуемые или другие члены предложения. При синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). Обстоятельства необходимо выделять запятыми в трех случаях. Рассмотрим каждый из них по очереди.  Первый случай Обстоятельства в предложениях могут быть выражены четырьмя частями речи:  Кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: Дождь шел две недели подряд.  Необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборото

# %%
lowered = soup3.lower()
lowered[:1000]
# Out:
# 'наши награды спор, дискуссия, диспут и полемика...\n\nэти синонимичные понятия часто сбивают нас с толку. в чём же разница? и что такое жуска? спор, дискуссия, диспут и полемика проверка слова:   выберите правильные варианты ответов. для проверки выполненного задания нажмите кнопку «проверить». обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. обстоятельства поясняют сказуемые или другие члены предложения. при синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). обстоятельства необходимо выделять запятыми в трех случаях. рассмотрим каждый из них по очереди.  первый случай обстоятельства в предложениях могут быть выражены четырьмя частями речи:  кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: дождь шел две недели подряд.  необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборото'

# %%
def remove_ns(text):
    return re.sub(r'\n', '', text)
clean = remove_ns(lowered)
clean[:1000]
# Out:
# 'наши награды спор, дискуссия, диспут и полемика...эти синонимичные понятия часто сбивают нас с толку. в чём же разница? и что такое жуска? спор, дискуссия, диспут и полемика проверка слова:   выберите правильные варианты ответов. для проверки выполненного задания нажмите кнопку «проверить». обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. обстоятельства поясняют сказуемые или другие члены предложения. при синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). обстоятельства необходимо выделять запятыми в трех случаях. рассмотрим каждый из них по очереди.  первый случай обстоятельства в предложениях могут быть выражены четырьмя частями речи:  кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: дождь шел две недели подряд.  необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборотом.'

# %%
def delete_punc(text):
    return re.sub(r'[().\–_,\':«»;…?!]', ' ', text)
clean2 = delete_punc(clean)
clean2[:1000]
# Out:
# 'наши награды спор  дискуссия  диспут и полемика   эти синонимичные понятия часто сбивают нас с толку  в чём же разница  и что такое жуска  спор  дискуссия  диспут и полемика проверка слова    выберите правильные варианты ответов  для проверки выполненного задания нажмите кнопку  проверить   обстоятельство   второстепенный член предложения  который обозначает признак действия или другого признака  обстоятельства поясняют сказуемые или другие члены предложения  при синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией  тире  точка  тире   обстоятельства необходимо выделять запятыми в трех случаях  рассмотрим каждый из них по очереди   первый случай обстоятельства в предложениях могут быть выражены четырьмя частями речи   кроме этого  обстоятельство может быть выражено цельным по смыслу выражением  например  дождь шел две недели подряд   необходимо запомнить  что выделять запятыми нужно обстоятельства  которые выражены деепричастием или деепричастным оборотом '

# %%
tokens = re.split(' ', clean2)
tokens[:100]
# Out:
# ['наши',
#  'награды',
#  'спор',
#  '',
#  'дискуссия',
#  '',
#  'диспут',
#  'и',
#  'полемика',
#  '',
#  '',
#  'эти',
#  'синонимичные',
#  'понятия',
#  'часто',
#  'сбивают',
#  'нас',
#  'с',
#  'толку',
#  '',
#  'в',
#  'чём',
#  'же',
#  'разница',
#  '',
#  'и',
#  'что',
#  'такое',
#  'жуска',
#  '',
#  'спор',
#  '',
#  'дискуссия',
#  '',
#  'диспут',
#  'и',
#  'полемика',
#  'проверка',
#  'слова',
#  '',
#  '',
#  '',
#  'выберите',
#  'правильные',
#  'варианты',
#  'ответов',
#  '',
#  'для',
#  'проверки',
#  'выполненного',
#  'задания',
#  'нажмите',
#  'кнопку',
#  '',
#  'проверить',
#  '',
#  '',
#  'обстоятельство',
#  '',
#  '',
#  'второстепенный',
#  'член',
#  'предложения',
#  '',
#  'который',
#  'обозначает',
#  'признак',
#  'действия',
#  'или',
#  'другого',
#  'признака',
#  '',
#  'обстоятельства',
#  'поясняют',
#  'сказуемые',
#  'или',
#  'другие',
#  'члены',
#  'предложения',
#  '',
#  'при',
#  'синтаксическом',
#  'разборе',
#  'предложения',
#  'обстоятельства',
#  'подчеркиваются',
#  'пунктирной',
#  'линией',
#  '',
#  'тире',
#  '',
#  'точка',
#  '',
#  'тире',
#  '',
#  '',
#  'обстоятельства',
#  'необходимо',
#  'выделять',
#  'запятыми']

# %%
stemmer = SnowballStemmer('russian')

# %%
stemmed = []
for w in tokens:
    if w in tokens:
        stemmed.append((w, stemmer.stem(w)))

# %%
stemmed
# Out:
# [('наши', 'наш'),
#  ('награды', 'наград'),
#  ('спор', 'спор'),
#  ('', ''),
#  ('дискуссия', 'дискусс'),
#  ('', ''),
#  ('диспут', 'диспут'),
#  ('и', 'и'),
#  ('полемика', 'полемик'),
#  ('', ''),
#  ('', ''),
#  ('эти', 'эт'),
#  ('синонимичные', 'синонимичн'),
#  ('понятия', 'понят'),
#  ('часто', 'част'),
#  ('сбивают', 'сбива'),
#  ('нас', 'нас'),
#  ('с', 'с'),
#  ('толку', 'толк'),
#  ('', ''),
#  ('в', 'в'),
#  ('чём', 'чем'),
#  ('же', 'же'),
#  ('разница', 'разниц'),
#  ('', ''),
#  ('и', 'и'),
#  ('что', 'что'),
#  ('такое', 'так'),
#  ('жуска', 'жуск'),
#  ('', ''),
#  ('спор', 'спор'),
#  ('', ''),
#  ('дискуссия', 'дискусс'),
#  ('', ''),
#  ('диспут', 'диспут'),
#  ('и', 'и'),
#  ('полемика', 'полемик'),
#  ('проверка', 'проверк'),
#  ('слова', 'слов'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('выберите', 'выбер'),
#  ('правильные', 'правильн'),
#  ('варианты', 'вариант'),
#  ('ответов', 'ответ'),
#  ('', ''),
#  ('для', 'для'),
#  ('проверки', 'проверк'),
#  ('выполненного', 'выполнен'),
#  ('задания', 'задан'),
#  ('нажмите', 'нажм'),
#  ('кнопку', 'кнопк'),
#  ('', ''),
#  ('проверить', 'провер'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельство', 'обстоятельств'),
#  ('', ''),
#  ('', ''),
#  ('второстепенный', 'второстепен'),
#  ('член', 'член'),
#  ('предложения', 'предложен'),
#  ('', ''),
#  ('который', 'котор'),
#  ('обозначает', 'обознача'),
#  ('признак', 'признак'),
#  ('действия', 'действ'),
#  ('или', 'ил'),
#  ('другого', 'друг'),
#  ('признака', 'признак'),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('поясняют', 'поясня'),
#  ('сказуемые', 'сказуем'),
#  ('или', 'ил'),
#  ('другие', 'друг'),
#  ('члены', 'член'),
#  ('предложения', 'предложен'),
#  ('', ''),
#  ('при', 'при'),
#  ('синтаксическом', 'синтаксическ'),
#  ('разборе', 'разбор'),
#  ('предложения', 'предложен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('подчеркиваются', 'подчеркива'),
#  ('пунктирной', 'пунктирн'),
#  ('линией', 'лин'),
#  ('', ''),
#  ('тире', 'тир'),
#  ('', ''),
#  ('точка', 'точк'),
#  ('', ''),
#  ('тире', 'тир'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('в', 'в'),
#  ('трех', 'трех'),
#  ('случаях', 'случа'),
#  ('', ''),
#  ('рассмотрим', 'рассмотр'),
#  ('каждый', 'кажд'),
#  ('из', 'из'),
#  ('них', 'них'),
#  ('по', 'по'),
#  ('очереди', 'очеред'),
#  ('', ''),
#  ('', ''),
#  ('первый', 'перв'),
#  ('случай', 'случа'),
#  ('обстоятельства', 'обстоятельств'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('могут', 'могут'),
#  ('быть', 'быт'),
#  ('выражены', 'выраж'),
#  ('четырьмя', 'четырьм'),
#  ('частями', 'част'),
#  ('речи', 'реч'),
#  ('', ''),
#  ('', ''),
#  ('кроме', 'кром'),
#  ('этого', 'эт'),
#  ('', ''),
#  ('обстоятельство', 'обстоятельств'),
#  ('может', 'может'),
#  ('быть', 'быт'),
#  ('выражено', 'выраж'),
#  ('цельным', 'цельн'),
#  ('по', 'по'),
#  ('смыслу', 'смысл'),
#  ('выражением', 'выражен'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('дождь', 'дожд'),
#  ('шел', 'шел'),
#  ('две', 'две'),
#  ('недели', 'недел'),
#  ('подряд', 'подряд'),
#  ('', ''),
#  ('', ''),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('', ''),
#  ('что', 'что'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('нужно', 'нужн'),
#  ('обстоятельства', 'обстоятельств'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('выражены', 'выраж'),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('', ''),
#  ('сравните', 'сравн'),
#  ('', ''),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('', ''),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('', ''),
#  ('и', 'и'),
#  ('скучал', 'скуча'),
#  ('и', 'и'),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('', ''),
#  ('в', 'в'),
#  ('первом', 'перв'),
#  ('предложении', 'предложен'),
#  ('обстоятельство', 'обстоятельств'),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('выделяется', 'выделя'),
#  ('', ''),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('', ''),
#  ('а', 'а'),
#  ('во', 'во'),
#  ('втором', 'втор'),
#  ('обстоятельство', 'обстоятельств'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('не', 'не'),
#  ('обособляется', 'обособля'),
#  ('', ''),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('существительным', 'существительн'),
#  ('с', 'с'),
#  ('предлогом', 'предлог'),
#  ('', ''),
#  ('', ''),
#  ('второй', 'втор'),
#  ('и', 'и'),
#  ('третий', 'трет'),
#  ('случаи', 'случа'),
#  ('', ''),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('делятся', 'дел'),
#  ('на', 'на'),
#  ('следующие', 'след'),
#  ('основные', 'основн'),
#  ('группы', 'групп'),
#  ('', ''),
#  ('', ''),
#  ('в', 'в'),
#  ('классификации', 'классификац'),
#  ('обстоятельств', 'обстоятельств'),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('одним', 'одн'),
#  ('из', 'из'),
#  ('восьми', 'восьм'),
#  ('видов', 'вид'),
#  ('являются', 'явля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('', ''),
#  ('они', 'он'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('', ''),
#  ('и', 'и'),
#  ('начинается', 'начина'),
#  ('с', 'с'),
#  ('союзов', 'союз'),
#  ('как', 'как'),
#  ('', ''),
#  ('словно', 'словн'),
#  ('или', 'ил'),
#  ('будто', 'будт'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('были', 'был'),
#  ('длинные', 'длин'),
#  ('волосы', 'волос'),
#  ('', ''),
#  ('мягкие', 'мягк'),
#  ('', ''),
#  ('как', 'как'),
#  ('лен', 'лен'),
#  ('', ''),
#  ('в', 'в'),
#  ('некоторых', 'некотор'),
#  ('учебниках', 'учебник'),
#  ('и', 'и'),
#  ('справочных', 'справочн'),
#  ('пособиях', 'пособ'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('называют', 'называ'),
#  ('также', 'такж'),
#  ('сравнительными', 'сравнительн'),
#  ('оборотами', 'оборот'),
#  ('', ''),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('', ''),
#  ('что', 'что'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('выделяются', 'выделя'),
#  ('запятыми', 'запят'),
#  ('', ''),
#  ('', ''),
#  ('еще', 'ещ'),
#  ('один', 'один'),
#  ('вид', 'вид'),
#  ('обстоятельств', 'обстоятельств'),
#  ('', ''),
#  ('который', 'котор'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('', ''),
#  ('это', 'эт'),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('', ''),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('', ''),
#  ('и', 'и'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('', ''),
#  ('или', 'ил'),
#  ('', ''),
#  ('реже', 'реж'),
#  ('', ''),
#  ('вопреки', 'вопрек'),
#  ('', ''),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('на', 'на'),
#  ('улицах', 'улиц'),
#  ('', ''),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('яркое', 'ярк'),
#  ('солнце', 'солнц'),
#  ('', ''),
#  ('горели', 'горел'),
#  ('фонари', 'фонар'),
#  ('', ''),
#  ('', ''),
#  ('итак', 'итак'),
#  ('', ''),
#  ('следует', 'след'),
#  ('запомнить', 'запомн'),
#  ('три', 'три'),
#  ('случая', 'случ'),
#  ('', ''),
#  ('когда', 'когд'),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('', ''),
#  ('', ''),
#  ('еще', 'ещ'),
#  ('раз', 'раз'),
#  ('рассмотрите', 'рассмотр'),
#  ('примеры', 'пример'),
#  ('', ''),
#  ('сверкая', 'сверк'),
#  ('быстро', 'быстр'),
#  ('в', 'в'),
#  ('вышине', 'вышин'),
#  ('', ''),
#  ('кружились', 'круж'),
#  ('искры', 'искр'),
#  ('', ''),
#  ('', ''),
#  ('лермонтов', 'лермонт'),
#  ('', ''),
#  ('она', 'он'),
#  ('вдруг', 'вдруг'),
#  ('скрылась', 'скрыл'),
#  ('', ''),
#  ('как', 'как'),
#  ('птичка', 'птичк'),
#  ('', ''),
#  ('вспугнутая', 'вспугнут'),
#  ('из', 'из'),
#  ('кустарника', 'кустарник'),
#  ('', ''),
#  ('лермонтов', 'лермонт'),
#  ('', ''),
#  ('', ''),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('непредвиденные', 'непредвиден'),
#  ('трудности', 'трудност'),
#  ('', ''),
#  ('работа', 'работ'),
#  ('закончена', 'законч'),
#  ('в', 'в'),
#  ('срок', 'срок'),
#  ('', ''),
#  ('', ''),
#  ('это', 'эт'),
#  ('правило', 'прав'),
#  ('имеет', 'имеет'),
#  ('несколько', 'нескольк'),
#  ('важных', 'важн'),
#  ('примечаний', 'примечан'),
#  ('', ''),
#  ('', ''),
#  ('от', 'от'),
#  ('деепричастий', 'деепричаст'),
#  ('следует', 'след'),
#  ('отличать', 'отлича'),
#  ('наречия', 'нареч'),
#  ('стоя', 'сто'),
#  ('', ''),
#  ('сидя', 'сид'),
#  ('', ''),
#  ('лежа', 'леж'),
#  ('', ''),
#  ('молча', 'молч'),
#  ('', ''),
#  ('нехотя', 'нехот'),
#  ('', ''),
#  ('шутя', 'шут'),
#  ('', ''),
#  ('не', 'не'),
#  ('глядя', 'гляд'),
#  ('', ''),
#  ('играя', 'игр'),
#  ('', ''),
#  ('они', 'он'),
#  ('образовались', 'образова'),
#  ('благодаря', 'благодар'),
#  ('переходу', 'переход'),
#  ('слов', 'слов'),
#  ('из', 'из'),
#  ('разряда', 'разряд'),
#  ('деепричастий', 'деепричаст'),
#  ('в', 'в'),
#  ('наречия', 'нареч'),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('', ''),
#  ('выраженные', 'выражен'),
#  ('такими', 'так'),
#  ('словами', 'слов'),
#  ('', ''),
#  ('не', 'не'),
#  ('обособляются', 'обособля'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('он', 'он'),
#  ('стоял', 'стоя'),
#  ('молча', 'молч'),
#  ('', ''),
#  ('', ''),
#  ('не', 'не'),
#  ('выделяются', 'выделя'),
#  ('также', 'такж'),
#  ('обстоятельства', 'обстоятельств'),
#  ('', ''),
#  ('выраженные', 'выражен'),
#  ('фразеологическими', 'фразеологическ'),
#  ('оборотами', 'оборот'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('они', 'он'),
#  ('работали', 'работа'),
#  ('засучив', 'засуч'),
#  ('рукава', 'рукав'),
#  ('или', 'ил'),
#  ('верчусь', 'верч'),
#  ('целый', 'цел'),
#  ('день', 'ден'),
#  ('как', 'как'),
#  ('белка', 'белк'),
#  ('в', 'в'),
#  ('колесе', 'колес'),
#  ('', ''),
#  ('', ''),
#  ('кроме', 'кром'),
#  ('обстоятельств', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('выделяются', 'выделя'),
#  ('всегда', 'всегд'),
#  ('', ''),
#  ('могут', 'могут'),
#  ('факультативно', 'факультативн'),
#  ('обособляться', 'обособля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('', ''),
#  ('выраженные', 'выражен'),
#  ('существительными', 'существительн'),
#  ('с', 'с'),
#  ('производными', 'производн'),
#  ('предлогами', 'предлог'),
#  ('благодаря', 'благодар'),
#  ('', ''),
#  ('согласно', 'согласн'),
#  ('', ''),
#  ('вопреки', 'вопрек'),
#  ('', ''),
#  ('ввиду', 'ввид'),
#  ('', ''),
#  ('вследствие', 'вследств'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('благодаря', 'благодар'),
#  ('хорошей', 'хорош'),
#  ('погоде', 'погод'),
#  ('', ''),
#  ('мы', 'мы'),
#  ('купались', 'купа'),
#  ('в', 'в'),
#  ('реке', 'рек'),
#  ('все', 'все'),
#  ('лето', 'лет'),
#  ('', ''),
#  ('обычно', 'обычн'),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обособляются', 'обособля'),
#  ('', ''),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('распространены', 'распростран'),
#  ('и', 'и'),
#  ('стоят', 'сто'),
#  ('перед', 'перед'),
#  ('сказуемым', 'сказуем'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('наречием', 'нареч'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('дворник', 'дворник'),
#  ('встает', 'встает'),
#  ('рано', 'ран'),
#  ('', ''),
#  ('', ''),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('мужики', 'мужик'),
#  ('', ''),
#  ('увидев', 'увид'),
#  ('помещика', 'помещик'),
#  ('', ''),
#  ('сняли', 'снял'),
#  ('шапки', 'шапк'),
#  ('', ''),
#  ('', ''),
#  ('инфинитивом', 'инфинитив'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('все', 'все'),
#  ('отправились', 'отправ'),
#  ('на', 'на'),
#  ('улицу', 'улиц'),
#  ('', ''),
#  ('зачем', 'зач'),
#  ('', ''),
#  ('', ''),
#  ('расчищать', 'расчища'),
#  ('снег', 'снег'),
#  ('', ''),
#  ('', ''),
#  ('существительным', 'существительн'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('я', 'я'),
#  ('приехал', 'приеха'),
#  ('в', 'в'),
#  ('столицу', 'столиц'),
#  ('', ''),
#  ('зачем', 'зач'),
#  ('', ''),
#  ('', ''),
#  ('на', 'на'),
#  ('экскурсию', 'экскурс'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('места', 'мест'),
#  ('', ''),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('где', 'где'),
#  ('', ''),
#  ('куда', 'куд'),
#  ('', ''),
#  ('откуда', 'откуд'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('мы', 'мы'),
#  ('въехали', 'въеха'),
#  ('', ''),
#  ('куда', 'куд'),
#  ('', ''),
#  ('', ''),
#  ('в', 'в'),
#  ('город', 'город'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('времени', 'времен'),
#  ('', ''),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('когда', 'когд'),
#  ('', ''),
#  ('с', 'с'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('', ''),
#  ('до', 'до'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('', ''),
#  ('как', 'как'),
#  ('долго', 'долг'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('мы', 'мы'),
#  ('прождали', 'прожда'),
#  ('их', 'их'),
#  ('около', 'окол'),
#  ('двух', 'двух'),
#  ('часов', 'час'),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('причины', 'причин'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('почему', 'поч'),
#  ('', ''),
#  ('отчего', 'отч'),
#  ('', ''),
#  ('по', 'по'),
#  ('какой', 'как'),
#  ('причине', 'причин'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('от', 'от'),
#  ('усталости', 'устал'),
#  ('я', 'я'),
#  ('не', 'не'),
#  ('мог', 'мог'),
#  ('говорить', 'говор'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('цели', 'цел'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('зачем', 'зач'),
#  ('', ''),
#  ('для', 'для'),
#  ('чего', 'чег'),
#  ('', ''),
#  ('с', 'с'),
#  ('какой', 'как'),
#  ('целью', 'цел'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('в', 'в'),
#  ('санатории', 'санатор'),
#  ('все', 'все'),
#  ('приготовлено', 'приготовл'),
#  ('для', 'для'),
#  ('лечения', 'лечен'),
#  ('отдыхающих', 'отдыха'),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('образа', 'образ'),
#  ('действия', 'действ'),
#  ('и', 'и'),
#  ('степени', 'степен'),
#  ('', ''),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('как', 'как'),
#  ('', ''),
#  ('каким', 'как'),
#  ('образом', 'образ'),
#  ('', ''),
#  ('в', 'в'),
#  ('какой', 'как'),
#  ('степени', 'степен'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('я', 'я'),
#  ('несколько', 'нескольк'),
#  ('призадумался', 'призадума'),
#  ('или', 'ил'),
#  ('отец', 'отец'),
#  ('ни', 'ни'),
#  ('на', 'на'),
#  ('шаг', 'шаг'),
#  ('не', 'не'),
#  ('отпускал', 'отпуска'),
#  ('меня', 'мен'),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('условия', 'услов'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('при', 'при'),
#  ('каком', 'как'),
#  ('условии', 'услов'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('при', 'при'),
#  ('старании', 'старан'),
#  ('можно', 'можн'),
#  ('добиться', 'доб'),
#  ('успеха', 'успех'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('', ''),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('на', 'на'),
#  ('улице', 'улиц'),
#  ('', ''),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('мороз', 'мороз'),
#  ('', ''),
#  ('было', 'был'),
#  ('многолюдно', 'многолюдн'),
#  ('', ''),
#  ('', ''),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('', ''),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('', ''),
#  ('например', 'например'),
#  ('', ''),
#  ('голова', 'голов'),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('острижена', 'остриж'),
#  ('', ''),
#  ('как', 'как'),
#  ('у', 'у'),
#  ('мальчишки', 'мальчишк'),
#  ('', ''),
#  ('', ''),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('выражены', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('', ''),
#  ('', ''),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('представляют', 'представля'),
#  ('собой', 'соб'),
#  ('сравнительный', 'сравнительн'),
#  ('оборот', 'оборот'),
#  ('', ''),
#  ('', ''),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('', ''),
#  ('', ''),
#  ('через', 'через'),
#  ('две', 'две'),
#  ('недели', 'недел'),
#  ('', ''),
#  ('наш', 'наш'),
#  ('сотрудник', 'сотрудник'),
#  ('выйдет', 'выйдет'),
#  ('из', 'из'),
#  ('отпуска', 'отпуск'),
#  ('', ''),
#  ('', ''),
#  ('петр', 'петр'),
#  ('пошел', 'пошел'),
#  ('в', 'в'),
#  ('библиотеку', 'библиотек'),
#  ('', ''),
#  ('готовиться', 'готов'),
#  ('к', 'к'),
#  ('экзамену', 'экзамен'),
#  ('', ''),
#  ('', ''),
#  ('выбежав', 'выбежа'),
#  ('на', 'на'),
#  ('трибуну', 'трибун'),
#  ('', ''),
#  ('он', 'он'),
#  ('быстро', 'быстр'),
#  ('заговорил', 'заговор'),
#  ('', ''),
#  ('', ''),
#  ('обгоняя', 'обгон'),
#  ('грузовик', 'грузовик'),
#  ('', ''),
#  ('машина', 'машин'),
#  ('выехала', 'выеха'),
#  ('на', 'на'),
#  ('встречную', 'встречн'),
#  ('полосу', 'полос'),
#  ('', ''),
#  ('', ''),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('опасность', 'опасн'),
#  ('', ''),
#  ('капитан', 'капита'),
#  ('приказал', 'приказа'),
#  ('продолжить', 'продолж'),
#  ('движение', 'движен'),
#  ('', ''),
#  ('', ''),
#  ('из', 'из'),
#  ('леса', 'лес'),
#  ('', ''),
#  ('доносились', 'донос'),
#  ('голоса', 'голос'),
#  ('грибников', 'грибник'),
#  ('', ''),
#  ('', ''),
#  ('ради', 'рад'),
#  ('победы', 'побед'),
#  ('', ''),
#  ('они', 'он'),
#  ('готовы', 'готов'),
#  ('на', 'на'),
#  ('все', 'все'),
#  ('', ''),
#  ('', ''),
#  ('мокрые', 'мокр'),
#  ('ступени', 'ступен'),
#  ('оказались', 'оказа'),
#  ('скользкими', 'скользк'),
#  ('', ''),
#  ('как', 'как'),
#  ('лед', 'лед'),
#  ('', ''),
#  ('', ''),
#  ('порт', 'порт'),
#  ('будет', 'будет'),
#  ('закрыт', 'закр'),
#  ('', ''),
#  ('в', 'в'),
#  ('случае', 'случа'),
#  ('усиления', 'усилен'),
#  ('ветра', 'ветр'),
#  ('', ''),
#  ('', ''),
#  ('было', 'был'),
#  ('темно', 'темн'),
#  ('', ''),
#  ('только', 'тольк'),
#  ('две', 'две'),
#  ('звездочки', 'звездочк'),
#  ('', ''),
#  ('как', 'как'),
#  ('два', 'два'),
#  ('спасательных', 'спасательн'),
#  ('маяка', 'маяк'),
#  ('', ''),
#  ('сверкали', 'сверка'),
#  ('на', 'на'),
#  ('темно-синем', 'темно-син'),
#  ('своде', 'свод'),
#  ('', ''),
#  ('лермонтов', 'лермонт'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('летит', 'лет'),
#  ('', ''),
#  ('сломя', 'слом'),
#  ('голову', 'голов'),
#  ('', ''),
#  ('', ''),
#  ('чуть', 'чут'),
#  ('с', 'с'),
#  ('ног', 'ног'),
#  ('не', 'не'),
#  ('сбил', 'сбил'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('пробормотала', 'пробормота'),
#  ('старуха', 'старух'),
#  ('', ''),
#  ('', ''),
#  ('на', 'на'),
#  ('борту', 'борт'),
#  ('пиджака', 'пиджак'),
#  ('', ''),
#  ('как', 'как'),
#  ('глаз', 'глаз'),
#  ('', ''),
#  ('торчал', 'торча'),
#  ('драгоценный', 'драгоцен'),
#  ('камень', 'камен'),
#  ('', ''),
#  ('м', 'м'),
#  ('', ''),
#  ('булгаков', 'булгак'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('старуха', 'старух'),
#  ('', ''),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('преклонный', 'преклон'),
#  ('возраст', 'возраст'),
#  ('', ''),
#  ('отлично', 'отличн'),
#  ('видит', 'вид'),
#  ('и', 'и'),
#  ('слышит', 'слыш'),
#  ('', ''),
#  ('а', 'а'),
#  ('', ''),
#  ('чехов', 'чех'),
#  ('', ''),
#  ('', ''),
#  ('пройдя', 'пройд'),
#  ('через', 'через'),
#  ('тяжкие', 'тяжк'),
#  ('испытания', 'испытан'),
#  ('', ''),
#  ('он', 'он'),
#  ('сумел', 'сумел'),
#  ('сохранить', 'сохран'),
#  ('свое', 'сво'),
#  ('человеческое', 'человеческ'),
#  ('достоинство', 'достоинств'),
#  ('', ''),
#  ('м', 'м'),
#  ('', ''),
#  ('шолохов', 'шолох'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('в', 'в'),
#  ('плите', 'плит'),
#  ('гудело', 'гудел'),
#  ...]

# %%
stemmed_clean = []
for i in range(len(stemmed)):
    if stemmed[i]!=('', ''):
        stemmed_clean.append(stemmed[i])

# %%
stemmed_clean
# Out:
# [('наши', 'наш'),
#  ('награды', 'наград'),
#  ('спор', 'спор'),
#  ('дискуссия', 'дискусс'),
#  ('диспут', 'диспут'),
#  ('и', 'и'),
#  ('полемика', 'полемик'),
#  ('эти', 'эт'),
#  ('синонимичные', 'синонимичн'),
#  ('понятия', 'понят'),
#  ('часто', 'част'),
#  ('сбивают', 'сбива'),
#  ('нас', 'нас'),
#  ('с', 'с'),
#  ('толку', 'толк'),
#  ('в', 'в'),
#  ('чём', 'чем'),
#  ('же', 'же'),
#  ('разница', 'разниц'),
#  ('и', 'и'),
#  ('что', 'что'),
#  ('такое', 'так'),
#  ('жуска', 'жуск'),
#  ('спор', 'спор'),
#  ('дискуссия', 'дискусс'),
#  ('диспут', 'диспут'),
#  ('и', 'и'),
#  ('полемика', 'полемик'),
#  ('проверка', 'проверк'),
#  ('слова', 'слов'),
#  ('выберите', 'выбер'),
#  ('правильные', 'правильн'),
#  ('варианты', 'вариант'),
#  ('ответов', 'ответ'),
#  ('для', 'для'),
#  ('проверки', 'проверк'),
#  ('выполненного', 'выполнен'),
#  ('задания', 'задан'),
#  ('нажмите', 'нажм'),
#  ('кнопку', 'кнопк'),
#  ('проверить', 'провер'),
#  ('обстоятельство', 'обстоятельств'),
#  ('второстепенный', 'второстепен'),
#  ('член', 'член'),
#  ('предложения', 'предложен'),
#  ('который', 'котор'),
#  ('обозначает', 'обознача'),
#  ('признак', 'признак'),
#  ('действия', 'действ'),
#  ('или', 'ил'),
#  ('другого', 'друг'),
#  ('признака', 'признак'),
#  ('обстоятельства', 'обстоятельств'),
#  ('поясняют', 'поясня'),
#  ('сказуемые', 'сказуем'),
#  ('или', 'ил'),
#  ('другие', 'друг'),
#  ('члены', 'член'),
#  ('предложения', 'предложен'),
#  ('при', 'при'),
#  ('синтаксическом', 'синтаксическ'),
#  ('разборе', 'разбор'),
#  ('предложения', 'предложен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('подчеркиваются', 'подчеркива'),
#  ('пунктирной', 'пунктирн'),
#  ('линией', 'лин'),
#  ('тире', 'тир'),
#  ('точка', 'точк'),
#  ('тире', 'тир'),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('в', 'в'),
#  ('трех', 'трех'),
#  ('случаях', 'случа'),
#  ('рассмотрим', 'рассмотр'),
#  ('каждый', 'кажд'),
#  ('из', 'из'),
#  ('них', 'них'),
#  ('по', 'по'),
#  ('очереди', 'очеред'),
#  ('первый', 'перв'),
#  ('случай', 'случа'),
#  ('обстоятельства', 'обстоятельств'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('могут', 'могут'),
#  ('быть', 'быт'),
#  ('выражены', 'выраж'),
#  ('четырьмя', 'четырьм'),
#  ('частями', 'част'),
#  ('речи', 'реч'),
#  ('кроме', 'кром'),
#  ('этого', 'эт'),
#  ('обстоятельство', 'обстоятельств'),
#  ('может', 'может'),
#  ('быть', 'быт'),
#  ('выражено', 'выраж'),
#  ('цельным', 'цельн'),
#  ('по', 'по'),
#  ('смыслу', 'смысл'),
#  ('выражением', 'выражен'),
#  ('например', 'например'),
#  ('дождь', 'дожд'),
#  ('шел', 'шел'),
#  ('две', 'две'),
#  ('недели', 'недел'),
#  ('подряд', 'подряд'),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('что', 'что'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('нужно', 'нужн'),
#  ('обстоятельства', 'обстоятельств'),
#  ('которые', 'котор'),
#  ('выражены', 'выраж'),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('сравните', 'сравн'),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('и', 'и'),
#  ('скучал', 'скуча'),
#  ('и', 'и'),
#  ('он', 'он'),
#  ('сидел', 'сидел'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('в', 'в'),
#  ('первом', 'перв'),
#  ('предложении', 'предложен'),
#  ('обстоятельство', 'обстоятельств'),
#  ('листая', 'лист'),
#  ('журнал', 'журна'),
#  ('выделяется', 'выделя'),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('а', 'а'),
#  ('во', 'во'),
#  ('втором', 'втор'),
#  ('обстоятельство', 'обстоятельств'),
#  ('на', 'на'),
#  ('скамейке', 'скамейк'),
#  ('не', 'не'),
#  ('обособляется', 'обособля'),
#  ('так', 'так'),
#  ('как', 'как'),
#  ('оно', 'он'),
#  ('выражено', 'выраж'),
#  ('существительным', 'существительн'),
#  ('с', 'с'),
#  ('предлогом', 'предлог'),
#  ('второй', 'втор'),
#  ('и', 'и'),
#  ('третий', 'трет'),
#  ('случаи', 'случа'),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('делятся', 'дел'),
#  ('на', 'на'),
#  ('следующие', 'след'),
#  ('основные', 'основн'),
#  ('группы', 'групп'),
#  ('в', 'в'),
#  ('классификации', 'классификац'),
#  ('обстоятельств', 'обстоятельств'),
#  ('по', 'по'),
#  ('значению', 'значен'),
#  ('одним', 'одн'),
#  ('из', 'из'),
#  ('восьми', 'восьм'),
#  ('видов', 'вид'),
#  ('являются', 'явля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('они', 'он'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('и', 'и'),
#  ('начинается', 'начина'),
#  ('с', 'с'),
#  ('союзов', 'союз'),
#  ('как', 'как'),
#  ('словно', 'словн'),
#  ('или', 'ил'),
#  ('будто', 'будт'),
#  ('например', 'например'),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('были', 'был'),
#  ('длинные', 'длин'),
#  ('волосы', 'волос'),
#  ('мягкие', 'мягк'),
#  ('как', 'как'),
#  ('лен', 'лен'),
#  ('в', 'в'),
#  ('некоторых', 'некотор'),
#  ('учебниках', 'учебник'),
#  ('и', 'и'),
#  ('справочных', 'справочн'),
#  ('пособиях', 'пособ'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('называют', 'называ'),
#  ('также', 'такж'),
#  ('сравнительными', 'сравнительн'),
#  ('оборотами', 'оборот'),
#  ('необходимо', 'необходим'),
#  ('запомнить', 'запомн'),
#  ('что', 'что'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('в', 'в'),
#  ('предложениях', 'предложен'),
#  ('выделяются', 'выделя'),
#  ('запятыми', 'запят'),
#  ('еще', 'ещ'),
#  ('один', 'один'),
#  ('вид', 'вид'),
#  ('обстоятельств', 'обстоятельств'),
#  ('который', 'котор'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('это', 'эт'),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('и', 'и'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('или', 'ил'),
#  ('реже', 'реж'),
#  ('вопреки', 'вопрек'),
#  ('например', 'например'),
#  ('на', 'на'),
#  ('улицах', 'улиц'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('яркое', 'ярк'),
#  ('солнце', 'солнц'),
#  ('горели', 'горел'),
#  ('фонари', 'фонар'),
#  ('итак', 'итак'),
#  ('следует', 'след'),
#  ('запомнить', 'запомн'),
#  ('три', 'три'),
#  ('случая', 'случ'),
#  ('когда', 'когд'),
#  ('обстоятельства', 'обстоятельств'),
#  ('необходимо', 'необходим'),
#  ('выделять', 'выделя'),
#  ('запятыми', 'запят'),
#  ('еще', 'ещ'),
#  ('раз', 'раз'),
#  ('рассмотрите', 'рассмотр'),
#  ('примеры', 'пример'),
#  ('сверкая', 'сверк'),
#  ('быстро', 'быстр'),
#  ('в', 'в'),
#  ('вышине', 'вышин'),
#  ('кружились', 'круж'),
#  ('искры', 'искр'),
#  ('лермонтов', 'лермонт'),
#  ('она', 'он'),
#  ('вдруг', 'вдруг'),
#  ('скрылась', 'скрыл'),
#  ('как', 'как'),
#  ('птичка', 'птичк'),
#  ('вспугнутая', 'вспугнут'),
#  ('из', 'из'),
#  ('кустарника', 'кустарник'),
#  ('лермонтов', 'лермонт'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('непредвиденные', 'непредвиден'),
#  ('трудности', 'трудност'),
#  ('работа', 'работ'),
#  ('закончена', 'законч'),
#  ('в', 'в'),
#  ('срок', 'срок'),
#  ('это', 'эт'),
#  ('правило', 'прав'),
#  ('имеет', 'имеет'),
#  ('несколько', 'нескольк'),
#  ('важных', 'важн'),
#  ('примечаний', 'примечан'),
#  ('от', 'от'),
#  ('деепричастий', 'деепричаст'),
#  ('следует', 'след'),
#  ('отличать', 'отлича'),
#  ('наречия', 'нареч'),
#  ('стоя', 'сто'),
#  ('сидя', 'сид'),
#  ('лежа', 'леж'),
#  ('молча', 'молч'),
#  ('нехотя', 'нехот'),
#  ('шутя', 'шут'),
#  ('не', 'не'),
#  ('глядя', 'гляд'),
#  ('играя', 'игр'),
#  ('они', 'он'),
#  ('образовались', 'образова'),
#  ('благодаря', 'благодар'),
#  ('переходу', 'переход'),
#  ('слов', 'слов'),
#  ('из', 'из'),
#  ('разряда', 'разряд'),
#  ('деепричастий', 'деепричаст'),
#  ('в', 'в'),
#  ('наречия', 'нареч'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('такими', 'так'),
#  ('словами', 'слов'),
#  ('не', 'не'),
#  ('обособляются', 'обособля'),
#  ('например', 'например'),
#  ('он', 'он'),
#  ('стоял', 'стоя'),
#  ('молча', 'молч'),
#  ('не', 'не'),
#  ('выделяются', 'выделя'),
#  ('также', 'такж'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('фразеологическими', 'фразеологическ'),
#  ('оборотами', 'оборот'),
#  ('например', 'например'),
#  ('они', 'он'),
#  ('работали', 'работа'),
#  ('засучив', 'засуч'),
#  ('рукава', 'рукав'),
#  ('или', 'ил'),
#  ('верчусь', 'верч'),
#  ('целый', 'цел'),
#  ('день', 'ден'),
#  ('как', 'как'),
#  ('белка', 'белк'),
#  ('в', 'в'),
#  ('колесе', 'колес'),
#  ('кроме', 'кром'),
#  ('обстоятельств', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('которые', 'котор'),
#  ('выделяются', 'выделя'),
#  ('всегда', 'всегд'),
#  ('могут', 'могут'),
#  ('факультативно', 'факультативн'),
#  ('обособляться', 'обособля'),
#  ('обстоятельства', 'обстоятельств'),
#  ('выраженные', 'выражен'),
#  ('существительными', 'существительн'),
#  ('с', 'с'),
#  ('производными', 'производн'),
#  ('предлогами', 'предлог'),
#  ('благодаря', 'благодар'),
#  ('согласно', 'согласн'),
#  ('вопреки', 'вопрек'),
#  ('ввиду', 'ввид'),
#  ('вследствие', 'вследств'),
#  ('например', 'например'),
#  ('благодаря', 'благодар'),
#  ('хорошей', 'хорош'),
#  ('погоде', 'погод'),
#  ('мы', 'мы'),
#  ('купались', 'купа'),
#  ('в', 'в'),
#  ('реке', 'рек'),
#  ('все', 'все'),
#  ('лето', 'лет'),
#  ('обычно', 'обычн'),
#  ('такие', 'так'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обособляются', 'обособля'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('распространены', 'распростран'),
#  ('и', 'и'),
#  ('стоят', 'сто'),
#  ('перед', 'перед'),
#  ('сказуемым', 'сказуем'),
#  ('наречием', 'нареч'),
#  ('например', 'например'),
#  ('дворник', 'дворник'),
#  ('встает', 'встает'),
#  ('рано', 'ран'),
#  ('деепричастием', 'деепричаст'),
#  ('или', 'ил'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('например', 'например'),
#  ('мужики', 'мужик'),
#  ('увидев', 'увид'),
#  ('помещика', 'помещик'),
#  ('сняли', 'снял'),
#  ('шапки', 'шапк'),
#  ('инфинитивом', 'инфинитив'),
#  ('например', 'например'),
#  ('все', 'все'),
#  ('отправились', 'отправ'),
#  ('на', 'на'),
#  ('улицу', 'улиц'),
#  ('зачем', 'зач'),
#  ('расчищать', 'расчища'),
#  ('снег', 'снег'),
#  ('существительным', 'существительн'),
#  ('например', 'например'),
#  ('я', 'я'),
#  ('приехал', 'приеха'),
#  ('в', 'в'),
#  ('столицу', 'столиц'),
#  ('зачем', 'зач'),
#  ('на', 'на'),
#  ('экскурсию', 'экскурс'),
#  ('обстоятельства', 'обстоятельств'),
#  ('места', 'мест'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('где', 'где'),
#  ('куда', 'куд'),
#  ('откуда', 'откуд'),
#  ('например', 'например'),
#  ('мы', 'мы'),
#  ('въехали', 'въеха'),
#  ('куда', 'куд'),
#  ('в', 'в'),
#  ('город', 'город'),
#  ('обстоятельства', 'обстоятельств'),
#  ('времени', 'времен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('когда', 'когд'),
#  ('с', 'с'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('до', 'до'),
#  ('каких', 'как'),
#  ('пор', 'пор'),
#  ('как', 'как'),
#  ('долго', 'долг'),
#  ('например', 'например'),
#  ('мы', 'мы'),
#  ('прождали', 'прожда'),
#  ('их', 'их'),
#  ('около', 'окол'),
#  ('двух', 'двух'),
#  ('часов', 'час'),
#  ('обстоятельства', 'обстоятельств'),
#  ('причины', 'причин'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('почему', 'поч'),
#  ('отчего', 'отч'),
#  ('по', 'по'),
#  ('какой', 'как'),
#  ('причине', 'причин'),
#  ('например', 'например'),
#  ('от', 'от'),
#  ('усталости', 'устал'),
#  ('я', 'я'),
#  ('не', 'не'),
#  ('мог', 'мог'),
#  ('говорить', 'говор'),
#  ('обстоятельства', 'обстоятельств'),
#  ('цели', 'цел'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('зачем', 'зач'),
#  ('для', 'для'),
#  ('чего', 'чег'),
#  ('с', 'с'),
#  ('какой', 'как'),
#  ('целью', 'цел'),
#  ('например', 'например'),
#  ('в', 'в'),
#  ('санатории', 'санатор'),
#  ('все', 'все'),
#  ('приготовлено', 'приготовл'),
#  ('для', 'для'),
#  ('лечения', 'лечен'),
#  ('отдыхающих', 'отдыха'),
#  ('обстоятельства', 'обстоятельств'),
#  ('образа', 'образ'),
#  ('действия', 'действ'),
#  ('и', 'и'),
#  ('степени', 'степен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('как', 'как'),
#  ('каким', 'как'),
#  ('образом', 'образ'),
#  ('в', 'в'),
#  ('какой', 'как'),
#  ('степени', 'степен'),
#  ('например', 'например'),
#  ('я', 'я'),
#  ('несколько', 'нескольк'),
#  ('призадумался', 'призадума'),
#  ('или', 'ил'),
#  ('отец', 'отец'),
#  ('ни', 'ни'),
#  ('на', 'на'),
#  ('шаг', 'шаг'),
#  ('не', 'не'),
#  ('отпускал', 'отпуска'),
#  ('меня', 'мен'),
#  ('обстоятельства', 'обстоятельств'),
#  ('условия', 'услов'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('при', 'при'),
#  ('каком', 'как'),
#  ('условии', 'услов'),
#  ('например', 'например'),
#  ('при', 'при'),
#  ('старании', 'старан'),
#  ('можно', 'можн'),
#  ('добиться', 'доб'),
#  ('успеха', 'успех'),
#  ('обстоятельства', 'обстоятельств'),
#  ('уступки', 'уступк'),
#  ('которые', 'котор'),
#  ('отвечают', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('что', 'что'),
#  ('например', 'например'),
#  ('на', 'на'),
#  ('улице', 'улиц'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('мороз', 'мороз'),
#  ('было', 'был'),
#  ('многолюдно', 'многолюдн'),
#  ('обстоятельства', 'обстоятельств'),
#  ('сравнения', 'сравнен'),
#  ('отвечающие', 'отвеча'),
#  ('на', 'на'),
#  ('вопрос', 'вопрос'),
#  ('как', 'как'),
#  ('например', 'например'),
#  ('голова', 'голов'),
#  ('у', 'у'),
#  ('нее', 'не'),
#  ('острижена', 'остриж'),
#  ('как', 'как'),
#  ('у', 'у'),
#  ('мальчишки', 'мальчишк'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('выражены', 'выраж'),
#  ('деепричастным', 'деепричастн'),
#  ('оборотом', 'оборот'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('представляют', 'представля'),
#  ('собой', 'соб'),
#  ('сравнительный', 'сравнительн'),
#  ('оборот', 'оборот'),
#  ('если', 'есл'),
#  ('они', 'он'),
#  ('начинаются', 'начина'),
#  ('с', 'с'),
#  ('предлога', 'предлог'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('через', 'через'),
#  ('две', 'две'),
#  ('недели', 'недел'),
#  ('наш', 'наш'),
#  ('сотрудник', 'сотрудник'),
#  ('выйдет', 'выйдет'),
#  ('из', 'из'),
#  ('отпуска', 'отпуск'),
#  ('петр', 'петр'),
#  ('пошел', 'пошел'),
#  ('в', 'в'),
#  ('библиотеку', 'библиотек'),
#  ('готовиться', 'готов'),
#  ('к', 'к'),
#  ('экзамену', 'экзамен'),
#  ('выбежав', 'выбежа'),
#  ('на', 'на'),
#  ('трибуну', 'трибун'),
#  ('он', 'он'),
#  ('быстро', 'быстр'),
#  ('заговорил', 'заговор'),
#  ('обгоняя', 'обгон'),
#  ('грузовик', 'грузовик'),
#  ('машина', 'машин'),
#  ('выехала', 'выеха'),
#  ('на', 'на'),
#  ('встречную', 'встречн'),
#  ('полосу', 'полос'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('опасность', 'опасн'),
#  ('капитан', 'капита'),
#  ('приказал', 'приказа'),
#  ('продолжить', 'продолж'),
#  ('движение', 'движен'),
#  ('из', 'из'),
#  ('леса', 'лес'),
#  ('доносились', 'донос'),
#  ('голоса', 'голос'),
#  ('грибников', 'грибник'),
#  ('ради', 'рад'),
#  ('победы', 'побед'),
#  ('они', 'он'),
#  ('готовы', 'готов'),
#  ('на', 'на'),
#  ('все', 'все'),
#  ('мокрые', 'мокр'),
#  ('ступени', 'ступен'),
#  ('оказались', 'оказа'),
#  ('скользкими', 'скользк'),
#  ('как', 'как'),
#  ('лед', 'лед'),
#  ('порт', 'порт'),
#  ('будет', 'будет'),
#  ('закрыт', 'закр'),
#  ('в', 'в'),
#  ('случае', 'случа'),
#  ('усиления', 'усилен'),
#  ('ветра', 'ветр'),
#  ('было', 'был'),
#  ('темно', 'темн'),
#  ('только', 'тольк'),
#  ('две', 'две'),
#  ('звездочки', 'звездочк'),
#  ('как', 'как'),
#  ('два', 'два'),
#  ('спасательных', 'спасательн'),
#  ('маяка', 'маяк'),
#  ('сверкали', 'сверка'),
#  ('на', 'на'),
#  ('темно-синем', 'темно-син'),
#  ('своде', 'свод'),
#  ('лермонтов', 'лермонт'),
#  ('летит', 'лет'),
#  ('сломя', 'слом'),
#  ('голову', 'голов'),
#  ('чуть', 'чут'),
#  ('с', 'с'),
#  ('ног', 'ног'),
#  ('не', 'не'),
#  ('сбил', 'сбил'),
#  ('пробормотала', 'пробормота'),
#  ('старуха', 'старух'),
#  ('на', 'на'),
#  ('борту', 'борт'),
#  ('пиджака', 'пиджак'),
#  ('как', 'как'),
#  ('глаз', 'глаз'),
#  ('торчал', 'торча'),
#  ('драгоценный', 'драгоцен'),
#  ('камень', 'камен'),
#  ('м', 'м'),
#  ('булгаков', 'булгак'),
#  ('старуха', 'старух'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('преклонный', 'преклон'),
#  ('возраст', 'возраст'),
#  ('отлично', 'отличн'),
#  ('видит', 'вид'),
#  ('и', 'и'),
#  ('слышит', 'слыш'),
#  ('а', 'а'),
#  ('чехов', 'чех'),
#  ('пройдя', 'пройд'),
#  ('через', 'через'),
#  ('тяжкие', 'тяжк'),
#  ('испытания', 'испытан'),
#  ('он', 'он'),
#  ('сумел', 'сумел'),
#  ('сохранить', 'сохран'),
#  ('свое', 'сво'),
#  ('человеческое', 'человеческ'),
#  ('достоинство', 'достоинств'),
#  ('м', 'м'),
#  ('шолохов', 'шолох'),
#  ('в', 'в'),
#  ('плите', 'плит'),
#  ('гудело', 'гудел'),
#  ('как', 'как'),
#  ('на', 'на'),
#  ('пожаре', 'пожар'),
#  ('м', 'м'),
#  ('булгаков', 'булгак'),
#  ('на', 'на'),
#  ('вопросы', 'вопрос'),
#  ('следователя', 'следовател'),
#  ('он', 'он'),
#  ('отвечал', 'отвеча'),
#  ('нехотя', 'нехот'),
#  ('лодка', 'лодк'),
#  ('как', 'как'),
#  ('утка', 'утк'),
#  ('ныряла', 'ныря'),
#  ('и', 'и'),
#  ('потом', 'пот'),
#  ('взмахнув', 'взмахнув'),
#  ('веслами', 'весл'),
#  ('будто', 'будт'),
#  ('крыльями', 'крыл'),
#  ('выскакивала', 'выскакива'),
#  ('на', 'на'),
#  ('поверхности', 'поверхн'),
#  ('м', 'м'),
#  ('лермонтов', 'лермонт'),
#  ('прихватив', 'прихват'),
#  ('немецкого', 'немецк'),
#  ('майора', 'майор'),
#  ('и', 'и'),
#  ('портфель', 'портфел'),
#  ('с', 'с'),
#  ('документами', 'документ'),
#  ('соколов', 'сокол'),
#  ('добирается', 'добира'),
#  ('до', 'до'),
#  ('своих', 'сво'),
#  ('м', 'м'),
#  ('шолохов', 'шолох'),
#  ('пережив', 'переж'),
#  ('сильное', 'сильн'),
#  ('потрясение', 'потрясен'),
#  ('он', 'он'),
#  ('заснул', 'заснул'),
#  ('как', 'как'),
#  ('убитый', 'убит'),
#  ('везде', 'везд'),
#  ('и', 'и'),
#  ('во', 'во'),
#  ('всем', 'всем'),
#  ('он', 'он'),
#  ('старался', 'стара'),
#  ('подчеркнуть', 'подчеркнут'),
#  ('свое', 'сво'),
#  ('превосходство', 'превосходств'),
#  ('считая', 'счит'),
#  ('себя', 'себ'),
#  ('благовоспитанным', 'благовоспита'),
#  ('и', 'и'),
#  ('гуманным', 'гума'),
#  ('а', 'а'),
#  ('фадеев', 'фаде'),
#  ('татьяна', 'татья'),
#  ('любит', 'люб'),
#  ('не', 'не'),
#  ('шутя', 'шут'),
#  ('а', 'а'),
#  ('пушкин', 'пушкин'),
#  ('жили', 'жил'),
#  ('спокойно', 'спокойн'),
#  ('и', 'и'),
#  ('вдруг', 'вдруг'),
#  ('гости', 'гост'),
#  ('свалились', 'свал'),
#  ('как', 'как'),
#  ('снег', 'снег'),
#  ('на', 'на'),
#  ('голову', 'голов'),
#  ('с', 'с'),
#  ('тех', 'тех'),
#  ('пор', 'пор'),
#  ('и', 'и'),
#  ('до', 'до'),
#  ('конца', 'конц'),
#  ('московского', 'московск'),
#  ('разорения', 'разорен'),
#  ('никто', 'никт'),
#  ('из', 'из'),
#  ('домашних', 'домашн'),
#  ('безуховых', 'безухов'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('все', 'все'),
#  ('поиски', 'поиск'),
#  ('не', 'не'),
#  ('видел', 'видел'),
#  ('больше', 'больш'),
#  ('пьера', 'пьер'),
#  ('и', 'и'),
#  ('не', 'не'),
#  ('знал', 'знал'),
#  ('где', 'где'),
#  ('он', 'он'),
#  ('находится', 'наход'),
#  ('л', 'л'),
#  ('толстой', 'толст'),
#  ('две', 'две'),
#  ('минуты', 'минут'),
#  ('тому', 'том'),
#  ('назад', 'назад'),
#  ('не', 'не'),
#  ('подвергая', 'подверг'),
#  ('себя', 'себ'),
#  ('никакой', 'никак'),
#  ('опасности', 'опасн'),
#  ('хотел', 'хотел'),
#  ('меня', 'мен'),
#  ('убить', 'уб'),
#  ('как', 'как'),
#  ('собаку', 'собак'),
#  ('ибо', 'иб'),
#  ('раненный', 'ранен'),
#  ('в', 'в'),
#  ('ногу', 'ног'),
#  ('немного', 'немн'),
#  ('сильнее', 'сильн'),
#  ('я', 'я'),
#  ('бы', 'бы'),
#  ('непременно', 'непремен'),
#  ('свалился', 'свал'),
#  ('с', 'с'),
#  ('утёса', 'утес'),
#  ('м', 'м'),
#  ('лермонтов', 'лермонт'),
#  ('а', 'а'),
#  ('затем', 'зат'),
#  ('на', 'на'),
#  ('пожарища', 'пожарищ'),
#  ('посыпали', 'посыпа'),
#  ('сотни', 'сотн'),
#  ('мелких', 'мелк'),
#  ('зажигательных', 'зажигательн'),
#  ('бомб', 'бомб'),
#  ('как', 'как'),
#  ('зерна', 'зерн'),
#  ('на', 'на'),
#  ('свежевспаханную', 'свежевспаха'),
#  ('землю', 'земл'),
#  ('к', 'к'),
#  ('воннегут', 'воннегут'),
#  ('людей', 'люд'),
#  ('одиноких', 'одинок'),
#  ('по', 'по'),
#  ('натуре', 'натур'),
#  ('которые', 'котор'),
#  ('как', 'как'),
#  ('рак-отшельник', 'рак-отшельник'),
#  ('или', 'ил'),
#  ('улитка', 'улитк'),
#  ('стараются', 'стара'),
#  ('уйти', 'уйт'),
#  ('в', 'в'),
#  ('свою', 'сво'),
#  ('скорлупу', 'скорлуп'),
#  ('на', 'на'),
#  ('этом', 'эт'),
#  ('свете', 'свет'),
#  ('не', 'не'),
#  ('мало', 'мал'),
#  ('а', 'а'),
#  ('чехов', 'чех'),
#  ('какой-то', 'какой-т'),
#  ('сволочной', 'сволочн'),
#  ('под', 'под'),
#  ('сибирского', 'сибирск'),
#  ('деланный', 'дела'),
#  ('кот-бродяга', 'кот-бродяг'),
#  ('вынырнул', 'вынырнул'),
#  ('из-за', 'из-з'),
#  ('водосточной', 'водосточн'),
#  ('трубы', 'труб'),
#  ('и', 'и'),
#  ('несмотря', 'несмотр'),
#  ('на', 'на'),
#  ('вьюгу', 'вьюг'),
#  ('учуял', 'учуя'),
#  ('краковскую', 'краковск'),
#  ('м', 'м'),
#  ('булгаков', 'булгак'),
#  ('долгое', 'долг'),
#  ('время', 'врем'),
#  ('он', 'он'),
#  ('боролся', 'борол'),
#  ('с', 'с'),
#  ('своею', 'сво'),
#  ('догадкою', 'догадк'),
#  ('принимая', 'приним'),
#  ('ее', 'е'),
#  ('за', 'за'),
#  ('мечту', 'мечт'),
#  ('воспаленного', 'воспален'),
#  ('съестными', 'съестн'),
#  ('припасами', 'припас'),
#  ('воображения', 'воображен'),
#  ('но', 'но'),
#  ('чем', 'чем'),
#  ('чаще', 'чащ'),
#  ('повторялись', 'повторя'),
#  ('свидания', 'свидан'),
#  ('тем', 'тем'),
#  ('мучительнее', 'мучительн'),
#  ('становились', 'станов'),
#  ('сомнения', 'сомнен'),
#  ('м', 'м'),
#  ('салтыков-щедрин', 'салтыков-щедрин')]

# %% [markdown]
# Ошибки первого вида (два разных слова ошибочно свелись к одинаковой основе):
#
# ('следует', 'след')
# ('следующие', 'след')
#
# ('выражением', 'выражен')
# ('выраженные', 'выражен')

# %%
sorted(stemmed_clean)
# Out:
# [('а', 'а'),
#  ('а', 'а'),
#  ('а', 'а'),
#  ('а', 'а'),
#  ('а', 'а'),
#  ('а', 'а'),
#  ('безуховых', 'безухов'),
#  ('белка', 'белк'),
#  ('библиотеку', 'библиотек'),
#  ('благовоспитанным', 'благовоспита'),
#  ('благодаря', 'благодар'),
#  ('благодаря', 'благодар'),
#  ('благодаря', 'благодар'),
#  ('больше', 'больш'),
#  ('бомб', 'бомб'),
#  ('боролся', 'борол'),
#  ('борту', 'борт'),
#  ('будет', 'будет'),
#  ('будто', 'будт'),
#  ('будто', 'будт'),
#  ('булгаков', 'булгак'),
#  ('булгаков', 'булгак'),
#  ('булгаков', 'булгак'),
#  ('бы', 'бы'),
#  ('были', 'был'),
#  ('было', 'был'),
#  ('было', 'был'),
#  ('быстро', 'быстр'),
#  ('быстро', 'быстр'),
#  ('быть', 'быт'),
#  ('быть', 'быт'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('в', 'в'),
#  ('важных', 'важн'),
#  ('варианты', 'вариант'),
#  ('ввиду', 'ввид'),
#  ('вдруг', 'вдруг'),
#  ('вдруг', 'вдруг'),
#  ('везде', 'везд'),
#  ('верчусь', 'верч'),
#  ('веслами', 'весл'),
#  ('ветра', 'ветр'),
#  ('взмахнув', 'взмахнув'),
#  ('вид', 'вид'),
#  ('видел', 'видел'),
#  ('видит', 'вид'),
#  ('видов', 'вид'),
#  ('во', 'во'),
#  ('во', 'во'),
#  ('водосточной', 'водосточн'),
#  ('возраст', 'возраст'),
#  ('волосы', 'волос'),
#  ('воннегут', 'воннегут'),
#  ('воображения', 'воображен'),
#  ('вопреки', 'вопрек'),
#  ('вопреки', 'вопрек'),
#  ('вопрос', 'вопрос'),
#  ('вопрос', 'вопрос'),
#  ('вопрос', 'вопрос'),
#  ('вопрос', 'вопрос'),
#  ('вопрос', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('вопросы', 'вопрос'),
#  ('воспаленного', 'воспален'),
#  ('восьми', 'восьм'),
#  ('времени', 'времен'),
#  ('время', 'врем'),
#  ('все', 'все'),
#  ('все', 'все'),
#  ('все', 'все'),
#  ('все', 'все'),
#  ('все', 'все'),
#  ('всегда', 'всегд'),
#  ('всем', 'всем'),
#  ('вследствие', 'вследств'),
#  ('вспугнутая', 'вспугнут'),
#  ('встает', 'встает'),
#  ('встречную', 'встречн'),
#  ('второй', 'втор'),
#  ('втором', 'втор'),
#  ('второстепенный', 'второстепен'),
#  ('въехали', 'въеха'),
#  ('выбежав', 'выбежа'),
#  ('выберите', 'выбер'),
#  ('выделяется', 'выделя'),
#  ('выделять', 'выделя'),
#  ('выделять', 'выделя'),
#  ('выделять', 'выделя'),
#  ('выделять', 'выделя'),
#  ('выделяются', 'выделя'),
#  ('выделяются', 'выделя'),
#  ('выделяются', 'выделя'),
#  ('выехала', 'выеха'),
#  ('выйдет', 'выйдет'),
#  ('вынырнул', 'вынырнул'),
#  ('выполненного', 'выполнен'),
#  ('выражением', 'выражен'),
#  ('выраженные', 'выражен'),
#  ('выраженные', 'выражен'),
#  ('выраженные', 'выражен'),
#  ('выражено', 'выраж'),
#  ('выражено', 'выраж'),
#  ('выражено', 'выраж'),
#  ('выражены', 'выраж'),
#  ('выражены', 'выраж'),
#  ('выражены', 'выраж'),
#  ('выскакивала', 'выскакива'),
#  ('вышине', 'вышин'),
#  ('вьюгу', 'вьюг'),
#  ('где', 'где'),
#  ('где', 'где'),
#  ('глаз', 'глаз'),
#  ('глядя', 'гляд'),
#  ('говорить', 'говор'),
#  ('голова', 'голов'),
#  ('голову', 'голов'),
#  ('голову', 'голов'),
#  ('голоса', 'голос'),
#  ('горели', 'горел'),
#  ('город', 'город'),
#  ('гости', 'гост'),
#  ('готовиться', 'готов'),
#  ('готовы', 'готов'),
#  ('грибников', 'грибник'),
#  ('грузовик', 'грузовик'),
#  ('группы', 'групп'),
#  ('гудело', 'гудел'),
#  ('гуманным', 'гума'),
#  ('два', 'два'),
#  ('две', 'две'),
#  ('две', 'две'),
#  ('две', 'две'),
#  ('две', 'две'),
#  ('движение', 'движен'),
#  ('дворник', 'дворник'),
#  ('двух', 'двух'),
#  ('деепричастием', 'деепричаст'),
#  ('деепричастием', 'деепричаст'),
#  ('деепричастий', 'деепричаст'),
#  ('деепричастий', 'деепричаст'),
#  ('деепричастным', 'деепричастн'),
#  ('деепричастным', 'деепричастн'),
#  ('деепричастным', 'деепричастн'),
#  ('деепричастным', 'деепричастн'),
#  ('действия', 'действ'),
#  ('действия', 'действ'),
#  ('деланный', 'дела'),
#  ('делятся', 'дел'),
#  ('день', 'ден'),
#  ('дискуссия', 'дискусс'),
#  ('дискуссия', 'дискусс'),
#  ('диспут', 'диспут'),
#  ('диспут', 'диспут'),
#  ('длинные', 'длин'),
#  ('для', 'для'),
#  ('для', 'для'),
#  ('для', 'для'),
#  ('до', 'до'),
#  ('до', 'до'),
#  ('до', 'до'),
#  ('добирается', 'добира'),
#  ('добиться', 'доб'),
#  ('догадкою', 'догадк'),
#  ('дождь', 'дожд'),
#  ('документами', 'документ'),
#  ('долго', 'долг'),
#  ('долгое', 'долг'),
#  ('домашних', 'домашн'),
#  ('доносились', 'донос'),
#  ('достоинство', 'достоинств'),
#  ('драгоценный', 'драгоцен'),
#  ('другие', 'друг'),
#  ('другого', 'друг'),
#  ('ее', 'е'),
#  ('если', 'есл'),
#  ('если', 'есл'),
#  ('если', 'есл'),
#  ('если', 'есл'),
#  ('еще', 'ещ'),
#  ('еще', 'ещ'),
#  ('же', 'же'),
#  ('жили', 'жил'),
#  ('журнал', 'журна'),
#  ('журнал', 'журна'),
#  ('жуска', 'жуск'),
#  ('за', 'за'),
#  ('заговорил', 'заговор'),
#  ('задания', 'задан'),
#  ('зажигательных', 'зажигательн'),
#  ('закончена', 'законч'),
#  ('закрыт', 'закр'),
#  ('запомнить', 'запомн'),
#  ('запомнить', 'запомн'),
#  ('запомнить', 'запомн'),
#  ('запятыми', 'запят'),
#  ('запятыми', 'запят'),
#  ('запятыми', 'запят'),
#  ('запятыми', 'запят'),
#  ('запятыми', 'запят'),
#  ('заснул', 'заснул'),
#  ('засучив', 'засуч'),
#  ('затем', 'зат'),
#  ('зачем', 'зач'),
#  ('зачем', 'зач'),
#  ('зачем', 'зач'),
#  ('звездочки', 'звездочк'),
#  ('землю', 'земл'),
#  ('зерна', 'зерн'),
#  ('знал', 'знал'),
#  ('значению', 'значен'),
#  ('значению', 'значен'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('и', 'и'),
#  ('ибо', 'иб'),
#  ('играя', 'игр'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из', 'из'),
#  ('из-за', 'из-з'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('или', 'ил'),
#  ('имеет', 'имеет'),
#  ('инфинитивом', 'инфинитив'),
#  ('искры', 'искр'),
#  ('испытания', 'испытан'),
#  ('итак', 'итак'),
#  ('их', 'их'),
#  ('к', 'к'),
#  ('к', 'к'),
#  ('каждый', 'кажд'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('как', 'как'),
#  ('каким', 'как'),
#  ('каких', 'как'),
#  ('каких', 'как'),
#  ('какой', 'как'),
#  ('какой', 'как'),
#  ('какой', 'как'),
#  ('какой-то', 'какой-т'),
#  ('каком', 'как'),
#  ('камень', 'камен'),
#  ('капитан', 'капита'),
#  ('классификации', 'классификац'),
#  ('кнопку', 'кнопк'),
#  ('когда', 'когд'),
#  ('когда', 'когд'),
#  ('колесе', 'колес'),
#  ('конца', 'конц'),
#  ('кот-бродяга', 'кот-бродяг'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('которые', 'котор'),
#  ('который', 'котор'),
#  ('который', 'котор'),
#  ('краковскую', 'краковск'),
#  ('кроме', 'кром'),
#  ('кроме', 'кром'),
#  ('кружились', 'круж'),
#  ('крыльями', 'крыл'),
#  ('куда', 'куд'),
#  ('куда', 'куд'),
#  ('купались', 'купа'),
#  ('кустарника', 'кустарник'),
#  ('л', 'л'),
#  ('лед', 'лед'),
#  ('лежа', 'леж'),
#  ('лен', 'лен'),
#  ('лермонтов', 'лермонт'),
#  ('лермонтов', 'лермонт'),
#  ('лермонтов', 'лермонт'),
#  ('лермонтов', 'лермонт'),
#  ('лермонтов', 'лермонт'),
#  ('леса', 'лес'),
#  ('летит', 'лет'),
#  ('лето', 'лет'),
#  ('лечения', 'лечен'),
#  ('линией', 'лин'),
#  ('листая', 'лист'),
#  ('листая', 'лист'),
#  ('лодка', 'лодк'),
#  ('любит', 'люб'),
#  ('людей', 'люд'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('м', 'м'),
#  ('майора', 'майор'),
#  ('мало', 'мал'),
#  ('мальчишки', 'мальчишк'),
#  ('машина', 'машин'),
#  ('маяка', 'маяк'),
#  ('мелких', 'мелк'),
#  ('меня', 'мен'),
#  ('меня', 'мен'),
#  ('места', 'мест'),
#  ('мечту', 'мечт'),
#  ('минуты', 'минут'),
#  ('многолюдно', 'многолюдн'),
#  ('мог', 'мог'),
#  ('могут', 'могут'),
#  ('могут', 'могут'),
#  ('может', 'может'),
#  ('можно', 'можн'),
#  ('мокрые', 'мокр'),
#  ('молча', 'молч'),
#  ('молча', 'молч'),
#  ('мороз', 'мороз'),
#  ('московского', 'московск'),
#  ('мужики', 'мужик'),
#  ('мучительнее', 'мучительн'),
#  ('мы', 'мы'),
#  ('мы', 'мы'),
#  ('мы', 'мы'),
#  ('мягкие', 'мягк'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('на', 'на'),
#  ('награды', 'наград'),
#  ('нажмите', 'нажм'),
#  ('назад', 'назад'),
#  ('называют', 'называ'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('например', 'например'),
#  ('наречием', 'нареч'),
#  ('наречия', 'нареч'),
#  ('наречия', 'нареч'),
#  ('нас', 'нас'),
#  ('натуре', 'натур'),
#  ('находится', 'наход'),
#  ('начинается', 'начина'),
#  ('начинаются', 'начина'),
#  ('начинаются', 'начина'),
#  ('наш', 'наш'),
#  ('наши', 'наш'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('не', 'не'),
#  ('недели', 'недел'),
#  ('недели', 'недел'),
#  ('нее', 'не'),
#  ('нее', 'не'),
#  ('некоторых', 'некотор'),
#  ('немецкого', 'немецк'),
#  ('немного', 'немн'),
#  ('необходимо', 'необходим'),
#  ('необходимо', 'необходим'),
#  ('необходимо', 'необходим'),
#  ('необходимо', 'необходим'),
#  ('необходимо', 'необходим'),
#  ('непредвиденные', 'непредвиден'),
#  ('непременно', 'непремен'),
#  ('несколько', 'нескольк'),
#  ('несколько', 'нескольк'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('несмотря', 'несмотр'),
#  ('нехотя', 'нехот'),
#  ('нехотя', 'нехот'),
#  ('ни', 'ни'),
#  ('никакой', 'никак'),
#  ('никто', 'никт'),
#  ('них', 'них'),
#  ('но', 'но'),
#  ('ног', 'ног'),
#  ('ногу', 'ног'),
#  ('нужно', 'нужн'),
#  ('ныряла', 'ныря'),
#  ('обгоняя', 'обгон'),
#  ('обозначает', 'обознача'),
#  ('оборот', 'оборот'),
#  ('оборотами', 'оборот'),
#  ('оборотами', 'оборот'),
#  ('оборотом', 'оборот'),
#  ('оборотом', 'оборот'),
#  ('оборотом', 'оборот'),
#  ('оборотом', 'оборот'),
#  ('обособляется', 'обособля'),
#  ('обособляться', 'обособля'),
#  ('обособляются', 'обособля'),
#  ('обособляются', 'обособля'),
#  ('образа', 'образ'),
#  ('образовались', 'образова'),
#  ('образом', 'образ'),
#  ('обстоятельств', 'обстоятельств'),
#  ('обстоятельств', 'обстоятельств'),
#  ('обстоятельств', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельства', 'обстоятельств'),
#  ('обстоятельство', 'обстоятельств'),
#  ('обстоятельство', 'обстоятельств'),
#  ('обстоятельство', 'обстоятельств'),
#  ('обстоятельство', 'обстоятельств'),
#  ('обычно', 'обычн'),
#  ('один', 'один'),
#  ('одиноких', 'одинок'),
#  ('одним', 'одн'),
#  ('оказались', 'оказа'),
#  ('около', 'окол'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('он', 'он'),
#  ('она', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('они', 'он'),
#  ('оно', 'он'),
#  ('оно', 'он'),
#  ('опасности', 'опасн'),
#  ('опасность', 'опасн'),
#  ('основные', 'основн'),
#  ('острижена', 'остриж'),
#  ('от', 'от'),
#  ('от', 'от'),
#  ('ответов', 'ответ'),
#  ('отвечал', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечают', 'отвеча'),
#  ('отвечающие', 'отвеча'),
#  ('отвечающие', 'отвеча'),
#  ('отвечающие', 'отвеча'),
#  ('отвечающие', 'отвеча'),
#  ('отдыхающих', 'отдыха'),
#  ('отец', 'отец'),
#  ('откуда', 'откуд'),
#  ('отличать', 'отлича'),
#  ('отлично', 'отличн'),
#  ('отправились', 'отправ'),
#  ('отпуска', 'отпуск'),
#  ('отпускал', 'отпуска'),
#  ('отчего', 'отч'),
#  ('очереди', 'очеред'),
#  ('первом', 'перв'),
#  ('первый', 'перв'),
#  ('перед', 'перед'),
#  ('пережив', 'переж'),
#  ('переходу', 'переход'),
#  ('петр', 'петр'),
#  ('пиджака', 'пиджак'),
#  ('плите', 'плит'),
#  ('по', 'по'),
#  ('по', 'по'),
#  ('по', 'по'),
#  ('по', 'по'),
#  ('по', 'по'),
#  ('по', 'по'),
#  ('победы', 'побед'),
#  ('поверхности', 'поверхн'),
#  ('повторялись', 'повторя'),
#  ('погоде', 'погод'),
#  ('под', 'под'),
#  ('подвергая', 'подверг'),
#  ('подряд', 'подряд'),
#  ('подчеркиваются', 'подчеркива'),
#  ('подчеркнуть', 'подчеркнут'),
#  ('пожаре', 'пожар'),
#  ('пожарища', 'пожарищ'),
#  ('поиски', 'поиск'),
#  ('полемика', 'полемик'),
#  ('полемика', 'полемик'),
#  ('полосу', 'полос'),
#  ('помещика', 'помещик'),
#  ('понятия', 'понят'),
#  ('пор', 'пор'),
#  ('пор', 'пор'),
#  ('пор', 'пор'),
#  ('порт', 'порт'),
#  ('портфель', 'портфел'),
#  ('пособиях', 'пособ'),
#  ('посыпали', 'посыпа'),
#  ('потом', 'пот'),
#  ('потрясение', 'потрясен'),
#  ('почему', 'поч'),
#  ('пошел', 'пошел'),
#  ('поясняют', 'поясня'),
#  ('правило', 'прав'),
#  ('правильные', 'правильн'),
#  ('превосходство', 'превосходств'),
#  ('предлога', 'предлог'),
#  ('предлога', 'предлог'),
#  ('предлогами', 'предлог'),
#  ('предлогом', 'предлог'),
#  ('предложении', 'предложен'),
#  ('предложения', 'предложен'),
#  ('предложения', 'предложен'),
#  ('предложения', 'предложен'),
#  ('предложениях', 'предложен'),
#  ('предложениях', 'предложен'),
#  ('представляют', 'представля'),
#  ('преклонный', 'преклон'),
#  ('при', 'при'),
#  ('при', 'при'),
#  ('при', 'при'),
#  ('приготовлено', 'приготовл'),
#  ('приехал', 'приеха'),
#  ('призадумался', 'призадума'),
#  ('признак', 'признак'),
#  ('признака', 'признак'),
#  ('приказал', 'приказа'),
#  ('примеры', 'пример'),
#  ('примечаний', 'примечан'),
#  ('принимая', 'приним'),
#  ('припасами', 'припас'),
#  ('прихватив', 'прихват'),
#  ('причине', 'причин'),
#  ('причины', 'причин'),
#  ('пробормотала', 'пробормота'),
#  ('проверить', 'провер'),
#  ('проверка', 'проверк'),
#  ('проверки', 'проверк'),
#  ('продолжить', 'продолж'),
#  ('прождали', 'прожда'),
#  ('производными', 'производн'),
#  ('пройдя', 'пройд'),
#  ('птичка', 'птичк'),
#  ('пунктирной', 'пунктирн'),
#  ('пушкин', 'пушкин'),
#  ('пьера', 'пьер'),
#  ('работа', 'работ'),
#  ('работали', 'работа'),
#  ('ради', 'рад'),
#  ('раз', 'раз'),
#  ('разборе', 'разбор'),
#  ('разница', 'разниц'),
#  ('разорения', 'разорен'),
#  ('разряда', 'разряд'),
#  ('рак-отшельник', 'рак-отшельник'),
#  ('раненный', 'ранен'),
#  ('рано', 'ран'),
#  ('распространены', 'распростран'),
#  ('рассмотрим', 'рассмотр'),
#  ('рассмотрите', 'рассмотр'),
#  ('расчищать', 'расчища'),
#  ('реже', 'реж'),
#  ('реке', 'рек'),
#  ('речи', 'реч'),
#  ('рукава', 'рукав'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('с', 'с'),
#  ('салтыков-щедрин', 'салтыков-щедрин'),
#  ('санатории', 'санатор'),
#  ('сбивают', 'сбива'),
#  ('сбил', 'сбил'),
#  ('свалились', 'свал'),
#  ('свалился', 'свал'),
#  ('свежевспаханную', 'свежевспаха'),
#  ('сверкали', 'сверка'),
#  ('сверкая', 'сверк'),
#  ('свете', 'свет'),
#  ('свидания', 'свидан'),
#  ('своде', 'свод'),
#  ('свое', 'сво'),
#  ('свое', 'сво'),
#  ('своею', 'сво'),
#  ('своих', 'сво'),
#  ('сволочной', 'сволочн'),
#  ('свою', 'сво'),
#  ('себя', 'себ'),
#  ('себя', 'себ'),
#  ('сибирского', 'сибирск'),
#  ('сидел', 'сидел'),
#  ('сидел', 'сидел'),
#  ('сидя', 'сид'),
#  ('сильнее', 'сильн'),
#  ('сильное', 'сильн'),
#  ('синонимичные', 'синонимичн'),
#  ('синтаксическом', 'синтаксическ'),
#  ('сказуемые', 'сказуем'),
#  ('сказуемым', 'сказуем'),
#  ('скамейке', 'скамейк'),
#  ('скамейке', 'скамейк'),
#  ('скользкими', 'скользк'),
#  ('скорлупу', 'скорлуп'),
#  ('скрылась', 'скрыл'),
#  ('скучал', 'скуча'),
#  ('следователя', 'следовател'),
#  ('следует', 'след'),
#  ('следует', 'след'),
#  ('следующие', 'след'),
#  ('слов', 'слов'),
#  ('слова', 'слов'),
#  ('словами', 'слов'),
#  ('словно', 'словн'),
#  ('сломя', 'слом'),
#  ('случае', 'случа'),
#  ('случаи', 'случа'),
#  ('случай', 'случа'),
#  ('случая', 'случ'),
#  ('случаях', 'случа'),
#  ('слышит', 'слыш'),
#  ('смыслу', 'смысл'),
#  ('снег', 'снег'),
#  ('снег', 'снег'),
#  ('сняли', 'снял'),
#  ('собаку', 'собак'),
#  ('собой', 'соб'),
#  ('согласно', 'согласн'),
#  ('соколов', 'сокол'),
#  ('солнце', 'солнц'),
#  ('сомнения', 'сомнен'),
#  ('сотни', 'сотн'),
#  ('сотрудник', 'сотрудник'),
#  ('сохранить', 'сохран'),
#  ('союзов', 'союз'),
#  ('спасательных', 'спасательн'),
#  ('спокойно', 'спокойн'),
#  ('спор', 'спор'),
#  ('спор', 'спор'),
#  ('справочных', 'справочн'),
#  ('сравнения', 'сравнен'),
#  ('сравнения', 'сравнен'),
#  ('сравнения', 'сравнен'),
#  ('сравнения', 'сравнен'),
#  ('сравните', 'сравн'),
#  ('сравнительный', 'сравнительн'),
#  ('сравнительными', 'сравнительн'),
#  ('срок', 'срок'),
#  ('становились', 'станов'),
#  ('старался', 'стара'),
#  ('старании', 'старан'),
#  ('стараются', 'стара'),
#  ('старуха', 'старух'),
#  ('старуха', 'старух'),
#  ('степени', 'степен'),
#  ('степени', 'степен'),
#  ('столицу', 'столиц'),
#  ('стоя', 'сто'),
#  ('стоял', 'стоя'),
#  ('стоят', 'сто'),
#  ('ступени', 'ступен'),
#  ('сумел', 'сумел'),
#  ('существительным', 'существительн'),
#  ('существительным', 'существительн'),
#  ('существительными', 'существительн'),
#  ('считая', 'счит'),
#  ('съестными', 'съестн'),
#  ('так', 'так'),
#  ('так', 'так'),
#  ('также', 'такж'),
#  ('также', 'такж'),
#  ('такие', 'так'),
#  ('такие', 'так'),
#  ('такими', 'так'),
#  ('такое', 'так'),
#  ('татьяна', 'татья'),
#  ('тем', 'тем'),
#  ('темно', 'темн'),
#  ('темно-синем', 'темно-син'),
#  ('тех', 'тех'),
#  ('тире', 'тир'),
#  ('тире', 'тир'),
#  ('толку', 'толк'),
#  ('толстой', 'толст'),
#  ('только', 'тольк'),
#  ('тому', 'том'),
#  ('торчал', 'торча'),
#  ('точка', 'точк'),
#  ('третий', 'трет'),
#  ('трех', 'трех'),
#  ('три', 'три'),
#  ('трибуну', 'трибун'),
#  ('трубы', 'труб'),
#  ('трудности', 'трудност'),
#  ('тяжкие', 'тяжк'),
#  ('у', 'у'),
#  ('у', 'у'),
#  ('у', 'у'),
#  ('убитый', 'убит'),
#  ('убить', 'уб'),
#  ('увидев', 'увид'),
#  ('уйти', 'уйт'),
#  ('улитка', 'улитк'),
#  ('улицах', 'улиц'),
#  ('улице', 'улиц'),
#  ('улицу', 'улиц'),
#  ('усиления', 'усилен'),
#  ('условии', 'услов'),
#  ('условия', 'услов'),
#  ('успеха', 'успех'),
#  ('усталости', 'устал'),
#  ('уступки', 'уступк'),
#  ('уступки', 'уступк'),
#  ('уступки', 'уступк'),
#  ('утка', 'утк'),
#  ('утёса', 'утес'),
#  ('учебниках', 'учебник'),
#  ('учуял', 'учуя'),
#  ('фадеев', 'фаде'),
#  ('факультативно', 'факультативн'),
#  ('фонари', 'фонар'),
#  ('фразеологическими', 'фразеологическ'),
#  ('хорошей', 'хорош'),
#  ('хотел', 'хотел'),
#  ('цели', 'цел'),
#  ('целый', 'цел'),
#  ('цельным', 'цельн'),
#  ('целью', 'цел'),
#  ('часов', 'час'),
#  ('часто', 'част'),
#  ('частями', 'част'),
#  ('чаще', 'чащ'),
#  ('чего', 'чег'),
#  ('человеческое', 'человеческ'),
#  ('чем', 'чем'),
#  ('через', 'через'),
#  ('через', 'через'),
#  ('четырьмя', 'четырьм'),
#  ('чехов', 'чех'),
#  ('чехов', 'чех'),
#  ('член', 'член'),
#  ('члены', 'член'),
#  ('что', 'что'),
#  ('что', 'что'),
#  ('что', 'что'),
#  ('что', 'что'),
#  ('что', 'что'),
#  ('чуть', 'чут'),
#  ('чём', 'чем'),
#  ('шаг', 'шаг'),
#  ('шапки', 'шапк'),
#  ('шел', 'шел'),
#  ('шолохов', 'шолох'),
#  ('шолохов', 'шолох'),
#  ('шутя', 'шут'),
#  ('шутя', 'шут'),
#  ('экзамену', 'экзамен'),
#  ('экскурсию', 'экскурс'),
#  ('эти', 'эт'),
#  ('это', 'эт'),
#  ('это', 'эт'),
#  ('этого', 'эт'),
#  ('этом', 'эт'),
#  ('я', 'я'),
#  ('я', 'я'),
#  ('я', 'я'),
#  ('я', 'я'),
#  ('являются', 'явля'),
#  ('яркое', 'ярк')]

# %% [markdown]
# Ошибки второго вида (две словоформы одного слова после стемминга отличаются друг от друга):

# %% [markdown]
#  ('видел', 'видел') ('видит', 'вид')
#
#  ('два', 'два') ('две', 'две')
#
#  ('могут', 'могут') ('может', 'может')

# %% [markdown]
# Ошибки третьего вида (слово не изменилось после стемминга):

# %% [markdown]
# ('могут', 'могут')
#
# ('сидел', 'сидел')
#
# ('сумел', 'сумел')

# %% [markdown]
# ### Задание 3

# %%
stops = stopwords.words('russian')
print(sorted(stops))
# Out:
# ['а', 'без', 'более', 'больше', 'будет', 'будто', 'бы', 'был', 'была', 'были', 'было', 'быть', 'в', 'вам', 'вас', 'вдруг', 'ведь', 'во', 'вот', 'впрочем', 'все', 'всегда', 'всего', 'всех', 'всю', 'вы', 'где', 'да', 'даже', 'два', 'для', 'до', 'другой', 'его', 'ее', 'ей', 'ему', 'если', 'есть', 'еще', 'ж', 'же', 'за', 'зачем', 'здесь', 'и', 'из', 'или', 'им', 'иногда', 'их', 'к', 'как', 'какая', 'какой', 'когда', 'конечно', 'кто', 'куда', 'ли', 'лучше', 'между', 'меня', 'мне', 'много', 'может', 'можно', 'мой', 'моя', 'мы', 'на', 'над', 'надо', 'наконец', 'нас', 'не', 'него', 'нее', 'ней', 'нельзя', 'нет', 'ни', 'нибудь', 'никогда', 'ним', 'них', 'ничего', 'но', 'ну', 'о', 'об', 'один', 'он', 'она', 'они', 'опять', 'от', 'перед', 'по', 'под', 'после', 'потом', 'потому', 'почти', 'при', 'про', 'раз', 'разве', 'с', 'сам', 'свою', 'себе', 'себя', 'сейчас', 'со', 'совсем', 'так', 'такой', 'там', 'тебя', 'тем', 'теперь', 'то', 'тогда', 'того', 'тоже', 'только', 'том', 'тот', 'три', 'тут', 'ты', 'у', 'уж', 'уже', 'хорошо', 'хоть', 'чего', 'чем', 'через', 'что', 'чтоб', 'чтобы', 'чуть', 'эти', 'этого', 'этой', 'этом', 'этот', 'эту', 'я']

# %% [markdown]
# Я бы добавила «та», «те» и словоформы в различных падежах для «какая», «какой», «какое», «какие», для «который», «которая», «которые», «которое» и для «никакой», «никакая», «никакое» и «никакие».

# %% [markdown]
# ### Задание 4

# %%
URL = "https://zona.media/news/2019/09/11/zhukov-expertise"
r = requests.get(URL) 
bs=BeautifulSoup(r.text, "html5lib") 

text2 = BeautifulSoup(" ".join([p.text for p in bs.find_all("p")]), "html5lib").get_text().replace("\xa0", " ")
print(soup)
# Out:
# Наши награды Спор, дискуссия, диспут и полемика...
#
# Эти синонимичные понятия часто сбивают нас с толку. В чём же разница? И что такое жуска? Спор, дискуссия, диспут и полемика Проверка слова:   Выберите правильные варианты ответов. Для проверки выполненного задания нажмите кнопку «Проверить». Обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. Обстоятельства поясняют сказуемые или другие члены предложения. При синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). Обстоятельства необходимо выделять запятыми в трех случаях. Рассмотрим каждый из них по очереди.  Первый случай Обстоятельства в предложениях могут быть выражены четырьмя частями речи:  Кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: Дождь шел две недели подряд.  Необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборотом. Сравните: Он сидел, листая журнал, и скучал и Он сидел на скамейке. В первом предложении обстоятельство листая журнал выделяется, так как оно выражено деепричастным оборотом, а во втором обстоятельство на скамейке не обособляется, так как оно выражено существительным с предлогом.  Второй и третий случаи  По значению обстоятельства делятся на следующие основные группы:  В классификации обстоятельств по значению одним из восьми видов являются обстоятельства сравнения: они отвечают на вопрос КАК? и начинается с союзов КАК, СЛОВНО или БУДТО. Например: У нее были длинные волосы, мягкие, как лен. В некоторых учебниках и справочных пособиях обстоятельства сравнения называют также сравнительными оборотами. Необходимо запомнить, что обстоятельства сравнения в предложениях выделяются запятыми.  Еще один вид обстоятельств, который необходимо выделять запятыми, это обстоятельства уступки. Такие обстоятельства отвечают на вопрос НЕСМОТРЯ НА ЧТО? и начинаются с предлога НЕСМОТРЯ НА (или, реже, ВОПРЕКИ). Например: На улицах, несмотря на яркое солнце, горели фонари.  Итак, следует запомнить три случая, когда обстоятельства необходимо выделять запятыми:  Еще раз рассмотрите примеры. Сверкая быстро в вышине, кружились искры. (Лермонтов) Она вдруг скрылась, как птичка, вспугнутая из кустарника (Лермонтов). Несмотря на непредвиденные трудности, работа закончена в срок.  Это правило имеет несколько важных примечаний:  От деепричастий следует отличать наречия СТОЯ, СИДЯ, ЛЕЖА, МОЛЧА. НЕХОТЯ, ШУТЯ, НЕ ГЛЯДЯ, ИГРАЯ. Они образовались благодаря переходу слов из разряда деепричастий в наречия. Обстоятельства, выраженные такими словами, не обособляются. Например: Он стоял молча.  Не выделяются также обстоятельства, выраженные фразеологическими оборотами, например: Они работали засучив рукава или Верчусь целый день как белка в колесе.  Кроме обстоятельств уступки, которые выделяются всегда, могут факультативно обособляться обстоятельства, выраженные существительными с производными предлогами БЛАГОДАРЯ, СОГЛАСНО, ВОПРЕКИ, ВВИДУ, ВСЛЕДСТВИЕ, например: Благодаря хорошей погоде, мы купались в реке все лето. Обычно такие обстоятельства обособляются, если они распространены и стоят перед сказуемым.

# %%
tokens = sent_tokenize(text2, 'russian')

# %%
tokens
# Out:
# ['\u200b«Новая газета» опубликовала сокращенный вариант заключения экспертов Александра Коршикова и Анны Осокиной, которые анализировали видео из блога студента Высшей школы экономики Егора Жукова, обвиняемого в призывах к экстремизму в интернете (часть 2 статьи 280 УК).',
#  'Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова.',
#  'По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».',
#  'В заключении говорится, что Жуков приписывает действующей власти «враждебные действия», называет ее врагами, источником зла и вреда.',
#  'Кроме того, студент призывает с этой властью бороться.',
#  '«Автор описывает катастрофическое положение населения в России, как следствие целенаправленной политики действующей власти <...>.',
#  'Основным идеалом, которого следует достичь, является "смена власти в России" для того, чтобы "Россия стала свободной"», — цитирует издание экспертов.',
#  'В одном из видео, в котором Жуков размышлял об итогах митинга 7 октября 2017 года, эксперты увидели призыв бороться любым способом, «что включает в себя и действия насильственного характера, в частности, насильственный захват власти, вооруженный мятеж».',
#  'Егор Жуков — фигурант «московского дела».',
#  'Сначала его обвиняли в участии в массовых беспорядках (часть 2 статьи 212 УК).',
#  'В суде говорили, что среди материалов есть видео, где Жуков показывает кому-то направо на акции 27 июля.',
#  'Из-за этого студента 2 августа отправили в СИЗО.',
#  'Однако через месяц дело о массовых беспорядках против Жукова закрыли, ему предъявили новое обвинение в призывах к экстремизму.',
#  'По ходатайстве следствие суд перевел студента под домашний арест.',
#  'Читайте также Раз в неделю наши авторы делятся своими впечатлениями от главных событий и текстов Истории трех петербурженок, которые годами борются с бесами Раз в неделю наши авторы делятся своими впечатлениями от главных событий и текстов  Последнее слово Участие подсудимого в акции доказывали решением суда по протоколу, который был одинаковым для десятков задержанных Мосгорсуд оставил приговор в силе']

# %%
clean_tokens = []
def cleaner(sents):
    for i in range(len(sents)):
        clean_tokens.append(re.findall('\w+', (re.sub(r'[«»<>()"—.\–_,\':;…?!]', '', sents[i].replace('\u200b', ' '))).lower()))
cleaner(tokens)
clean_tokens
# Out:
# [['новая',
#   'газета',
#   'опубликовала',
#   'сокращенный',
#   'вариант',
#   'заключения',
#   'экспертов',
#   'александра',
#   'коршикова',
#   'и',
#   'анны',
#   'осокиной',
#   'которые',
#   'анализировали',
#   'видео',
#   'из',
#   'блога',
#   'студента',
#   'высшей',
#   'школы',
#   'экономики',
#   'егора',
#   'жукова',
#   'обвиняемого',
#   'в',
#   'призывах',
#   'к',
#   'экстремизму',
#   'в',
#   'интернете',
#   'часть',
#   '2',
#   'статьи',
#   '280',
#   'ук'],
#  ['эксперты',
#   'нашли',
#   'экстремизм',
#   'в',
#   'четырех',
#   'видео',
#   'на',
#   'youtube',
#   'канале',
#   'жукова'],
#  ['по',
#   'их',
#   'мнению',
#   'в',
#   'видео',
#   'отчетливо',
#   'прослеживается',
#   'мотив',
#   'политической',
#   'ненависти',
#   'или',
#   'вражды',
#   'к',
#   'действующей',
#   'власти'],
#  ['в',
#   'заключении',
#   'говорится',
#   'что',
#   'жуков',
#   'приписывает',
#   'действующей',
#   'власти',
#   'враждебные',
#   'действия',
#   'называет',
#   'ее',
#   'врагами',
#   'источником',
#   'зла',
#   'и',
#   'вреда'],
#  ['кроме', 'того', 'студент', 'призывает', 'с', 'этой', 'властью', 'бороться'],
#  ['автор',
#   'описывает',
#   'катастрофическое',
#   'положение',
#   'населения',
#   'в',
#   'россии',
#   'как',
#   'следствие',
#   'целенаправленной',
#   'политики',
#   'действующей',
#   'власти'],
#  ['основным',
#   'идеалом',
#   'которого',
#   'следует',
#   'достичь',
#   'является',
#   'смена',
#   'власти',
#   'в',
#   'россии',
#   'для',
#   'того',
#   'чтобы',
#   'россия',
#   'стала',
#   'свободной',
#   'цитирует',
#   'издание',
#   'экспертов'],
#  ['в',
#   'одном',
#   'из',
#   'видео',
#   'в',
#   'котором',
#   'жуков',
#   'размышлял',
#   'об',
#   'итогах',
#   'митинга',
#   '7',
#   'октября',
#   '2017',
#   'года',
#   'эксперты',
#   'увидели',
#   'призыв',
#   'бороться',
#   'любым',
#   'способом',
#   'что',
#   'включает',
#   'в',
#   'себя',
#   'и',
#   'действия',
#   'насильственного',
#   'характера',
#   'в',
#   'частности',
#   'насильственный',
#   'захват',
#   'власти',
#   'вооруженный',
#   'мятеж'],
#  ['егор', 'жуков', 'фигурант', 'московского', 'дела'],
#  ['сначала',
#   'его',
#   'обвиняли',
#   'в',
#   'участии',
#   'в',
#   'массовых',
#   'беспорядках',
#   'часть',
#   '2',
#   'статьи',
#   '212',
#   'ук'],
#  ['в',
#   'суде',
#   'говорили',
#   'что',
#   'среди',
#   'материалов',
#   'есть',
#   'видео',
#   'где',
#   'жуков',
#   'показывает',
#   'кому',
#   'то',
#   'направо',
#   'на',
#   'акции',
#   '27',
#   'июля'],
#  ['из', 'за', 'этого', 'студента', '2', 'августа', 'отправили', 'в', 'сизо'],
#  ['однако',
#   'через',
#   'месяц',
#   'дело',
#   'о',
#   'массовых',
#   'беспорядках',
#   'против',
#   'жукова',
#   'закрыли',
#   'ему',
#   'предъявили',
#   'новое',
#   'обвинение',
#   'в',
#   'призывах',
#   'к',
#   'экстремизму'],
#  ['по',
#   'ходатайстве',
#   'следствие',
#   'суд',
#   'перевел',
#   'студента',
#   'под',
#   'домашний',
#   'арест'],
#  ['читайте',
#   'также',
#   'раз',
#   'в',
#   'неделю',
#   'наши',
#   'авторы',
#   'делятся',
#   'своими',
#   'впечатлениями',
#   'от',
#   'главных',
#   'событий',
#   'и',
#   'текстов',
#   'истории',
#   'трех',
#   'петербурженок',
#   'которые',
#   'годами',
#   'борются',
#   'с',
#   'бесами',
#   'раз',
#   'в',
#   'неделю',
#   'наши',
#   'авторы',
#   'делятся',
#   'своими',
#   'впечатлениями',
#   'от',
#   'главных',
#   'событий',
#   'и',
#   'текстов',
#   'последнее',
#   'слово',
#   'участие',
#   'подсудимого',
#   'в',
#   'акции',
#   'доказывали',
#   'решением',
#   'суда',
#   'по',
#   'протоколу',
#   'который',
#   'был',
#   'одинаковым',
#   'для',
#   'десятков',
#   'задержанных',
#   'мосгорсуд',
#   'оставил',
#   'приговор',
#   'в',
#   'силе']]

# %%
pymorphed = []
for i in range(len(clean_tokens)):
    for j in range(len(clean_tokens[i])):
        pymorphed.append(morph.parse(clean_tokens[i][j]))
pymorphed
# Out:
# [[Parse(word='новая', tag=OpencorporaTag('ADJF,Qual femn,sing,nomn'), normal_form='новый', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'новая', 405, 7),))],
#  [Parse(word='газета', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='газета', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'газета', 55, 0),))],
#  [Parse(word='опубликовала', tag=OpencorporaTag('VERB,perf,tran femn,sing,past,indc'), normal_form='опубликовать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'опубликовала', 276, 2),))],
#  [Parse(word='сокращённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv,Adjx masc,sing,nomn'), normal_form='сократить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'сокращённый', 858, 42),)),
#   Parse(word='сокращённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv,Adjx inan,masc,sing,accs'), normal_form='сократить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'сокращённый', 858, 46),))],
#  [Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='вариант', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 33, 0),)),
#   Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='вариант', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 33, 3),)),
#   Parse(word='вариант', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='варианта', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'вариант', 55, 8),))],
#  [Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='заключение', score=0.967741, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 2),)),
#   Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='заключение', score=0.016129, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 13),)),
#   Parse(word='заключения', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='заключение', score=0.016129, methods_stack=((<DictionaryAnalyzer>, 'заключения', 76, 18),))],
#  [Parse(word='экспертов', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='эксперт', score=0.78125, methods_stack=((<DictionaryAnalyzer>, 'экспертов', 52, 7),)),
#   Parse(word='экспертов', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='эксперт', score=0.21875, methods_stack=((<DictionaryAnalyzer>, 'экспертов', 52, 9),))],
#  [Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 1),)),
#   Parse(word='александра', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='александр', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 26, 3),)),
#   Parse(word='александра', tag=OpencorporaTag('NOUN,anim,femn,Name sing,nomn'), normal_form='александра', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'александра', 68, 0),))],
#  [Parse(word='коршикова', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,nomn'), normal_form='коршикова', score=0.5002875215641174, methods_stack=((<DictionaryAnalyzer>, 'кова', 35, 0), (<UnknownPrefixAnalyzer>, 'корши'))),
#   Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 1), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,accs'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 3), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,nomn'), normal_form='коршиков', score=0.156411730879816, methods_stack=((<FakeDictionary>, 'коршикова', 36, 6), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('ADJS femn,sing'), normal_form='коршиковый', score=0.028177113283496265, methods_stack=((<FakeDictionary>, 'коршикова', 72, 28), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('ADJF,Poss masc,sing,gent'), normal_form='коршиков', score=0.0005750431282346177, methods_stack=((<FakeDictionary>, 'коршикова', 99, 1), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('ADJF,Poss anim,masc,sing,accs'), normal_form='коршиков', score=0.0005750431282346177, methods_stack=((<FakeDictionary>, 'коршикова', 99, 3), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('ADJF,Poss femn,sing,nomn'), normal_form='коршиков', score=0.0005750431282346177, methods_stack=((<FakeDictionary>, 'коршикова', 99, 7), (<KnownSuffixAnalyzer>, 'икова'))),
#   Parse(word='коршикова', tag=OpencorporaTag('ADJF,Poss neut,sing,gent'), normal_form='коршиков', score=0.0005750431282346177, methods_stack=((<FakeDictionary>, 'коршикова', 99, 15), (<KnownSuffixAnalyzer>, 'икова')))],
#  [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#   Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)),
#   Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))],
#  [Parse(word='анны', tag=OpencorporaTag('NOUN,anim,femn,Name sing,gent'), normal_form='анна', score=0.982758, methods_stack=((<DictionaryAnalyzer>, 'анны', 68, 1),)),
#   Parse(word='анны', tag=OpencorporaTag('NOUN,anim,femn,Name plur,nomn'), normal_form='анна', score=0.017241, methods_stack=((<DictionaryAnalyzer>, 'анны', 68, 7),))],
#  [Parse(word='осокиной', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,gent'), normal_form='осокин', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'осокиной', 36, 7),)),
#   Parse(word='осокиной', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,datv'), normal_form='осокин', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'осокиной', 36, 8),)),
#   Parse(word='осокиной', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,ablt'), normal_form='осокин', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'осокиной', 36, 10),)),
#   Parse(word='осокиной', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,loct'), normal_form='осокин', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'осокиной', 36, 11),))],
#  [Parse(word='которые', tag=OpencorporaTag('ADJF,Apro,Subx,Anph plur,nomn'), normal_form='который', score=0.785714, methods_stack=((<DictionaryAnalyzer>, 'которые', 1788, 19),)),
#   Parse(word='которые', tag=OpencorporaTag('ADJF,Apro,Subx,Anph inan,plur,accs'), normal_form='который', score=0.214285, methods_stack=((<DictionaryAnalyzer>, 'которые', 1788, 22),))],
#  [Parse(word='анализировали', tag=OpencorporaTag('VERB,impf,tran plur,past,indc'), normal_form='анализировать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'анализировали', 168, 10),))],
#  [Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,nomn'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 0),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,accs'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 3),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,loct'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 5),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 1),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 2),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 4),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,nomn'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 6),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 7),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 8),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,accs'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 9),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 10),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,loct'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 11),))],
#  [Parse(word='из', tag=OpencorporaTag('PREP'), normal_form='из', score=0.999661, methods_stack=((<DictionaryAnalyzer>, 'из', 375, 0),)),
#   Parse(word='из', tag=OpencorporaTag('NOUN,anim,femn,Name plur,gent'), normal_form='иза', score=0.000169, methods_stack=((<DictionaryAnalyzer>, 'из', 68, 8),)),
#   Parse(word='из', tag=OpencorporaTag('NOUN,anim,femn,Name plur,accs'), normal_form='иза', score=0.000169, methods_stack=((<DictionaryAnalyzer>, 'из', 68, 10),))],
#  [Parse(word='блога', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='блог', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'блога', 19, 1),))],
#  [Parse(word='студента', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='студент', score=0.6, methods_stack=((<DictionaryAnalyzer>, 'студента', 52, 1),)),
#   Parse(word='студента', tag=OpencorporaTag('NOUN,anim,masc sing,accs'), normal_form='студент', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'студента', 52, 3),))],
#  [Parse(word='высшей', tag=OpencorporaTag('ADJF,Supr,Qual femn,sing,gent'), normal_form='высокий', score=0.6, methods_stack=((<DictionaryAnalyzer>, 'высшей', 1086, 68),)),
#   Parse(word='высшей', tag=OpencorporaTag('ADJF,Supr,Qual femn,sing,loct'), normal_form='высокий', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'высшей', 1086, 73),)),
#   Parse(word='высшей', tag=OpencorporaTag('ADJF,Supr,Qual femn,sing,datv'), normal_form='высокий', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'высшей', 1086, 69),)),
#   Parse(word='высшей', tag=OpencorporaTag('ADJF,Supr,Qual femn,sing,ablt'), normal_form='высокий', score=0.1, methods_stack=((<DictionaryAnalyzer>, 'высшей', 1086, 71),))],
#  [Parse(word='школы', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='школа', score=0.970588, methods_stack=((<DictionaryAnalyzer>, 'школы', 55, 1),)),
#   Parse(word='школы', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='школа', score=0.014705, methods_stack=((<DictionaryAnalyzer>, 'школы', 55, 7),)),
#   Parse(word='школы', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='школа', score=0.014705, methods_stack=((<DictionaryAnalyzer>, 'школы', 55, 10),))],
#  [Parse(word='экономики', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='экономика', score=0.985185, methods_stack=((<DictionaryAnalyzer>, 'экономики', 43, 1),)),
#   Parse(word='экономики', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='экономика', score=0.007407, methods_stack=((<DictionaryAnalyzer>, 'экономики', 43, 7),)),
#   Parse(word='экономики', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='экономика', score=0.007407, methods_stack=((<DictionaryAnalyzer>, 'экономики', 43, 10),))],
#  [Parse(word='егора', tag=OpencorporaTag('NOUN,anim,masc,Name sing,gent'), normal_form='егор', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'егора', 26, 1),)),
#   Parse(word='егора', tag=OpencorporaTag('NOUN,anim,masc,Name sing,accs'), normal_form='егор', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'егора', 26, 3),))],
#  [Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 1),)),
#   Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,accs'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 3),)),
#   Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,nomn'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 6),))],
#  [Parse(word='обвиняемого', tag=OpencorporaTag('PRTF,Subx,impf,tran,pres,pssv neut,sing,gent'), normal_form='обвинять', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'обвиняемого', 2138, 82),)),
#   Parse(word='обвиняемого', tag=OpencorporaTag('PRTF,Subx,impf,tran,pres,pssv masc,sing,gent'), normal_form='обвинять', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'обвиняемого', 2138, 68),)),
#   Parse(word='обвиняемого', tag=OpencorporaTag('PRTF,Subx,impf,tran,pres,pssv anim,masc,sing,accs'), normal_form='обвинять', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'обвиняемого', 2138, 70),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='призывах', tag=OpencorporaTag('NOUN,inan,masc plur,loct'), normal_form='призыв', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'призывах', 33, 11),))],
#  [Parse(word='к', tag=OpencorporaTag('PREP'), normal_form='к', score=0.998113, methods_stack=((<DictionaryAnalyzer>, 'к', 375, 0),)),
#   Parse(word='к', tag=OpencorporaTag('ADVB,Ques Abbr'), normal_form='как', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1674, 1),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 12),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 13),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 14),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 15),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 16),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 17),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 18),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 19),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 20),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 21),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 22),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 23),))],
#  [Parse(word='экстремизму', tag=OpencorporaTag('NOUN,inan,masc sing,datv'), normal_form='экстремизм', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'экстремизму', 33, 2),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='интернете', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='интернет', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'интернете', 33, 5),))],
#  [Parse(word='часть', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='часть', score=0.6, methods_stack=((<DictionaryAnalyzer>, 'часть', 3025, 0),)),
#   Parse(word='часть', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='часть', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'часть', 3025, 3),))],
#  [Parse(word='2', tag=OpencorporaTag('NUMB,intg'), normal_form='2', score=1.0, methods_stack=((<NumberAnalyzer>, '2'),))],
#  [Parse(word='статьи', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='статья', score=0.995283, methods_stack=((<DictionaryAnalyzer>, 'статьи', 315, 1),)),
#   Parse(word='статьи', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='статья', score=0.002358, methods_stack=((<DictionaryAnalyzer>, 'статьи', 315, 7),)),
#   Parse(word='статьи', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='статья', score=0.002358, methods_stack=((<DictionaryAnalyzer>, 'статьи', 315, 10),))],
#  [Parse(word='280', tag=OpencorporaTag('NUMB,intg'), normal_form='280', score=1.0, methods_stack=((<NumberAnalyzer>, '280'),))],
#  [Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 19, 0),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 19, 3),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 0),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 1),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 2),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 3),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 4),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 5),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 6),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 7),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 8),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 9),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 10),)),
#   Parse(word='ук', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='ук', score=0.07142857142857142, methods_stack=((<DictionaryAnalyzer>, 'ук', 332, 11),))],
#  [Parse(word='эксперты', tag=OpencorporaTag('NOUN,anim,masc plur,nomn'), normal_form='эксперт', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'эксперты', 52, 6),))],
#  [Parse(word='нашли', tag=OpencorporaTag('VERB,perf,tran plur,past,indc'), normal_form='найти', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'нашли', 2013, 4),)),
#   Parse(word='нашли', tag=OpencorporaTag('VERB,perf,tran sing,impr,excl'), normal_form='наслать', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'нашли', 1331, 13),))],
#  [Parse(word='экстремизм', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='экстремизм', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'экстремизм', 33, 3),)),
#   Parse(word='экстремизм', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='экстремизм', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'экстремизм', 33, 0),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='четырёх', tag=OpencorporaTag('NUMR gent'), normal_form='четыре', score=0.678571, methods_stack=((<DictionaryAnalyzer>, 'четырёх', 3036, 1),)),
#   Parse(word='четырёх', tag=OpencorporaTag('NUMR anim,accs'), normal_form='четыре', score=0.214285, methods_stack=((<DictionaryAnalyzer>, 'четырёх', 3036, 4),)),
#   Parse(word='четырёх', tag=OpencorporaTag('NUMR loct'), normal_form='четыре', score=0.107142, methods_stack=((<DictionaryAnalyzer>, 'четырёх', 3036, 6),))],
#  [Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,nomn'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 0),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,accs'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 3),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,loct'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 5),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 1),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 2),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 4),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,nomn'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 6),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 7),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 8),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,accs'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 9),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 10),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,loct'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 11),))],
#  [Parse(word='на', tag=OpencorporaTag('PREP'), normal_form='на', score=0.99931, methods_stack=((<DictionaryAnalyzer>, 'на', 24, 0),)),
#   Parse(word='на', tag=OpencorporaTag('PRCL'), normal_form='на', score=0.000477, methods_stack=((<DictionaryAnalyzer>, 'на', 22, 0),)),
#   Parse(word='на', tag=OpencorporaTag('INTJ'), normal_form='на', score=0.000212, methods_stack=((<DictionaryAnalyzer>, 'на', 21, 0),))],
#  [Parse(word='youtube', tag=OpencorporaTag('LATN'), normal_form='youtube', score=1.0, methods_stack=((<LatinAnalyzer>, 'youtube'),))],
#  [Parse(word='канале', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='канал', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'канале', 33, 5),))],
#  [Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,gent'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 1),)),
#   Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,accs'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 3),)),
#   Parse(word='жукова', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Surn sing,nomn'), normal_form='жуков', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'жукова', 36, 6),))],
#  [Parse(word='по', tag=OpencorporaTag('PREP'), normal_form='по', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'по', 24, 0),))],
#  [Parse(word='их', tag=OpencorporaTag('NPRO,3per,Anph plur,gent'), normal_form='они', score=0.111111, methods_stack=((<DictionaryAnalyzer>, 'их', 2210, 1),)),
#   Parse(word='их', tag=OpencorporaTag('NPRO,3per,Anph plur,accs'), normal_form='они', score=0.111111, methods_stack=((<DictionaryAnalyzer>, 'их', 2210, 5),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,nomn'), normal_form='их', score=0.083333, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 6),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,accs'), normal_form='их', score=0.055555, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 15),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,nomn'), normal_form='их', score=0.055555, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 18),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,nomn'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 0),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,gent'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 1),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,datv'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 2),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,accs'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 3),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,ablt'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 4),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,loct'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 5),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,gent'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 7),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,datv'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 8),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,accs'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 9),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,ablt'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 10),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,loct'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 11),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,nomn'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 12),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,gent'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 13),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,datv'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 14),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,ablt'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 16),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,loct'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 17),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,gent'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 19),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,datv'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 20),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,accs'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 21),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,ablt'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 22),)),
#   Parse(word='их', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,loct'), normal_form='их', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'их', 1377, 23),))],
#  [Parse(word='мнению', tag=OpencorporaTag('NOUN,inan,neut sing,datv'), normal_form='мнение', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'мнению', 76, 4),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,nomn'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 0),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,accs'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 3),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,loct'), normal_form='видео', score=0.133333, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 5),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 1),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 2),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd sing,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 4),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,nomn'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 6),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,gent'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 7),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,datv'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 8),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,accs'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 9),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,ablt'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 10),)),
#   Parse(word='видео', tag=OpencorporaTag('NOUN,inan,neut,Fixd plur,loct'), normal_form='видео', score=0.066666, methods_stack=((<DictionaryAnalyzer>, 'видео', 23, 11),))],
#  [Parse(word='отчётливо', tag=OpencorporaTag('ADVB'), normal_form='отчётливо', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'отчётливо', 3, 0),)),
#   Parse(word='отчётливо', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='отчётливый', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'отчётливо', 4, 29),))],
#  [Parse(word='прослеживается', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='прослеживаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'прослеживается', 224, 5),))],
#  [Parse(word='мотив', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='мотив', score=0.8, methods_stack=((<DictionaryAnalyzer>, 'мотив', 33, 0),)),
#   Parse(word='мотив', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='мотив', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'мотив', 33, 3),))],
#  [Parse(word='политической', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='политический', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'политической', 16, 8),)),
#   Parse(word='политической', tag=OpencorporaTag('ADJF femn,sing,loct'), normal_form='политический', score=0.40909, methods_stack=((<DictionaryAnalyzer>, 'политической', 16, 13),)),
#   Parse(word='политической', tag=OpencorporaTag('ADJF femn,sing,datv'), normal_form='политический', score=0.045454, methods_stack=((<DictionaryAnalyzer>, 'политической', 16, 9),)),
#   Parse(word='политической', tag=OpencorporaTag('ADJF femn,sing,ablt'), normal_form='политический', score=0.045454, methods_stack=((<DictionaryAnalyzer>, 'политической', 16, 11),))],
#  [Parse(word='ненависти', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='ненависть', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'ненависти', 13, 1),)),
#   Parse(word='ненависти', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='ненависть', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'ненависти', 13, 2),)),
#   Parse(word='ненависти', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='ненависть', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'ненависти', 13, 5),)),
#   Parse(word='ненависти', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='ненависть', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'ненависти', 13, 6),)),
#   Parse(word='ненависти', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='ненависть', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'ненависти', 13, 9),))],
#  [Parse(word='или', tag=OpencorporaTag('CONJ'), normal_form='или', score=0.978723, methods_stack=((<DictionaryAnalyzer>, 'или', 20, 0),)),
#   Parse(word='или', tag=OpencorporaTag('PRCL'), normal_form='или', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'или', 22, 0),))],
#  [Parse(word='вражды', tag=OpencorporaTag('NOUN,inan,femn,Sgtm sing,gent'), normal_form='вражда', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'вражды', 29, 1),))],
#  [Parse(word='к', tag=OpencorporaTag('PREP'), normal_form='к', score=0.998113, methods_stack=((<DictionaryAnalyzer>, 'к', 375, 0),)),
#   Parse(word='к', tag=OpencorporaTag('ADVB,Ques Abbr'), normal_form='как', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1674, 1),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 12),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 13),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 14),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 15),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 16),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 17),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 18),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 19),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 20),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 21),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 22),)),
#   Parse(word='к', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='кандидат', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'к', 1685, 23),))],
#  [Parse(word='действующей', tag=OpencorporaTag('ADJF femn,sing,gent'), normal_form='действующий', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 162, 8),)),
#   Parse(word='действующей', tag=OpencorporaTag('ADJF femn,sing,datv'), normal_form='действующий', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 162, 9),)),
#   Parse(word='действующей', tag=OpencorporaTag('ADJF femn,sing,ablt'), normal_form='действующий', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 162, 11),)),
#   Parse(word='действующей', tag=OpencorporaTag('ADJF femn,sing,loct'), normal_form='действующий', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 162, 13),)),
#   Parse(word='действующей', tag=OpencorporaTag('COMP V-ej'), normal_form='действующий', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 162, 32),)),
#   Parse(word='действующей', tag=OpencorporaTag('PRTF,impf,intr,pres,actv femn,sing,gent'), normal_form='действовать', score=0.1111111111111111, methods_stack=((<DictionaryAnalyzer>, 'действующей', 172, 21),)),
# ...
#   Parse(word='наши', tag=OpencorporaTag('ADJF,Apro inan,plur,accs'), normal_form='наш', score=0.428571, methods_stack=((<DictionaryAnalyzer>, 'наши', 2047, 22),))],
#  [Parse(word='авторы', tag=OpencorporaTag('NOUN,anim,masc plur,nomn'), normal_form='автор', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'авторы', 52, 6),))],
#  [Parse(word='делятся', tag=OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'), normal_form='делиться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'делятся', 312, 6),))],
#  [Parse(word='своими', tag=OpencorporaTag('ADJF,Apro,Anph plur,ablt'), normal_form='свой', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'своими', 2737, 25),))],
#  [Parse(word='впечатлениями', tag=OpencorporaTag('NOUN,inan,neut plur,ablt'), normal_form='впечатление', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'впечатлениями', 76, 20),))],
#  [Parse(word='от', tag=OpencorporaTag('PREP'), normal_form='от', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'от', 375, 0),))],
#  [Parse(word='главных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='главный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'главных', 214, 21),)),
#   Parse(word='главных', tag=OpencorporaTag('NOUN,inan,neut plur,gent'), normal_form='главное', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'главных', 972, 7),)),
#   Parse(word='главных', tag=OpencorporaTag('NOUN,inan,neut plur,loct'), normal_form='главное', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'главных', 972, 11),)),
#   Parse(word='главных', tag=OpencorporaTag('ADJF,Qual anim,plur,accs'), normal_form='главный', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'главных', 214, 23),)),
#   Parse(word='главных', tag=OpencorporaTag('ADJF,Qual plur,loct'), normal_form='главный', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'главных', 214, 26),))],
#  [Parse(word='событий', tag=OpencorporaTag('NOUN,inan,neut plur,gent'), normal_form='событие', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'событий', 76, 15),))],
#  [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#   Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)),
#   Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))],
#  [Parse(word='текстов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='текст', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'текстов', 33, 7),))],
#  [Parse(word='последнее', tag=OpencorporaTag('ADJF neut,sing,nomn'), normal_form='последний', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'последнее', 382, 14),)),
#   Parse(word='последнее', tag=OpencorporaTag('ADJF neut,sing,accs'), normal_form='последний', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'последнее', 382, 17),)),
#   Parse(word='последнее', tag=OpencorporaTag('COMP'), normal_form='последний', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'последнее', 382, 30),))],
#  [Parse(word='слово', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='слово', score=0.615384, methods_stack=((<DictionaryAnalyzer>, 'слово', 54, 0),)),
#   Parse(word='слово', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='слово', score=0.384615, methods_stack=((<DictionaryAnalyzer>, 'слово', 54, 3),))],
#  [Parse(word='участие', tag=OpencorporaTag('NOUN,inan,neut sing,accs'), normal_form='участие', score=0.890909, methods_stack=((<DictionaryAnalyzer>, 'участие', 76, 6),)),
#   Parse(word='участие', tag=OpencorporaTag('NOUN,inan,neut sing,nomn'), normal_form='участие', score=0.10909, methods_stack=((<DictionaryAnalyzer>, 'участие', 76, 0),))],
#  [Parse(word='подсудимого', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='подсудимый', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'подсудимого', 218, 1),)),
#   Parse(word='подсудимого', tag=OpencorporaTag('NOUN,anim,masc sing,accs'), normal_form='подсудимый', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'подсудимого', 218, 3),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='акции', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='акция', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'акции', 40, 1),)),
#   Parse(word='акции', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='акция', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'акции', 40, 6),)),
#   Parse(word='акции', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='акция', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'акции', 40, 2),)),
#   Parse(word='акции', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='акция', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'акции', 40, 7),)),
#   Parse(word='акции', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='акция', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'акции', 40, 10),))],
#  [Parse(word='доказывали', tag=OpencorporaTag('VERB,impf,tran plur,past,indc'), normal_form='доказывать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'доказывали', 206, 10),))],
#  [Parse(word='решением', tag=OpencorporaTag('NOUN,inan,neut sing,ablt'), normal_form='решение', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'решением', 76, 8),))],
#  [Parse(word='суда', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='суд', score=0.99363, methods_stack=((<DictionaryAnalyzer>, 'суда', 33, 1),)),
#   Parse(word='суда', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='судно', score=0.003184, methods_stack=((<DictionaryAnalyzer>, 'суда', 2849, 6),)),
#   Parse(word='суда', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='судно', score=0.003184, methods_stack=((<DictionaryAnalyzer>, 'суда', 2849, 9),))],
#  [Parse(word='по', tag=OpencorporaTag('PREP'), normal_form='по', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'по', 24, 0),))],
#  [Parse(word='протоколу', tag=OpencorporaTag('NOUN,inan,masc sing,datv'), normal_form='протокол', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'протоколу', 33, 2),))],
#  [Parse(word='который', tag=OpencorporaTag('ADJF,Apro,Subx,Anph masc,sing,nomn'), normal_form='который', score=0.823529, methods_stack=((<DictionaryAnalyzer>, 'который', 1788, 0),)),
#   Parse(word='который', tag=OpencorporaTag('ADJF,Apro,Subx,Anph inan,masc,sing,accs'), normal_form='который', score=0.17647, methods_stack=((<DictionaryAnalyzer>, 'который', 1788, 3),))],
#  [Parse(word='был', tag=OpencorporaTag('VERB,impf,intr masc,sing,past,indc'), normal_form='быть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'был', 587, 4),))],
#  [Parse(word='одинаковым', tag=OpencorporaTag('ADJF,Qual masc,sing,ablt'), normal_form='одинаковый', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'одинаковым', 4, 5),)),
#   Parse(word='одинаковым', tag=OpencorporaTag('ADJF,Qual neut,sing,ablt'), normal_form='одинаковый', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'одинаковым', 4, 18),)),
#   Parse(word='одинаковым', tag=OpencorporaTag('ADJF,Qual plur,datv'), normal_form='одинаковый', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'одинаковым', 4, 22),))],
#  [Parse(word='для', tag=OpencorporaTag('PREP'), normal_form='для', score=0.99984, methods_stack=((<DictionaryAnalyzer>, 'для', 24, 0),)),
#   Parse(word='для', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='длить', score=0.00016, methods_stack=((<DictionaryAnalyzer>, 'для', 463, 94),))],
#  [Parse(word='десятков', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='десяток', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'десятков', 139, 7),))],
#  [Parse(word='задержанных', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,gent'), normal_form='задержать', score=0.714285, methods_stack=((<DictionaryAnalyzer>, 'задержанных', 845, 63),)),
#   Parse(word='задержанных', tag=OpencorporaTag('PRTF,perf,tran,past,pssv anim,plur,accs'), normal_form='задержать', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'задержанных', 845, 65),)),
#   Parse(word='задержанных', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,loct'), normal_form='задержать', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'задержанных', 845, 68),))],
#  [Parse(word='мосгорсуд', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='мосгорсуд', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'мосгорсуд', 33, 0),)),
#   Parse(word='мосгорсуд', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='мосгорсуд', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'мосгорсуд', 33, 3),))],
#  [Parse(word='оставил', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='оставить', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'оставил', 753, 1),))],
#  [Parse(word='приговор', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='приговор', score=0.571428, methods_stack=((<DictionaryAnalyzer>, 'приговор', 33, 3),)),
#   Parse(word='приговор', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='приговор', score=0.428571, methods_stack=((<DictionaryAnalyzer>, 'приговор', 33, 0),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word='силе', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='сила', score=0.588235, methods_stack=((<DictionaryAnalyzer>, 'силе', 55, 2),)),
#   Parse(word='силе', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='сила', score=0.352941, methods_stack=((<DictionaryAnalyzer>, 'силе', 55, 6),)),
#   Parse(word='силе', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='сило', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'силе', 107, 5),))]]

# %%
mystemmed = mystem.lemmatize(text2)
mystemmed
# Out:
# ['\u200b«',
#  'новый',
#  ' ',
#  'газета',
#  '» ',
#  'опубликовывать',
#  ' ',
#  'сокращать',
#  ' ',
#  'вариант',
#  ' ',
#  'заключение',
#  ' ',
#  'эксперт',
#  ' ',
#  'александр',
#  ' ',
#  'коршиков',
#  ' ',
#  'и',
#  ' ',
#  'анна',
#  ' ',
#  'осокина',
#  ', ',
#  'который',
#  ' ',
#  'анализировать',
#  ' ',
#  'видео',
#  ' ',
#  'из',
#  ' ',
#  'блог',
#  ' ',
#  'студент',
#  ' ',
#  'высокий',
#  ' ',
#  'школа',
#  ' ',
#  'экономика',
#  ' ',
#  'егор',
#  ' ',
#  'жуков',
#  ', ',
#  'обвиняемый',
#  ' ',
#  'в',
#  ' ',
#  'призыв',
#  ' ',
#  'к',
#  ' ',
#  'экстремизм',
#  ' ',
#  'в',
#  ' ',
#  'интернет',
#  ' (',
#  'часть',
#  ' ',
#  '2',
#  ' ',
#  'статья',
#  ' ',
#  '280',
#  ' ',
#  'ук',
#  ')',
#  '.  ',
#  'эксперт',
#  ' ',
#  'находить',
#  ' ',
#  'экстремизм',
#  ' ',
#  'в',
#  ' ',
#  'четыре',
#  ' ',
#  'видео',
#  ' ',
#  'на',
#  ' ',
#  'YouTube',
#  '-',
#  'канал',
#  ' ',
#  'жуков',
#  '. ',
#  'по',
#  ' ',
#  'их',
#  ' ',
#  'мнение',
#  ', ',
#  'в',
#  ' ',
#  'видео',
#  ' «',
#  'отчетливо',
#  ' ',
#  'прослеживаться',
#  ' ',
#  'мотив',
#  ' ',
#  'политический',
#  ' ',
#  'ненависть',
#  ' ',
#  'или',
#  ' ',
#  'вражда',
#  ' ',
#  'к',
#  ' ',
#  'действующий',
#  ' ',
#  'власть',
#  '»',
#  '.  ',
#  'в',
#  ' ',
#  'заключение',
#  ' ',
#  'говориться',
#  ', ',
#  'что',
#  ' ',
#  'жуков',
#  ' ',
#  'приписывать',
#  ' ',
#  'действующий',
#  ' ',
#  'власть',
#  ' «',
#  'враждебный',
#  ' ',
#  'действие',
#  '», ',
#  'называть',
#  ' ',
#  'ее',
#  ' ',
#  'враг',
#  ', ',
#  'источник',
#  ' ',
#  'зло',
#  ' ',
#  'и',
#  ' ',
#  'вред',
#  '. ',
#  'кроме',
#  ' ',
#  'то',
#  ', ',
#  'студент',
#  ' ',
#  'призывать',
#  ' ',
#  'с',
#  ' ',
#  'этот',
#  ' ',
#  'власть',
#  ' ',
#  'бороться',
#  '.  ',
#  '«',
#  'автор',
#  ' ',
#  'описывать',
#  ' ',
#  'катастрофический',
#  ' ',
#  'положение',
#  ' ',
#  'население',
#  ' ',
#  'в',
#  ' ',
#  'россия',
#  ', ',
#  'как',
#  ' ',
#  'следствие',
#  ' ',
#  'целенаправленный',
#  ' ',
#  'политика',
#  ' ',
#  'действовать',
#  ' ',
#  'власть',
#  ' <',
#  '...>. ',
#  'основной',
#  ' ',
#  'идеал',
#  ', ',
#  'который',
#  ' ',
#  'следовать',
#  ' ',
#  'достигать',
#  ', ',
#  'являться',
#  ' "',
#  'смена',
#  ' ',
#  'власть',
#  ' ',
#  'в',
#  ' ',
#  'россия',
#  '" ',
#  'для',
#  ' ',
#  'то',
#  ', ',
#  'чтобы',
#  ' "',
#  'россия',
#  ' ',
#  'становиться',
#  ' ',
#  'свободный',
#  '"», — ',
#  'цитировать',
#  ' ',
#  'издание',
#  ' ',
#  'эксперт',
#  '. ',
#  'в',
#  ' ',
#  'один',
#  ' ',
#  'из',
#  ' ',
#  'видео',
#  ', ',
#  'в',
#  ' ',
#  'который',
#  ' ',
#  'жуков',
#  ' ',
#  'размышлять',
#  ' ',
#  'об',
#  ' ',
#  'итог',
#  ' ',
#  'митинг',
#  ' ',
#  '7',
#  ' ',
#  'октябрь',
#  ' ',
#  '2017',
#  ' ',
#  'год',
#  ', ',
#  'эксперт',
#  ' ',
#  'увидеть',
#  ' ',
#  'призыв',
#  ' ',
#  'бороться',
#  ' ',
#  'любой',
#  ' ',
#  'способ',
#  ', «',
#  'что',
#  ' ',
#  'включать',
#  ' ',
#  'в',
#  ' ',
#  'себя',
#  ' ',
#  'и',
#  ' ',
#  'действие',
#  ' ',
#  'насильственный',
#  ' ',
#  'характер',
#  ', ',
#  'в',
#  ' ',
#  'частность',
#  ', ',
#  'насильственный',
#  ' ',
#  'захват',
#  ' ',
#  'власть',
#  ', ',
#  'вооруженный',
#  ' ',
#  'мятеж',
#  '»',
#  '.  ',
#  'егор',
#  ' ',
#  'жуков',
#  ' — ',
#  'фигурант',
#  ' «',
#  'московский',
#  ' ',
#  'дело',
#  '»',
#  '. ',
#  'сначала',
#  ' ',
#  'он',
#  ' ',
#  'обвинять',
#  ' ',
#  'в',
#  ' ',
#  'участие',
#  ' ',
#  'в',
#  ' ',
#  'массовый',
#  ' ',
#  'беспорядок',
#  ' (',
#  'часть',
#  ' ',
#  '2',
#  ' ',
#  'статья',
#  ' ',
#  '212',
#  ' ',
#  'ук',
#  ')',
#  '. ',
#  'в',
#  ' ',
#  'суд',
#  ' ',
#  'говорить',
#  ', ',
#  'что',
#  ' ',
#  'среди',
#  ' ',
#  'материал',
#  ' ',
#  'быть',
#  ' ',
#  'видео',
#  ', ',
#  'где',
#  ' ',
#  'жуков',
#  ' ',
#  'показывать',
#  ' ',
#  'кто-то',
#  ' ',
#  'направо',
#  ' ',
#  'на',
#  ' ',
#  'акция',
#  ' ',
#  '27',
#  ' ',
#  'июль',
#  '. ',
#  'из-за',
#  ' ',
#  'этот',
#  ' ',
#  'студент',
#  ' ',
#  '2',
#  ' ',
#  'август',
#  ' ',
#  'отправлять',
#  ' ',
#  'в',
#  ' ',
#  'сизо',
#  '.  ',
#  'однако',
#  ' ',
#  'через',
#  ' ',
#  'месяц',
#  ' ',
#  'дело',
#  ' ',
#  'о',
#  ' ',
#  'массовый',
#  ' ',
#  'беспорядок',
#  ' ',
#  'против',
#  ' ',
#  'жуков',
#  ' ',
#  'закрывать',
#  ', ',
#  'он',
#  ' ',
#  'предъявлять',
#  ' ',
#  'новый',
#  ' ',
#  'обвинение',
#  ' ',
#  'в',
#  ' ',
#  'призыв',
#  ' ',
#  'к',
#  ' ',
#  'экстремизм',
#  '. ',
#  'по',
#  ' ',
#  'ходатайство',
#  ' ',
#  'следствие',
#  ' ',
#  'суд',
#  ' ',
#  'переводить',
#  ' ',
#  'студент',
#  ' ',
#  'под',
#  ' ',
#  'домашний',
#  ' ',
#  'арест',
#  '.  ',
#  'читать',
#  ' ',
#  'также',
#  ' ',
#  'раз',
#  ' ',
#  'в',
#  ' ',
#  'неделя',
#  ' ',
#  'наш',
#  ' ',
#  'автор',
#  ' ',
#  'делиться',
#  ' ',
#  'свой',
#  ' ',
#  'впечатление',
#  ' ',
#  'от',
#  ' ',
#  'главный',
#  ' ',
#  'событие',
#  ' ',
#  'и',
#  ' ',
#  'текст',
#  ' ',
#  'история',
#  ' ',
#  'три',
#  ' ',
#  'петербурженка',
#  ', ',
#  'который',
#  ' ',
#  'год',
#  ' ',
#  'бороться',
#  ' ',
#  'с',
#  ' ',
#  'бес',
#  ' ',
#  'раз',
#  ' ',
#  'в',
#  ' ',
#  'неделя',
#  ' ',
#  'наш',
#  ' ',
#  'автор',
#  ' ',
#  'делиться',
#  ' ',
#  'свой',
#  ' ',
#  'впечатление',
#  ' ',
#  'от',
#  ' ',
#  'главный',
#  ' ',
#  'событие',
#  ' ',
#  'и',
#  ' ',
#  'текст',
#  '  ',
#  'последний',
#  ' ',
#  'слово',
#  ' ',
#  'участие',
#  ' ',
#  'подсудимый',
#  ' ',
#  'в',
#  ' ',
#  'акция',
#  ' ',
#  'доказывать',
#  ' ',
#  'решение',
#  ' ',
#  'суд',
#  ' ',
#  'по',
#  ' ',
#  'протокол',
#  ', ',
#  'который',
#  ' ',
#  'быть',
#  ' ',
#  'одинаковый',
#  ' ',
#  'для',
#  ' ',
#  'десяток',
#  ' ',
#  'задержанный',
#  ' ',
#  'мосгорсуд',
#  ' ',
#  'оставлять',
#  ' ',
#  'приговор',
#  ' ',
#  'в',
#  ' ',
#  'сила',
#  ' \n']

# %% [markdown]
# 1) Что лучше разбивает на предложения (mystem или sent_tokenize)?
#
# sent_tokenize, так как mystem не разбивает на предложения, а sent_tokenize — да.
#
# 2) Что лучше токенизирует (mystem или ваша регулярка)? Если mystem, то можно ли улучшить регулярное выражение так, чтобы качество было выше?
#
#
#
# 3) Что лучше для лемматизации mystem или pymorphy?
#
# на тексте-примере лучше справился pymorphy – у него не было проблем с фамилиями, он перевел youtube в нижний регистр, в отличие от mystem, а также содержал меньше ошибок в определении видов глаголов. возможно, на более крупном тексте было бы проще определить, что лемматизирует лучше.

# %%
dir(mystem)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analyze_impl',
#  '_disambiguation',
#  '_entire_input',
#  '_get_lemma',
#  '_grammar_info',
#  '_mystem_bin',
#  '_mystemargs',
#  '_proc',
#  '_procin',
#  '_procout',
#  '_procout_no',
#  '_start_mystem',
#  '_weight',
#  'analyze',
#  'close',
#  'lemmatize',
#  'start']

# %%
dir(morph)
# Out:
# ['DEFAULT_UNITS',
#  'ENV_VARIABLE',
#  'TagClass',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_inflect',
#  '_init_units',
#  '_result_type',
#  '_result_type_orig',
#  '_unit_classes',
#  '_units',
#  'choose_dictionary_path',
#  'cyr2lat',
#  'dictionary',
#  'get_lexeme',
#  'iter_known_word_parses',
#  'lat2cyr',
#  'normal_forms',
#  'parse',
#  'prob_estimator',
#  'tag',
#  'word_is_known']

# %%
lemmas = []
for i in range(len(clean_tokens)):
    for j in range(len(clean_tokens[i])):
        lemmas.append(morph.parse(clean_tokens[i][j])[0].normal_form)
lemmas
# Out:
# ['новый',
#  'газета',
#  'опубликовать',
#  'сократить',
#  'вариант',
#  'заключение',
#  'эксперт',
#  'александр',
#  'коршикова',
#  'и',
#  'анна',
#  'осокин',
#  'который',
#  'анализировать',
#  'видео',
#  'из',
#  'блог',
#  'студент',
#  'высокий',
#  'школа',
#  'экономика',
#  'егор',
#  'жуков',
#  'обвинять',
#  'в',
#  'призыв',
#  'к',
#  'экстремизм',
#  'в',
#  'интернет',
#  'часть',
#  '2',
#  'статья',
#  '280',
#  'ук',
#  'эксперт',
#  'найти',
#  'экстремизм',
#  'в',
#  'четыре',
#  'видео',
#  'на',
#  'youtube',
#  'канал',
#  'жуков',
#  'по',
#  'они',
#  'мнение',
#  'в',
#  'видео',
#  'отчётливо',
#  'прослеживаться',
#  'мотив',
#  'политический',
#  'ненависть',
#  'или',
#  'вражда',
#  'к',
#  'действующий',
#  'власть',
#  'в',
#  'заключение',
#  'говориться',
#  'что',
#  'жуков',
#  'приписывать',
#  'действующий',
#  'власть',
#  'враждебный',
#  'действие',
#  'называть',
#  'она',
#  'враг',
#  'источник',
#  'зло',
#  'и',
#  'вред',
#  'кроме',
#  'тот',
#  'студент',
#  'призывать',
#  'с',
#  'этот',
#  'власть',
#  'бороться',
#  'автор',
#  'описывать',
#  'катастрофический',
#  'положение',
#  'население',
#  'в',
#  'россия',
#  'как',
#  'следствие',
#  'целенаправленный',
#  'политика',
#  'действующий',
#  'власть',
#  'основный',
#  'идеал',
#  'который',
#  'следовать',
#  'достигнуть',
#  'являться',
#  'смена',
#  'власть',
#  'в',
#  'россия',
#  'для',
#  'тот',
#  'чтобы',
#  'россия',
#  'стать',
#  'свободный',
#  'цитировать',
#  'издание',
#  'эксперт',
#  'в',
#  'один',
#  'из',
#  'видео',
#  'в',
#  'который',
#  'жуков',
#  'размышлять',
#  'о',
#  'итог',
#  'митинг',
#  '7',
#  'октябрь',
#  '2017',
#  'год',
#  'эксперт',
#  'увидеть',
#  'призыв',
#  'бороться',
#  'любой',
#  'способ',
#  'что',
#  'включать',
#  'в',
#  'себя',
#  'и',
#  'действие',
#  'насильственный',
#  'характер',
#  'в',
#  'частность',
#  'насильственный',
#  'захват',
#  'власть',
#  'вооружённый',
#  'мятеж',
#  'егор',
#  'жуков',
#  'фигурант',
#  'московский',
#  'дело',
#  'сначала',
#  'он',
#  'обвинять',
#  'в',
#  'участие',
#  'в',
#  'массовый',
#  'беспорядок',
#  'часть',
#  '2',
#  'статья',
#  '212',
#  'ук',
#  'в',
#  'суд',
#  'говорить',
#  'что',
#  'среди',
#  'материал',
#  'есть',
#  'видео',
#  'где',
#  'жуков',
#  'показывать',
#  'кома',
#  'то',
#  'направо',
#  'на',
#  'акция',
#  '27',
#  'июль',
#  'из',
#  'за',
#  'это',
#  'студент',
#  '2',
#  'август',
#  'отправить',
#  'в',
#  'сизый',
#  'однако',
#  'через',
#  'месяц',
#  'дело',
#  'о',
#  'массовый',
#  'беспорядок',
#  'против',
#  'жуков',
#  'закрыть',
#  'он',
#  'предъявить',
#  'новое',
#  'обвинение',
#  'в',
#  'призыв',
#  'к',
#  'экстремизм',
#  'по',
#  'ходатайство',
#  'следствие',
#  'суд',
#  'перевести',
#  'студент',
#  'под',
#  'домашний',
#  'арест',
#  'читать',
#  'также',
#  'раз',
#  'в',
#  'неделя',
#  'наш',
#  'автор',
#  'делиться',
#  'свой',
#  'впечатление',
#  'от',
#  'главный',
#  'событие',
#  'и',
#  'текст',
#  'история',
#  'три',
#  'петербурженка',
#  'который',
#  'годами',
#  'бороться',
#  'с',
#  'бес',
#  'раз',
#  'в',
#  'неделя',
#  'наш',
#  'автор',
#  'делиться',
#  'свой',
#  'впечатление',
#  'от',
#  'главный',
#  'событие',
#  'и',
#  'текст',
#  'последний',
#  'слово',
#  'участие',
#  'подсудимый',
#  'в',
#  'акция',
#  'доказывать',
#  'решение',
#  'суд',
#  'по',
#  'протокол',
#  'который',
#  'быть',
#  'одинаковый',
#  'для',
#  'десяток',
#  'задержать',
#  'мосгорсуд',
#  'оставить',
#  'приговор',
#  'в',
#  'сила']
