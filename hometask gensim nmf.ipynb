# %%
import pymorphy2
import re
import string
import gensim
import pandas as pd
from pymorphy2 import MorphAnalyzer
from collections import Counter
from nltk.corpus import stopwords
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
morph = MorphAnalyzer()

# %%
stops = set(stopwords.words('russian')) | {'gt', 'int', 'if', 'x', 'to', 'in', 'return', 'case', 'i', '•', 
                                          'null', 'set', 'as', 'from', 'var', 'lt', 'on', 'is', 'end', 'b',
                                          'else', 'bool', 'const', 'function', 'class', 'string', 'import',
                                          'then', 'type', 'person', 'select', 'def', 'up', 'down', 'active',
                                          'print', 'assert', 'j', 'str', 'loop', 'char', 'unsigned', 'true',
                                          'main', 'func'}

# %%
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %%
texts = open('/Users/macbookpro/Downloads/habr.txt').read().splitlines()

# %%
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)

# %%
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.7) # threshold можно подбирать

# %%
p = gensim.models.phrases.Phraser(ph)

# %%
ngrammed_texts = p[texts]

# %%
words = gensim.corpora.Dictionary(texts)

# %%
words.filter_extremes(no_above=0.15, no_below=22)
words.compactify()

# %%
print(words)
# Out:
# Dictionary(6770 unique tokens: ['2-х', '3.0', 'address', 'api', 'architecture']...)

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=words)

# %%
corpus = tfidf[corpus]

# %%
corpus = [words.doc2bow(text) for text in texts]

# %%
lda = gensim.models.LdaMulticore(corpus, 100, id2word=words, eval_every=0)

# %%
lda.print_topics()
# Out:
# [(41,
#   '0.007*"google" + 0.004*"изображение" + 0.003*"карта" + 0.003*"android" + 0.003*"игрок" + 0.003*"переменный" + 0.003*"глаз" + 0.002*"вирус" + 0.002*"microsoft" + 0.002*"письмо"'),
#  (81,
#   '0.004*"игра" + 0.004*"обучение" + 0.003*"модуль" + 0.003*"new" + 0.003*"диск" + 0.002*"qt" + 0.002*"контейнер" + 0.002*"counter" + 0.002*"частота" + 0.002*"битый"'),
#  (85,
#   '0.006*"000" + 0.003*"модуль" + 0.003*"пакет" + 0.003*"рубль" + 0.003*"метка" + 0.002*"виртуальный" + 0.002*"свет" + 0.002*"вызов" + 0.002*"цвета" + 0.002*"кнопка"'),
#  (53,
#   '0.004*"переменный" + 0.004*"датчик" + 0.003*"частота" + 0.003*"id" + 0.003*"сигнал" + 0.002*"тест" + 0.002*"звук" + 0.002*"компонент" + 0.002*"игра" + 0.002*"кнопка"'),
#  (4,
#   '0.004*"нейрон" + 0.003*"public" + 0.003*"бизнес" + 0.003*"value" + 0.003*"сотрудник" + 0.003*"false" + 0.003*"new" + 0.003*"сигнал" + 0.003*"обучение" + 0.003*"виртуальный"'),
#  (83,
#   '0.006*"игра" + 0.003*"google" + 0.003*"игрок" + 0.002*"учёный" + 0.002*"канал" + 0.002*"public" + 0.002*"уязвимость" + 0.002*"сигнал" + 0.002*"кнопка" + 0.002*"ребёнок"'),
#  (21,
#   '0.011*"игра" + 0.007*"days" + 0.003*"участник" + 0.002*"программист" + 0.002*"телефон" + 0.002*"go" + 0.002*"карта" + 0.002*"выступление" + 0.002*"магазин" + 0.002*"программирование"'),
#  (98,
#   '0.004*"массив" + 0.004*"символ" + 0.003*"пакет" + 0.003*"домен" + 0.002*"блок" + 0.002*"номер" + 0.002*"письмо" + 0.002*"мозг" + 0.002*"вызов" + 0.002*"переменный"'),
#  (67,
#   '0.004*"игра" + 0.003*"изображение" + 0.003*"git" + 0.003*"блок" + 0.003*"api" + 0.003*"begin" + 0.002*"документ" + 0.002*"домен" + 0.002*"браузер" + 0.002*"property"'),
#  (35,
#   '0.005*"компонент" + 0.004*"смартфон" + 0.003*"public" + 0.003*"камера" + 0.003*"игра" + 0.003*"экран" + 0.002*"new" + 0.002*"тест" + 0.002*"цена" + 0.002*"игрок"'),
#  (49,
#   '0.014*"public" + 0.009*"void" + 0.009*"new" + 0.009*"private" + 0.004*"lt;&lt" + 0.003*"модуль" + 0.003*"static" + 0.003*"microsoft" + 0.003*"узел" + 0.003*"windows"'),
#  (90,
#   '0.006*"игра" + 0.003*"камера" + 0.003*"дом" + 0.003*"движение" + 0.003*"переменный" + 0.003*"учёный" + 0.003*"поль" + 0.002*"частица" + 0.002*"цена" + 0.002*"google"'),
#  (46,
#   '0.010*"windows" + 0.004*"пакет" + 0.003*"движение" + 0.003*"модуль" + 0.003*"обновление" + 0.003*"блок" + 0.002*"сетевой" + 0.002*"драйвер" + 0.002*"адрес" + 0.002*"интеграция"'),
#  (37,
#   '0.005*"n" + 0.004*"docker" + 0.004*"карта" + 0.003*"канал" + 0.003*"пакет" + 0.003*"php" + 0.003*"контейнер" + 0.003*"модуль" + 0.003*"r" + 0.003*"уведомление"'),
#  (11,
#   '0.003*"игрок" + 0.003*"обучение" + 0.002*"ноутбук" + 0.002*"игра" + 0.002*"дата-центр" + 0.002*"браузер" + 0.002*"карта" + 0.002*"сотрудник" + 0.002*"ключ" + 0.002*"тэг"'),
#  (97,
#   '0.011*"блок" + 0.004*"игра" + 0.003*"видео" + 0.002*"бизнес" + 0.002*"экран" + 0.002*"лампа" + 0.002*"игрок" + 0.002*"транзакция" + 0.002*"изображение" + 0.002*"знание"'),
#  (32,
#   '0.004*"свойство" + 0.003*"oracle" + 0.003*"сотрудник" + 0.003*"google" + 0.003*"бот" + 0.003*"new" + 0.003*"изображение" + 0.003*"массив" + 0.003*"тест" + 0.002*"android"'),
#  (6,
#   '0.004*"модуль" + 0.004*"видео" + 0.003*"кнопка" + 0.003*"камера" + 0.002*"участник" + 0.002*"лицензия" + 0.002*"канал" + 0.002*"слой" + 0.002*"поль" + 0.002*"город"'),
#  (31,
#   '0.010*"услуга" + 0.006*"игра" + 0.004*"зона" + 0.003*"скидка" + 0.003*"2017" + 0.002*"участник" + 0.002*"слушать" + 0.002*"тест" + 0.002*"бизнес" + 0.002*"температура"'),
#  (27,
#   '0.005*"пароль" + 0.004*"игра" + 0.004*"таблица" + 0.003*"пакет" + 0.003*"переменный" + 0.003*"sudo" + 0.003*"public" + 0.002*"ключ" + 0.002*"скрипт" + 0.002*"p"')]

# %%
lda = gensim.models.LdaMulticore(corpus, 200, id2word=words, passes=3, alpha='asymmetric', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(199,
#   '0.007*"studio" + 0.007*"окно" + 0.006*"visual" + 0.006*"иконка" + 0.004*"программирование" + 0.003*"плагин" + 0.003*"камера" + 0.003*"оборудование" + 0.003*"ребёнок" + 0.003*"paypal"'),
#  (198,
#   '0.011*"connected" + 0.010*"российский" + 0.008*"компонент" + 0.008*"react" + 0.008*"message" + 0.004*"site" + 0.004*"виртуальный" + 0.004*"native" + 0.003*"export" + 0.003*"apple"'),
#  (197,
#   '0.026*"azure" + 0.021*"docker" + 0.015*"сборка" + 0.009*"windows" + 0.008*"linux" + 0.008*"run" + 0.007*"репозиторий" + 0.006*"агент" + 0.006*"build" + 0.005*"service"'),
#  (195,
#   '0.018*"спутник" + 0.016*"марс" + 0.013*"аппарат" + 0.013*"орбита" + 0.012*"земля" + 0.011*"космический" + 0.011*"луна" + 0.010*"планета" + 0.008*"поверхность" + 0.007*"солнечный"'),
#  (196,
#   '0.025*"тест" + 0.012*"тестирование" + 0.006*"номер" + 0.006*"тестовый" + 0.005*"вызов" + 0.004*"температура" + 0.003*"шанс" + 0.003*"маршрутизация" + 0.003*"вредоносный" + 0.003*"изображение"'),
#  (194,
#   '0.010*"университет" + 0.006*"0.5" + 0.005*"механизм" + 0.005*"инфраструктура" + 0.004*"single" + 0.004*"научный" + 0.004*"dns" + 0.004*"begin" + 0.004*"информационный" + 0.004*"среда"'),
#  (191,
#   '0.012*"смартфон" + 0.011*"xiaomi" + 0.008*"mi" + 0.007*"участник" + 0.006*"транзакция" + 0.004*"доллар" + 0.004*"обучение" + 0.004*"экран" + 0.004*"bitcoin" + 0.003*"script"'),
#  (193,
#   '0.014*"цифра" + 0.010*"сумма" + 0.008*"почта" + 0.007*"пароль" + 0.006*"частичный" + 0.006*"печать" + 0.005*"домен" + 0.005*"l" + 0.004*"z" + 0.004*"итерация"'),
#  (185,
#   '0.011*"тест" + 0.007*"сохранение" + 0.006*"id" + 0.006*"виртуальный" + 0.006*"тестирование" + 0.005*"загрузка" + 0.005*"восстановление" + 0.005*"activity" + 0.005*"ядро" + 0.004*"таблица"'),
#  (190,
#   '0.015*"ребёнок" + 0.012*"обучение" + 0.008*"нейросеть" + 0.008*"lego" + 0.005*"робот" + 0.005*"машинный" + 0.004*"кнопка" + 0.004*"программирование" + 0.004*"изображение" + 0.004*"услуга"'),
#  (9,
#   '0.019*"резервный" + 0.016*"копия" + 0.015*"хостинг" + 0.014*"объём" + 0.012*"заявка" + 0.008*"канал" + 0.007*"ограничение" + 0.007*"размещение" + 0.007*"панель" + 0.007*"ssd"'),
#  (8,
#   '0.010*"видео" + 0.010*"2017" + 0.009*"кнопка" + 0.008*"аккумулятор" + 0.006*"участие" + 0.005*"экран" + 0.004*"январь" + 0.004*"000" + 0.004*"yahoo" + 0.004*"энергия"'),
#  (7,
#   '0.016*"канал" + 0.012*"игра" + 0.008*"сигнал" + 0.008*"cloud" + 0.008*"передача" + 0.006*"пакет" + 0.005*"блок" + 0.004*"стандарт" + 0.004*"формат" + 0.004*"скрипт"'),
#  (6,
#   '0.010*"галактика" + 0.006*"канал" + 0.006*"amp;&amp" + 0.005*"браузер" + 0.005*"ген" + 0.005*"транзистор" + 0.005*"звезда" + 0.005*"германия" + 0.004*"корея" + 0.003*"изображение"'),
#  (5,
#   '0.012*"диск" + 0.007*"пароль" + 0.007*"раздел" + 0.006*"тестовый" + 0.006*"виртуальный" + 0.005*"тест" + 0.004*"vmware" + 0.004*"учётный" + 0.004*"физический" + 0.004*"уязвимость"'),
#  (4,
#   '0.014*"пациент" + 0.010*"лечение" + 0.010*"клетка" + 0.009*"заболевание" + 0.008*"болезнь" + 0.008*"вирус" + 0.008*"врач" + 0.007*"пакет" + 0.006*"организм" + 0.006*"учёный"'),
#  (3,
#   '0.004*"страна" + 0.004*"сотрудник" + 0.004*"сша" + 0.004*"документ" + 0.003*"россия" + 0.003*"книга" + 0.002*"российский" + 0.002*"фирма" + 0.002*"директор" + 0.002*"пять"'),
#  (2,
#   '0.022*"мощность" + 0.008*"вт" + 0.007*"usb" + 0.007*"питание" + 0.007*"напряжение" + 0.006*"батарея" + 0.006*"энергия" + 0.005*"wifi" + 0.005*"порт" + 0.005*"плагин"'),
#  (1,
#   '0.034*"ms" + 0.023*"sec" + 0.006*"игра" + 0.006*"sum" + 0.005*"диск" + 0.004*"2.1" + 0.004*"2.2" + 0.003*"экран" + 0.003*"доллар" + 0.003*"процессор"'),
#  (0,
#   '0.009*"атом" + 0.007*"признак" + 0.007*"скрипт" + 0.007*"comment" + 0.007*"column" + 0.005*"next" + 0.004*"маска" + 0.004*"пакет" + 0.004*"integer" + 0.004*"hello"')]

# %%
lda = gensim.models.LdaModel(corpus, 150, id2word=words, passes=6, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(97,
#   '0.206*"лаборатория" + 0.166*"account" + 0.110*"log" + 0.074*"security" + 0.037*"верх" + 0.030*"injection" + 0.022*"подготовиться" + 0.022*"data" + 0.019*"блокироваться" + 0.015*"ноябрь"'),
#  (58,
#   '0.242*"биржа" + 0.225*"московский" + 0.058*"кредитный" + 0.057*"близость" + 0.051*"400" + 0.033*"zero" + 0.027*"торговый" + 0.021*"доллар" + 0.020*"магнит" + 0.019*"стратегический"'),
#  (63,
#   '0.255*"days" + 0.097*"подсеть" + 0.057*"cisco" + 0.055*"адрес" + 0.048*"inc" + 0.045*"маска" + 0.032*"connection" + 0.020*"участник" + 0.019*"94" + 0.019*"50"'),
#  (66,
#   '0.133*"чёрный" + 0.098*"пятница" + 0.080*"золото" + 0.076*"праздник" + 0.057*"openstack" + 0.046*"четверг" + 0.046*"посылка" + 0.039*"т.е" + 0.029*"понедельник" + 0.027*"виртуализация"'),
#  (93,
#   '0.138*"azure" + 0.098*"microsoft" + 0.072*"vpn" + 0.028*"облако" + 0.027*"team" + 0.024*"виртуальный" + 0.023*"европа" + 0.022*"update" + 0.020*"продолжение" + 0.018*"т.к"'),
#  (16,
#   '0.244*"провайдер" + 0.107*"sla" + 0.084*"дата-центр" + 0.046*"беспилотный" + 0.035*"автомобиль" + 0.027*"cdn" + 0.025*"активироваться" + 0.022*"мириться" + 0.020*"нота" + 0.019*"доставка"'),
#  (126,
#   '0.221*"0.0" + 0.215*"mb" + 0.106*"usb" + 0.070*"писатель" + 0.052*"amd" + 0.035*"голосование" + 0.034*"am" + 0.029*"mode" + 0.025*"normal" + 0.021*"59"'),
#  (46,
#   '0.513*"метр" + 0.122*"стенд" + 0.058*"мощность" + 0.058*"тестовый" + 0.032*"боев" + 0.030*"тонна" + 0.028*"мвт" + 0.021*"строить" + 0.016*"магнит" + 0.016*"длина"'),
#  (100,
#   '0.119*"cookie" + 0.069*"партнёр" + 0.040*"идентификация" + 0.035*"пиксель" + 0.033*"идентификатор" + 0.026*"браузер" + 0.025*"контейнер" + 0.021*"оформление" + 0.021*"метка" + 0.020*"учитывать"'),
#  (62,
#   '0.226*"глаз" + 0.069*"животное" + 0.068*"линза" + 0.056*"маска" + 0.053*"qt" + 0.039*"еда" + 0.033*"камера" + 0.026*"растение" + 0.026*"обеспечивать" + 0.025*"изображение"'),
#  (42,
#   '0.016*"api" + 0.015*"file" + 0.014*"сборка" + 0.012*"папка" + 0.012*"документация" + 0.010*"опция" + 0.009*"→" + 0.009*"скрипт" + 0.008*"редактор" + 0.008*"запускать"'),
#  (129,
#   '0.042*"программирование" + 0.031*"программист" + 0.025*"java" + 0.023*"знание" + 0.014*"математика" + 0.011*"навык" + 0.008*"it" + 0.007*"функциональный" + 0.007*"ruby" + 0.006*"профессиональный"'),
#  (112,
#   '0.038*"сотрудник" + 0.018*"офис" + 0.018*"бизнес" + 0.014*"руководитель" + 0.013*"отдел" + 0.011*"срок" + 0.010*"гибкость" + 0.008*"успех" + 0.008*"респондент" + 0.007*"конкурент"'),
#  (64,
#   '0.015*"ия" + 0.012*"квеста" + 0.009*"университет" + 0.008*"лицо" + 0.007*"глубокий" + 0.007*"фильм" + 0.007*"интеллект" + 0.007*"манипуляция" + 0.007*"основать" + 0.006*"поведение"'),
#  (2,
#   '0.013*"бизнес" + 0.012*"инвестиция" + 0.009*"партнерский" + 0.008*"партнёр" + 0.008*"покупка" + 0.008*"посетитель" + 0.008*"продажа" + 0.008*"доллар" + 0.008*"заплатить" + 0.007*"приходить"'),
#  (88,
#   '0.019*"нагрузка" + 0.011*"цифровой" + 0.011*"облачный" + 0.011*"инфраструктура" + 0.011*"производительность" + 0.010*"облако" + 0.009*"хранилище" + 0.007*"хранение" + 0.007*"виртуальный" + 0.006*"обеспечивать"'),
#  (11,
#   '0.007*"прибор" + 0.006*"мощность" + 0.006*"генератор" + 0.006*"тепло" + 0.004*"измерение" + 0.004*"импульс" + 0.004*"производство" + 0.004*"сопротивление" + 0.004*"длительность" + 0.004*"постоянный"'),
#  (141,
#   '0.031*"студент" + 0.027*"курс" + 0.012*"mail.ru" + 0.012*"электроника" + 0.011*"лекция" + 0.008*"обучение" + 0.008*"занятие" + 0.007*"образовательный" + 0.007*"программист" + 0.007*"преподаватель"'),
#  (34,
#   '0.009*"продажа" + 0.007*"публикация" + 0.007*"социальный" + 0.006*"сообщество" + 0.004*"личный" + 0.004*"рейтинг" + 0.004*"распространение" + 0.004*"профессиональный" + 0.004*"лицо" + 0.004*"новость"'),
#  (135,
#   '0.004*"т.е" + 0.004*"карта" + 0.003*"картинка" + 0.003*"брать" + 0.003*"старое" + 0.003*"поставить" + 0.003*"выбирать" + 0.003*"понятно" + 0.003*"как-то" + 0.003*"минимум"')]

# %%
topics = [lda.print_topics()]

# %%
print(topics[0][4], '\n\n', topics[0][10], '\n\n', topics[0][16])
# Out:
# (16, '0.244*"провайдер" + 0.107*"sla" + 0.084*"дата-центр" + 0.046*"беспилотный" + 0.035*"автомобиль" + 0.027*"cdn" + 0.025*"активироваться" + 0.022*"мириться" + 0.020*"нота" + 0.019*"доставка"')
#
#  (52, '0.040*"заказчик" + 0.030*"услуга" + 0.016*"документ" + 0.016*"защита" + 0.016*"корпоративный" + 0.013*"предприятие" + 0.012*"ожидание" + 0.012*"бизнес" + 0.011*"внедрение" + 0.011*"ит"')
#
#  (11, '0.007*"прибор" + 0.006*"мощность" + 0.006*"генератор" + 0.006*"тепло" + 0.004*"измерение" + 0.004*"импульс" + 0.004*"производство" + 0.004*"сопротивление" + 0.004*"длительность" + 0.004*"постоянный"')

# %% [markdown]
# модели на преобразованном корпусе:

# %%
lda = gensim.models.LdaMulticore(corpus, 100, id2word=words, eval_every=0)

# %%
lda.print_topics()
# Out:
# [(26,
#   '0.003*"нативный" + 0.003*"power" + 0.002*"игра" + 0.002*"визуализация" + 0.002*"массив" + 0.002*"документ" + 0.002*"болезнь" + 0.002*"контекст" + 0.002*"российский" + 0.002*"ноутбук"'),
#  (3,
#   '0.002*"ручка" + 0.002*"операция" + 0.002*"юпитер" + 0.002*"пост" + 0.002*"аппарат" + 0.002*"анализатор" + 0.002*"devops" + 0.002*"подписка" + 0.002*"javascript" + 0.002*"react"'),
#  (89,
#   '0.003*"ibm" + 0.003*"виртуальный" + 0.002*"php" + 0.002*"игра" + 0.002*"сергей" + 0.002*"sap" + 0.002*"вм" + 0.002*"книга" + 0.002*"бумажный" + 0.002*"вирус"'),
#  (87,
#   '0.002*"учёный" + 0.002*"игра" + 0.002*"таблица" + 0.002*"lt;input" + 0.002*"подсветка" + 0.002*"датчик" + 0.002*"техподдержка" + 0.002*"дисплей" + 0.002*"sum" + 0.002*"фото"'),
#  (18,
#   '0.003*"конструктор" + 0.002*"игра" + 0.002*"менеджер" + 0.002*"звук" + 0.002*"коллекция" + 0.002*"dns" + 0.002*"выделить" + 0.002*"gitlab" + 0.002*"sudo" + 0.002*"временный"'),
#  (36,
#   '0.004*"игрок" + 0.003*"триггер" + 0.003*"email" + 0.003*"сотрудник" + 0.003*"персонаж" + 0.003*"образование" + 0.003*"анимация" + 0.003*"игра" + 0.002*"интервал" + 0.002*"san"'),
#  (92,
#   '0.002*"марс" + 0.002*"панель" + 0.002*"накопитель" + 0.002*"солнечный" + 0.002*"производительность" + 0.002*"фильтр" + 0.002*"юпитер" + 0.002*"angular" + 0.002*"api" + 0.002*"студент"'),
#  (80,
#   '0.003*"поток" + 0.003*"анализатор" + 0.003*"сертификат" + 0.003*"биржа" + 0.002*"сенсорный" + 0.002*"магазин" + 0.002*"собака" + 0.002*"архив" + 0.002*"swift" + 0.002*"математика"'),
#  (12,
#   '0.006*"камера" + 0.003*"linux" + 0.003*"ядро" + 0.002*"виртуализация" + 0.002*"public" + 0.002*"виджет" + 0.002*"приоритет" + 0.002*"wi-fi" + 0.002*"символ" + 0.002*"microsoft"'),
#  (17,
#   '0.003*"уязвимость" + 0.002*"доклад" + 0.002*"смартфон" + 0.002*"игрок" + 0.002*"database" + 0.002*"задание" + 0.002*"шифрование" + 0.002*"integer" + 0.002*"адрес" + 0.002*"аккумулятор"'),
#  (44,
#   '0.004*"протокол" + 0.003*"транзистор" + 0.003*"умный" + 0.003*"do" + 0.003*"счётчик" + 0.003*"квантовый" + 0.002*"закон" + 0.002*"плагин" + 0.002*"кластер" + 0.002*"вк"'),
#  (1,
#   '0.003*"игра" + 0.003*"страна" + 0.002*"работодатель" + 0.002*"вакансия" + 0.002*"канал" + 0.002*"загрузчик" + 0.002*"автомобиль" + 0.002*"интервью" + 0.002*"бот" + 0.002*"заполнение"'),
#  (22,
#   '0.004*"аккумулятор" + 0.004*"продажа" + 0.003*"разрешать" + 0.003*"сцена" + 0.003*"усилитель" + 0.002*"crm" + 0.002*"узел" + 0.002*"контент" + 0.002*"lenovo" + 0.002*"трафик"'),
#  (50,
#   '0.003*"биткоина" + 0.003*"цена" + 0.002*"слайд" + 0.002*"amazon" + 0.002*"доклад" + 0.002*"ключ" + 0.002*"вредоносный" + 0.002*"спикер" + 0.002*"windows" + 0.002*"антенна"'),
#  (9,
#   '0.003*"атака" + 0.003*"игра" + 0.003*"автомобиль" + 0.002*"public" + 0.002*"сигнал" + 0.002*"lego" + 0.002*"усилитель" + 0.002*"метка" + 0.002*"работник" + 0.002*"сотрудник"'),
#  (53,
#   '0.003*"http" + 0.002*"шейдёр" + 0.002*"служба" + 0.002*"модификатор" + 0.002*"false" + 0.002*"дата-центр" + 0.002*"design" + 0.002*"заголовок" + 0.002*"сигнал" + 0.002*"аппарат"'),
#  (84,
#   '0.004*"защита" + 0.002*"сигнал" + 0.002*"ddos-атака" + 0.002*"бизнес" + 0.002*"атака" + 0.002*"упаковка" + 0.002*"антенна" + 0.002*"кадр" + 0.002*"тест" + 0.002*"потребитель"'),
#  (72,
#   '0.004*"метр" + 0.003*"автомат" + 0.003*"драйвер" + 0.003*"ия" + 0.003*"маркетинг" + 0.003*"my" + 0.002*"виртуализация" + 0.002*"злоумышленник" + 0.002*"программист" + 0.002*"рыба"'),
#  (13,
#   '0.002*"рецепт" + 0.002*"светодиод" + 0.002*"распознавание" + 0.002*"словно" + 0.002*"смартфон" + 0.002*"книга" + 0.002*"аккумулятор" + 0.002*"диск" + 0.002*"мастер" + 0.002*"replace"'),
#  (42,
#   '0.003*"игра" + 0.002*"робот" + 0.002*"url" + 0.002*"gitlab" + 0.002*"модуль" + 0.002*"wi-fi" + 0.002*"регистратор" + 0.002*"игрок" + 0.001*"спектр" + 0.001*"аспект"')]

# %%
lda = gensim.models.LdaMulticore(corpus, 200, id2word=words, passes=3, alpha='asymmetric', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(196,
#   '0.170*"робот" + 0.006*"автоматизация" + 0.004*"дрон" + 0.001*"ия" + 0.001*"watson" + 0.001*"общество" + 0.001*"население" + 0.001*"технологический" + 0.001*"сфера" + 0.001*"корпорация"'),
#  (194,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (199,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (193,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (198,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (197,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (195,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (189,
#   '0.024*"vr" + 0.003*"дизайн" + 0.001*"unity" + 0.001*"гц" + 0.001*"привязка" + 0.001*"oculus" + 0.001*"камера" + 0.001*"макет" + 0.001*"fps" + 0.001*"дисплей"'),
#  (187,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (192,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (9,
#   '0.072*"виртуальный" + 0.071*"ip" + 0.059*"адрес" + 0.031*"management" + 0.024*"роутер" + 0.024*"interface" + 0.019*"huawei" + 0.016*"nat" + 0.015*"dhcp" + 0.014*"version"'),
#  (8,
#   '0.068*"блокчейн" + 0.060*"ibm" + 0.041*"begin" + 0.035*"облачный" + 0.023*"ms" + 0.022*"scrum" + 0.021*"баг" + 0.020*"integer" + 0.019*"диаграмма" + 0.017*"доска"'),
#  (7,
#   '0.070*"учёный" + 0.067*"вызов" + 0.044*"вирус" + 0.042*"java" + 0.033*"заболевание" + 0.028*"deepmind" + 0.026*"журнал" + 0.023*"научный" + 0.021*"стек" + 0.015*"геном"'),
#  (6,
#   '0.035*"code" + 0.030*"билд" + 0.027*"яндекс" + 0.021*"тест" + 0.012*"компилятор" + 0.011*"cc" + 0.008*"олег" + 0.006*"страх" + 0.005*"павел" + 0.005*"tdd"'),
#  (5,
#   '0.081*"нейросеть" + 0.061*"python" + 0.032*"f" + 0.027*"file" + 0.027*"run" + 0.026*"install" + 0.025*"0.0" + 0.024*"изображение" + 0.023*"искусственный" + 0.021*"профессор"'),
#  (4,
#   '0.094*"диск" + 0.066*"контроллер" + 0.053*"производительность" + 0.050*"нагрузка" + 0.037*"ssd" + 0.032*"unity" + 0.031*"препарат" + 0.029*"схд" + 0.023*"конверсия" + 0.021*"кэш"'),
#  (3,
#   '0.063*"windows" + 0.041*"окно" + 0.036*"меню" + 0.029*"иконка" + 0.023*"пункт" + 0.019*"скриншот" + 0.017*"показатель" + 0.017*"сборка" + 0.016*"личность" + 0.016*"основатель"'),
#  (2,
#   '0.012*"доклад" + 0.011*"android" + 0.009*"инфраструктура" + 0.009*"трафик" + 0.009*"оборудование" + 0.008*"россия" + 0.008*"конференция" + 0.008*"экран" + 0.008*"уязвимость" + 0.008*"энергия"'),
#  (1,
#   '0.015*"игра" + 0.006*"игрок" + 0.006*"обучение" + 0.005*"программирование" + 0.005*"книга" + 0.005*"мозг" + 0.004*"обновление" + 0.004*"пакет" + 0.004*"сигнал" + 0.004*"защита"'),
#  (0,
#   '0.010*"google" + 0.007*"сотрудник" + 0.006*"бизнес" + 0.006*"цена" + 0.006*"рубль" + 0.006*"microsoft" + 0.006*"товар" + 0.006*"000" + 0.005*"продажа" + 0.005*"ключ"')]

# %%
lda = gensim.models.LdaModel(corpus, 150, id2word=words, passes=6, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(148,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (149,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (60,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (84,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (117,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (5,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (74,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (90,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (101,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (53,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"'),
#  (18,
#   '0.021*"индекс" + 0.020*"css" + 0.020*"операция" + 0.019*"use" + 0.019*"переменный" + 0.019*"выражение" + 0.019*"фильтр" + 0.018*"дерево" + 0.018*"do" + 0.017*"тест"'),
#  (98,
#   '0.033*"клетка" + 0.028*"кожа" + 0.020*"пациент" + 0.019*"категория" + 0.018*"покупка" + 0.018*"зарядка" + 0.017*"тело" + 0.015*"несмотря" + 0.014*"женщина" + 0.013*"организм"'),
#  (55,
#   '0.026*"закон" + 0.025*"документ" + 0.023*"печать" + 0.021*"российский" + 0.019*"срок" + 0.018*"изделие" + 0.018*"объём" + 0.017*"электронный" + 0.016*"суд" + 0.014*"орган"'),
#  (145,
#   '0.024*"температура" + 0.022*"помещение" + 0.017*"сигнал" + 0.016*"питание" + 0.015*"кабель" + 0.015*"плата" + 0.014*"корпус" + 0.014*"напряжение" + 0.012*"звук" + 0.012*"датчик"'),
#  (106,
#   '0.020*"раздел" + 0.018*"google" + 0.017*"адрес" + 0.016*"номер" + 0.015*"ос" + 0.015*"вкладка" + 0.013*"браузер" + 0.012*"chrome" + 0.011*"операционный" + 0.011*"модуль"'),
#  (91,
#   '0.019*"обучение" + 0.017*"ия" + 0.016*"компонент" + 0.016*"узел" + 0.015*"лицо" + 0.013*"учёный" + 0.013*"оценка" + 0.013*"эксперимент" + 0.012*"характеристика" + 0.012*"теория"'),
#  (62,
#   '0.017*"представитель" + 0.014*"заказчик" + 0.013*"выделить" + 0.013*"system" + 0.013*"профиль" + 0.012*"государственный" + 0.012*"активность" + 0.012*"читатель" + 0.012*"пять" + 0.011*"изначально"'),
#  (144,
#   '0.046*"игра" + 0.024*"игрок" + 0.013*"тестирование" + 0.012*"карта" + 0.012*"бот" + 0.010*"личный" + 0.010*"площадка" + 0.010*"поделиться" + 0.010*"стикер" + 0.009*"мысль"'),
#  (40,
#   '0.008*"программирование" + 0.008*"канал" + 0.007*"api" + 0.006*"виртуальный" + 0.006*"браузер" + 0.006*"2017" + 0.005*"сетевой" + 0.005*"знание" + 0.005*"задать" + 0.005*"блок"'),
#  (120,
#   '0.007*"сотрудник" + 0.005*"бизнес" + 0.005*"страна" + 0.005*"формат" + 0.005*"windows" + 0.005*"социальный" + 0.005*"трафик" + 0.005*"робот" + 0.005*"поток" + 0.005*"производительность"')]

# %%
lda = gensim.models.LdaModel(corpus, 85, id2word=words, passes=1, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(59,
#   '0.008*"callback" + 0.005*"license" + 0.004*"весы" + 0.004*"аналоговый" + 0.004*"развёртывание" + 0.004*"поисковый" + 0.003*"session" + 0.003*"iot" + 0.003*"выдача" + 0.003*"configuration"'),
#  (84,
#   '0.009*"qualcomm" + 0.005*"post" + 0.005*"звезда" + 0.004*"чип" + 0.003*"астроном" + 0.003*"арифметический" + 0.003*"geektimes" + 0.003*"учёный" + 0.003*"дц" + 0.002*"тп"'),
#  (35,
#   '0.009*"микросервис" + 0.008*"view" + 0.008*"коллекция" + 0.007*"игра" + 0.005*"рассказ" + 0.003*"мартин" + 0.003*"серия" + 0.003*"рельеф" + 0.002*"контроллер" + 0.002*"дайджест"'),
#  (41,
#   '0.008*"спрайт" + 0.008*"когнитивный" + 0.008*"сертификат" + 0.007*"vsphere" + 0.005*"devops" + 0.004*"сертификация" + 0.003*"врач" + 0.003*"схд" + 0.003*"gb" + 0.003*"package"'),
#  (17,
#   '0.089*"iaas" + 0.014*"ит-инфраструктура" + 0.012*"обоснование" + 0.009*"облачный" + 0.006*"доход" + 0.005*"ип" + 0.004*"книга" + 0.003*"флешек" + 0.003*"облако" + 0.003*"зарубежный"'),
#  (76,
#   '0.008*"подписка" + 0.007*"воспоминание" + 0.006*"билд" + 0.006*"paypal" + 0.006*"ядро" + 0.005*"блок" + 0.005*"сериал" + 0.004*"сделка" + 0.004*"обмен" + 0.004*"sed"'),
#  (11,
#   '0.010*"signal" + 0.010*"материя" + 0.008*"intel" + 0.006*"тёмный" + 0.005*"гравитация" + 0.005*"tor" + 0.004*"кук" + 0.004*"отклонение" + 0.004*"тематический" + 0.004*"игрок"'),
#  (12,
#   '0.010*"пластик" + 0.005*"предприятие" + 0.005*"air" + 0.004*"ноутбук" + 0.004*"бэкап" + 0.004*"загрязнение" + 0.004*"агент" + 0.004*"изделие" + 0.003*"станок" + 0.003*"body"'),
#  (3,
#   '0.014*"регистр" + 0.006*"инструкция" + 0.006*"университет" + 0.005*"государственный" + 0.005*"агентство" + 0.004*"видеонаблюдение" + 0.004*"камера" + 0.003*"портал" + 0.003*"ui" + 0.003*"участник"'),
#  (62,
#   '0.078*"no" + 0.049*"yes" + 0.008*"swift" + 0.007*"double" + 0.006*"фреймворк" + 0.005*"one" + 0.005*"exit" + 0.005*"objective-c" + 0.004*"node.js" + 0.004*"платёж"'),
#  (74,
#   '0.016*"app" + 0.015*"браузер" + 0.015*"скрипт" + 0.012*"расширение" + 0.012*"content" + 0.011*"url" + 0.011*"бот" + 0.010*"variable" + 0.010*"public" + 0.010*"windows"'),
#  (75,
#   '0.023*"публичный" + 0.017*"токен" + 0.014*"перезагрузка" + 0.013*"закон" + 0.013*"vpn" + 0.012*"address" + 0.011*"ключ" + 0.011*"model" + 0.010*"веб-сервер" + 0.009*"state"'),
#  (13,
#   '0.017*"ия" + 0.014*"браузер" + 0.011*"edge" + 0.010*"chrome" + 0.009*"объявление" + 0.009*"microsoft" + 0.008*"генератор" + 0.007*"резистор" + 0.007*"mvp" + 0.007*"сергей"'),
#  (34,
#   '0.016*"электроника" + 0.013*"датчик" + 0.010*"помещение" + 0.010*"аудио" + 0.010*"звук" + 0.009*"яркость" + 0.008*"гаджет" + 0.008*"иван" + 0.007*"перемещение" + 0.007*"игра"'),
#  (69,
#   '0.013*"уязвимость" + 0.012*"шифрование" + 0.012*"домен" + 0.012*"вредоносный" + 0.011*"атака" + 0.011*"пароль" + 0.010*"виртуальный" + 0.010*"злоумышленник" + 0.010*"google" + 0.009*"км/ч"'),
#  (19,
#   '0.022*"студент" + 0.017*"корея" + 0.014*"34" + 0.011*"квеста" + 0.011*"client" + 0.010*"южный" + 0.010*"фич" + 0.010*"вконтакте" + 0.009*"загадка" + 0.008*"cluster"'),
#  (48,
#   '0.011*"сотрудник" + 0.010*"стикер" + 0.007*"программирование" + 0.007*"книга" + 0.007*"пообщаться" + 0.007*"бизнес" + 0.006*"дизайн" + 0.006*"дизайнер" + 0.006*"иконка" + 0.006*"коммуникация"'),
#  (7,
#   '0.012*"кампания" + 0.008*"игра" + 0.008*"февраль" + 0.007*"2017" + 0.006*"аккаунт" + 0.006*"делиться" + 0.006*"ценность" + 0.005*"сообщество" + 0.005*"общаться" + 0.005*"порог"'),
#  (64,
#   '0.006*"социальный" + 0.006*"игра" + 0.006*"услуга" + 0.005*"java" + 0.005*"хостинг" + 0.005*"площадка" + 0.005*"динамический" + 0.004*"умолчание" + 0.004*"ос" + 0.004*"обмен"'),
#  (40,
#   '0.009*"документ" + 0.006*"мозг" + 0.005*"контекст" + 0.004*"приходить" + 0.004*"трафик" + 0.004*"гипотеза" + 0.004*"канал" + 0.004*"браузер" + 0.004*"выборка" + 0.004*"кабель"')]

# %% [markdown]
# Первое, что бросилось в глаза после применения tf-idf — это появление множества дубликатов на нескольких вариантах настроек модели, вот таких:
#
# (148,
#   '0.000*"мучительный" + 0.000*"отметка" + 0.000*"капля" + 0.000*"мина" + 0.000*"морской" + 0.000*"ехать" + 0.000*"отверстие" + 0.000*"погружение" + 0.000*"повредить" + 0.000*"душа"')
#
# Вероятно, это как-то связано с количеством проходов по корпусу, но до tf-idf этого не было.
#
# При этом сами темы стали более осмысленными — если однозначную тематику угадать все еще можно не всегда, то связи между словами в теме почти всегда можно найти, в отличие от результатов моделей до tf-idf:
#
# (48,
#   '0.011*"сотрудник" + 0.010*"стикер" + 0.007*"программирование" + 0.007*"книга" + 0.007*"пообщаться" + 0.007*"бизнес" + 0.006*"дизайн" + 0.006*"дизайнер" + 0.006*"иконка" + 0.006*"коммуникация"') — что-то про визуальную составляющую, UX
#
# (69,
#   '0.013*"уязвимость" + 0.012*"шифрование" + 0.012*"домен" + 0.012*"вредоносный" + 0.011*"атака" + 0.011*"пароль" + 0.010*"виртуальный" + 0.010*"злоумышленник" + 0.010*"google" + 0.009*"км/ч"') — что-то про безопасность и инфобез
#
# Некоторые из тем ухудшились, например, в более ранней
#
# (4,
#   '0.014*"пациент" + 0.010*"лечение" + 0.010*"клетка" + 0.009*"заболевание" + 0.008*"болезнь" + 0.008*"вирус" + 0.008*"врач" + 0.007*"пакет" + 0.006*"организм" + 0.006*"учёный"')
#
# легче понять, о чем речь, нежели в более поздней
#
# (7,
#   '0.070*"учёный" + 0.067*"вызов" + 0.044*"вирус" + 0.042*"java" + 0.033*"заболевание" + 0.028*"deepmind" + 0.026*"журнал" + 0.023*"научный" + 0.021*"стек" + 0.015*"геном"')
#
# .

# %%
stexts = [' '.join(text) for text in texts]

# %%
vectorizer = TfidfVectorizer(max_features=500, min_df=5, max_df=0.7, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 то  очень  какой  делать
# 1 файл  скрипт  пакет  настройка
# 2 игра  игрок  разработчик  уровень
# 3 приложение  мобильный  android  разработка
# 4 lt  gt  gt lt  компонент
# 5 система  управление  безопасность  оборудование
# 6 проект  команда  разработчик  разработка
# 7 устройство  смартфон  производитель  мобильный
# 8 год  2016  миллион  стать
# 9 public  new  void  класс
# 10 компания  сотрудник  рынок  бизнес
# 11 the  of  and  for
# 12 код  функция  значение  переменный
# 13 сервер  виртуальный  машина  настройка
# 14 сайт  страница  браузер  адрес
# 15 язык  программирование  программист  книга
# 16 windows  microsoft  linux  версия
# 17 дать  запрос  база  база дать
# 18 элемент  изображение  материал  модель
# 19 google  android  сервис  api
# 20 сигнал  связь  канал  передача
# 21 тест  тестирование  результат  производительность
# 22 камера  смартфон  видео  цена
# 23 amp  for  void  gt
# 24 пользователь  сообщение  сервис  доступ
# 25 объект  класс  метод  свойство
# 26 человек  исследование  жизнь  работа
# 27 процессор  память  ядро  диск
# 28 клиент  услуга  бизнес  сервис
# 29 сеть  интернет  связь  доступ

# %%
model.reconstruction_err_
# Out:
# 49.62858140486233

# %%
vectorizer = TfidfVectorizer(max_features=1500, min_df=8, max_df=0.5, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 проект  команда  задача  разработка
# 1 файл  папка  скрипт  пакет
# 2 игра  игрок  игровой  играть
# 3 человек  учёный  мозг  исследование
# 4 устройство  сигнал  звук  частота
# 5 lt  gt  lt div  div
# 6 приложение  android  мобильный  пользователь
# 7 public  new  void  private
# 8 сайт  страница  пользователь  реклама
# 9 человек  книга  какой  что
# 10 the  of  and  for
# 11 космический  спутник  орбита  аппарат
# 12 товар  рубль  цена  скидка
# 13 виртуальный  машина  виртуальный машина  windows
# 14 уязвимость  атака  безопасность  пароль
# 15 процессор  память  intel  диск
# 16 печать  принтер  3d  материал
# 17 доклад  конференция  участник  тема
# 18 функция  объект  значение  метод
# 19 тест  тестирование  код  тестировать
# 20 react  css  javascript  js
# 21 сервер  запрос  база  сервис
# 22 компания  сотрудник  рынок  бизнес
# 23 камера  видео  смартфон  изображение
# 24 бот  сообщение  пользователь  канал
# 25 дата центр  центр  дата  оборудование
# 26 вселенная  энергия  звезда  свет
# 27 amp  amp amp  echo  for
# 28 сеть  трафик  связь  интернет
# 29 язык  программирование  код  программа

# %%
model.reconstruction_err_
# Out:
# 55.30179936400718

# %%
vectorizer = TfidfVectorizer(max_features=1200, min_df=21, max_df=0.35, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 клиент  продукт  команда  сотрудник
# 1 файл  папка  скрипт  команда
# 2 игра  игрок  игровой  играть
# 3 вселенная  энергия  теория  свет
# 4 устройство  смартфон  телефон  датчик
# 5 lt  gt  lt div  div
# 6 приложение  android  мобильный  ios
# 7 public  void  new  private
# 8 windows  microsoft  уязвимость  linux
# 9 товар  рубль  скидка  цена
# 10 космический  спутник  аппарат  земля
# 11 сайт  страница  реклама  браузер
# 12 рынок  google  российский  миллион
# 13 the  of  and  for
# 14 доклад  конференция  участник  тема
# 15 сервер  запрос  сервис  база
# 16 учёный  мозг  исследование  клетка
# 17 печать  принтер  3d  материал
# 18 объект  класс  метод  свойство
# 19 язык  программирование  программа  программист
# 20 сеть  атака  безопасность  трафик
# 21 дата центр  центр  дата  оборудование
# 22 бот  сообщение  робот  канал
# 23 функция  значение  элемент  переменный
# 24 amp  amp amp  echo  for
# 25 камера  видео  смартфон  изображение
# 26 react  css  javascript  js
# 27 сигнал  звук  частота  напряжение
# 28 книга  что  какой то  что то
# 29 процессор  диск  память  виртуальный

# %%
model.reconstruction_err_
# Out:
# 55.18919946327033

# %% [markdown]
# лучшей оказалась первая модель.

# %%
top_words = model.components_.argsort()[:,:-5:-1]
ready = []
for i in range(top_words.shape[0]):
    ready.append([feat_names[j] for j in top_words[i]])

# %%
print(ready[2], ready[3], ready[6])
# Out:
# ['игра', 'игрок', 'разработчик', 'уровень'] ['приложение', 'мобильный', 'android', 'разработка'] ['проект', 'команда', 'разработчик', 'разработка']

# %% [markdown]
# осмысленности в резуль
