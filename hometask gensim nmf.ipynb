# %%
import pymorphy2
import re
import string
import gensim
import pandas as pd
from pymorphy2 import MorphAnalyzer
from collections import Counter
from nltk.corpus import stopwords
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
morph = MorphAnalyzer()

# %%
stops = set(stopwords.words('russian')) | {'gt', 'int', 'if', 'x', 'to', 'in', 'return', 'case', 'i', '•', 
                                          'null', 'set', 'as', 'from', 'var', 'lt', 'on', 'is', 'end', 'b',
                                          'else', 'bool', 'const', 'function', 'class', 'string', 'import',
                                          'then', 'type', 'person', 'select', 'def', 'up', 'down', 'active',
                                          'print', 'assert', 'j', 'str', 'loop', 'char', 'unsigned', 'true',
                                          'main', 'func'}

# %%
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %%
texts = open('/Users/macbookpro/Downloads/habr.txt').read().splitlines()

# %%
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)

# %%
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.7) # threshold можно подбирать

# %%
p = gensim.models.phrases.Phraser(ph)

# %%
ngrammed_texts = p[texts]

# %%
words = gensim.corpora.Dictionary(ngrammed_texts)

# %%
words.filter_extremes(no_above=0.15, no_below=22)
words.compactify()

# %%
print(words)
# Out:
# Dictionary(6710 unique tokens: ['2-х', '3.0', 'address', 'api', 'architecture']...)

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=words)

# %%
corpus = tfidf[corpus]

# %%
corpus = [words.doc2bow(text) for text in ngrammed_texts]

# %%
lda = gensim.models.LdaMulticore(corpus, 100, id2word=words, eval_every=0)

# %%
lda.print_topics()
# Out:
# [(90,
#   '0.005*"скидка" + 0.004*"apple" + 0.004*"книга" + 0.004*"цена" + 0.003*"000" + 0.003*"стоимость" + 0.003*"формула" + 0.003*"энергия" + 0.003*"товар" + 0.003*"рейтинг"'),
#  (69,
#   '0.006*"игра" + 0.005*"адрес" + 0.005*"услуга" + 0.004*"add" + 0.003*"процессор" + 0.003*"виртуальный" + 0.003*"выделить" + 0.003*"трафик" + 0.003*"хост" + 0.002*"участник"'),
#  (2,
#   '0.003*"процессор" + 0.002*"сотрудник" + 0.002*"виртуальный" + 0.002*"ключ" + 0.002*"user" + 0.002*"адрес" + 0.002*"услуга" + 0.002*"операция" + 0.002*"экран" + 0.002*"ядро"'),
#  (83,
#   '0.005*"microsoft" + 0.002*"таблица" + 0.002*"виртуальный" + 0.002*"страна" + 0.002*"трафик" + 0.002*"программирование" + 0.002*"this" + 0.002*"go" + 0.002*"локальный" + 0.002*"производительность"'),
#  (98,
#   '0.004*"user" + 0.004*"вселенная" + 0.004*"телефон" + 0.003*"звук" + 0.002*"таблица" + 0.002*"тело" + 0.002*"n" + 0.002*"свет" + 0.002*"постоянный" + 0.002*"дерево"'),
#  (87,
#   '0.006*"игра" + 0.005*"тест" + 0.004*"диск" + 0.003*"текстура" + 0.003*"кластер" + 0.003*"сигнал" + 0.003*"карта" + 0.003*"производительность" + 0.002*"azure" + 0.002*"виртуальный"'),
#  (7,
#   '0.006*"ключ" + 0.005*"тест" + 0.003*"public" + 0.002*"производительность" + 0.002*"пакет" + 0.002*"ядро" + 0.002*"виртуальный" + 0.002*"хранение" + 0.002*"таблица" + 0.002*"вызов"'),
#  (67,
#   '0.011*"public" + 0.004*"блок" + 0.004*"php" + 0.003*"new" + 0.003*"кнопка" + 0.003*"void" + 0.003*"игра" + 0.003*"иначе" + 0.002*"private" + 0.002*"транзакция"'),
#  (53,
#   '0.022*"игра" + 0.005*"игрок" + 0.003*"диск" + 0.003*"индекс" + 0.002*"видео" + 0.002*"фигура" + 0.002*"таблица" + 0.002*"играть" + 0.002*"папка" + 0.002*"токен"'),
#  (70,
#   '0.005*"ребёнок" + 0.004*"блок" + 0.004*"ядро" + 0.003*"модуль" + 0.003*"адрес" + 0.003*"оператор" + 0.003*"программирование" + 0.003*"кнопка" + 0.003*"токен" + 0.003*"тест"'),
#  (28,
#   '0.005*"книга" + 0.004*"изображение" + 0.004*"нейросеть" + 0.004*"begin" + 0.003*"глаз" + 0.003*"обучение" + 0.003*"вызов" + 0.003*"research" + 0.003*"not" + 0.002*"s"'),
#  (63,
#   '0.017*"игра" + 0.003*"заказчик" + 0.003*"public" + 0.002*"модуль" + 0.002*"бизнес" + 0.002*"игрок" + 0.002*"amp;&amp" + 0.002*"отчёт" + 0.002*"точка_зрение" + 0.002*"игровой"'),
#  (92,
#   '0.004*"слушать" + 0.004*"видео" + 0.004*"модуль" + 0.004*"public" + 0.003*"linux" + 0.003*"игра" + 0.003*"windows" + 0.002*"docker" + 0.002*"new" + 0.002*"add"'),
#  (51,
#   '0.004*"игра" + 0.004*"рубль" + 0.003*"игрок" + 0.003*"страна" + 0.002*"сигнал" + 0.002*"изображение" + 0.002*"бизнес" + 0.002*"стоимость" + 0.002*"оператор" + 0.002*"000"'),
#  (50,
#   '0.008*"ключ" + 0.004*"тест" + 0.003*"блок" + 0.003*"тестирование" + 0.003*"производительность" + 0.003*"процессор" + 0.003*"лекция" + 0.002*"сертификат" + 0.002*"документ" + 0.002*"номер"'),
#  (86,
#   '0.008*"игра" + 0.005*"игрок" + 0.003*"android" + 0.003*"канал" + 0.002*"процессор" + 0.002*"т.е" + 0.002*"public" + 0.002*"new" + 0.002*"сотрудник" + 0.002*"книга"'),
#  (49,
#   '0.007*"игра" + 0.004*"сертификат" + 0.003*"лампа" + 0.002*"игрок" + 0.002*"e" + 0.002*"диск" + 0.002*"react" + 0.002*"звук" + 0.002*"id" + 0.002*"000"'),
#  (41,
#   '0.004*"research" + 0.003*"international" + 0.003*"боль" + 0.003*"массив" + 0.002*"операция" + 0.002*"игра" + 0.002*"модуль" + 0.002*"блок" + 0.002*"виртуальный" + 0.002*"тест"'),
#  (11,
#   '0.012*"public" + 0.007*"new" + 0.007*"тест" + 0.006*"private" + 0.004*"void" + 0.004*"windows" + 0.003*"swift" + 0.003*"static" + 0.003*"linux" + 0.003*"участник"'),
#  (38,
#   '0.007*"игра" + 0.004*"e" + 0.003*"d" + 0.003*"операция" + 0.003*"камера" + 0.003*"браузер" + 0.003*"модуль" + 0.002*"хранение" + 0.002*"тест" + 0.002*"вкладка"')]

# %%
lda = gensim.models.LdaMulticore(corpus, 200, id2word=words, passes=3, alpha='asymmetric', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(197,
#   '0.005*"дизайн" + 0.004*"частица" + 0.004*"теория" + 0.003*"игра" + 0.003*"здание" + 0.003*"изображение" + 0.003*"квантовый" + 0.002*"автомат" + 0.002*"движение" + 0.002*"построить"'),
#  (193,
#   '0.050*"byte" + 0.010*"комната" + 0.009*"сканер" + 0.009*"void" + 0.007*"температура" + 0.006*"меню" + 0.006*"поверхность" + 0.006*"amp;&amp" + 0.006*"9" + 0.005*"output"'),
#  (191,
#   '0.008*"виртуальный" + 0.008*"станция" + 0.007*"звук" + 0.006*"скрипт" + 0.006*"базовый" + 0.004*"плагин" + 0.004*"температура" + 0.004*"офис" + 0.003*"api" + 0.003*"сетевой"'),
#  (192,
#   '0.029*"вм" + 0.019*"виртуальный" + 0.015*"linux" + 0.015*"хост" + 0.013*"windows" + 0.012*"транзакция" + 0.010*"защита" + 0.010*"схд" + 0.009*"ос" + 0.008*"драйвер"'),
#  (198,
#   '0.015*"узел" + 0.014*"android" + 0.009*"экран" + 0.009*"university" + 0.008*"кластер" + 0.007*"вкладка" + 0.006*"systems" + 0.005*"data" + 0.005*"at" + 0.005*"cs"'),
#  (199,
#   '0.008*"лицензия" + 0.008*"тест" + 0.006*"бизнес" + 0.005*"тестирование" + 0.004*"плагин" + 0.004*"new" + 0.004*"google" + 0.004*"модуль" + 0.003*"php" + 0.003*"просмотр"'),
#  (189,
#   '0.009*"драйвер" + 0.008*"компонент" + 0.007*"принтер" + 0.007*"презентация" + 0.007*"dom" + 0.006*"windows" + 0.006*"api" + 0.006*"бот" + 0.006*"вызов" + 0.006*"слушать"'),
#  (196,
#   '0.014*"частота" + 0.011*"days" + 0.009*"таймер" + 0.009*"порт" + 0.008*"прерывание" + 0.007*"tcp" + 0.007*"сигнал" + 0.006*"производительность" + 0.006*"регистр" + 0.006*"битый"'),
#  (195,
#   '0.009*"глобальный" + 0.008*"оператор" + 0.007*"pass" + 0.006*"пакет" + 0.006*"комната" + 0.006*"height" + 0.005*"ребёнок" + 0.005*"переменный" + 0.005*"width" + 0.004*"webpack"'),
#  (194,
#   '0.029*"доклад" + 0.017*"конференция" + 0.006*"telegram" + 0.006*"бот" + 0.005*"analysis" + 0.004*"производительность" + 0.004*"performance" + 0.004*"php" + 0.003*"тестирование" + 0.003*"core"'),
#  (9,
#   '0.011*"доклад" + 0.010*"тест" + 0.009*"зрение" + 0.008*"участие" + 0.007*"конференция" + 0.007*"глаз" + 0.006*"услуга" + 0.005*"2017" + 0.005*"январь" + 0.005*"участник"'),
#  (8,
#   '0.012*"тест" + 0.007*"домен" + 0.006*"репозиторий" + 0.006*"адрес" + 0.006*"браузер" + 0.005*"сборка" + 0.004*"git" + 0.004*"переменный" + 0.004*"компонент" + 0.003*"ip"'),
#  (7,
#   '0.011*"сигнал" + 0.009*"драйвер" + 0.006*"root" + 0.005*"передача" + 0.004*"void" + 0.004*"нода" + 0.004*"file" + 0.004*"блок" + 0.004*"шина" + 0.004*"канал"'),
#  (6,
#   '0.010*"станок" + 0.007*"днк" + 0.006*"31" + 0.006*"кандидат" + 0.005*"n" + 0.005*"цифра" + 0.003*"пост" + 0.003*"тестирование" + 0.003*"хранение" + 0.003*"адрес"'),
#  (5,
#   '0.008*"карта" + 0.007*"ребёнок" + 0.006*"игра" + 0.006*"процессор" + 0.005*"видеокарта" + 0.005*"тест" + 0.004*"crm" + 0.004*"железо" + 0.004*"сотрудник" + 0.003*"интеграция"'),
#  (4,
#   '0.011*"блок" + 0.007*"массив" + 0.005*"слайд" + 0.005*"вызов" + 0.005*"sleep" + 0.005*"define" + 0.005*"операция" + 0.004*"переменный" + 0.004*"сотрудник" + 0.003*"k"'),
#  (3,
#   '0.010*"карта" + 0.008*"цена" + 0.006*"модуль" + 0.005*"смартфон" + 0.005*"поток" + 0.004*"ребёнок" + 0.004*"страна" + 0.003*"стоимость" + 0.003*"россия" + 0.002*"сша"'),
#  (2,
#   '0.013*"лампа" + 0.011*"вода" + 0.007*"автомобиль" + 0.004*"карта" + 0.004*"участник" + 0.004*"вод" + 0.004*"температура" + 0.004*"платёж" + 0.004*"сша" + 0.003*"стоимость"'),
#  (1,
#   '0.013*"документ" + 0.008*"сотрудник" + 0.006*"срок" + 0.006*"заказчик" + 0.005*"ms" + 0.004*"график" + 0.004*"договор" + 0.004*"бумага" + 0.004*"count" + 0.004*"руководство"'),
#  (0,
#   '0.008*"нейрон" + 0.006*"сигнал" + 0.005*"битый" + 0.005*"блок" + 0.004*"знание" + 0.004*"переменный" + 0.004*"звук" + 0.004*"адрес" + 0.004*"воспоминание" + 0.004*"ядро"')]

# %%
lda = gensim.models.LdaModel(corpus, 150, id2word=words, passes=6, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(5,
#   '0.249*"нажать" + 0.159*"галактика" + 0.128*"тёмный" + 0.044*"кнопка" + 0.040*"тёмный_материя" + 0.031*"открытие" + 0.029*"горячее" + 0.025*"иначе" + 0.023*"центр" + 0.014*"объяснение"'),
#  (146,
#   '0.200*"усилитель" + 0.167*"микросхема" + 0.162*"искажение" + 0.091*"подбирать" + 0.061*"эффект" + 0.036*"клон" + 0.034*"повредить" + 0.033*"обратный" + 0.029*"спринт" + 0.027*"когнитивный"'),
#  (4,
#   '0.730*"символ" + 0.087*"шрифт" + 0.048*"валюта" + 0.036*"зуб" + 0.013*"unicode" + 0.008*"составной" + 0.005*"избегать" + 0.004*"нагрузка" + 0.003*"снижать" + 0.003*"нормальный"'),
#  (90,
#   '0.256*"вода" + 0.088*"gitlab" + 0.076*"вод" + 0.054*"script" + 0.049*"температура" + 0.038*"лёд" + 0.034*"кислород" + 0.030*"ci" + 0.027*"pages" + 0.027*"гелий"'),
#  (141,
#   '0.333*"фотография" + 0.108*"разрешение" + 0.057*"горизонт" + 0.050*"снимать" + 0.042*"кадр" + 0.041*"проекция" + 0.040*"съёмка" + 0.025*"телескоп" + 0.024*"фото" + 0.021*"видный"'),
#  (129,
#   '0.216*"право" + 0.110*"механизм" + 0.075*"патент" + 0.065*"изобретение" + 0.040*"инновация" + 0.038*"изобретатель" + 0.026*"колесо" + 0.025*"профессор" + 0.020*"выдавать" + 0.019*"владение"'),
#  (24,
#   '0.178*"test" + 0.076*"read" + 0.072*"write" + 0.069*"bytes" + 0.061*"date" + 0.049*"t" + 0.042*"архитектор" + 0.034*"server" + 0.033*"os" + 0.031*"sleep"'),
#  (116,
#   '0.184*"level" + 0.123*"ввод" + 0.083*"like" + 0.070*"transaction" + 0.067*"наименование" + 0.037*"labs" + 0.032*"фокус" + 0.029*"периодичность" + 0.028*"parent" + 0.018*"порядком"'),
#  (75,
#   '0.148*"node" + 0.094*"path" + 0.065*"ssh" + 0.056*"mount" + 0.049*"tdd" + 0.044*"отмечаться" + 0.043*"файловый" + 0.038*"powershell" + 0.032*"tree" + 0.031*"накопление"'),
#  (101,
#   '0.195*"звезда" + 0.055*"root" + 0.055*"светов" + 0.054*"echo" + 0.043*"шина" + 0.036*"яркий" + 0.027*"driver" + 0.023*"i2c" + 0.018*"ядро" + 0.016*"direct"'),
#  (70,
#   '0.017*"обновление" + 0.014*"сущность" + 0.012*"расширение" + 0.012*"sql_server" + 0.010*"пользовательский" + 0.009*"контакт" + 0.009*"token" + 0.009*"sql" + 0.008*"уведомление" + 0.007*"отчёт"'),
#  (56,
#   '0.017*"автомобиль" + 0.016*"робот" + 0.010*"рубль" + 0.009*"телефон" + 0.009*"обзор" + 0.008*"производитель" + 0.007*"цена" + 0.007*"номер" + 0.006*"купить" + 0.006*"покупка"'),
#  (99,
#   '0.017*"api" + 0.011*"репозиторий" + 0.011*"плагин" + 0.010*"сборка" + 0.009*"папка" + 0.008*"github" + 0.008*"age" + 0.007*"статический" + 0.007*"добавление" + 0.007*"git"'),
#  (112,
#   '0.008*"играть" + 0.008*"подумать" + 0.008*"дом" + 0.007*"виртуальный_реальность" + 0.006*"ответить" + 0.006*"спросить" + 0.006*"час" + 0.006*"голова" + 0.005*"помнить" + 0.005*"против"'),
#  (41,
#   '0.031*"услуга" + 0.024*"облачный" + 0.022*"инфраструктура" + 0.018*"заказчик" + 0.012*"корпоративный" + 0.011*"публичный" + 0.009*"облако" + 0.008*"домен" + 0.008*"iaas" + 0.008*"провайдер"'),
#  (15,
#   '0.011*"движение" + 0.010*"вектор" + 0.009*"матрица" + 0.006*"положение" + 0.006*"угол" + 0.005*"расстояние" + 0.005*"вероятность" + 0.005*"пространство" + 0.005*"равный" + 0.004*"друг_друг"'),
#  (97,
#   '0.009*"подборка" + 0.009*"цифровой" + 0.008*"рассказывать" + 0.007*"распространение" + 0.006*"публикация" + 0.006*"аудитория" + 0.006*"категория" + 0.006*"знание" + 0.005*"доллар" + 0.005*"сообщество"'),
#  (63,
#   '0.013*"энергия" + 0.010*"теория" + 0.009*"университет" + 0.009*"научный" + 0.007*"учёный" + 0.005*"мировой" + 0.005*"наука" + 0.005*"институт" + 0.005*"центр" + 0.005*"технологический"'),
#  (89,
#   '0.017*"заказчик" + 0.008*"ожидание" + 0.007*"бизнес" + 0.006*"программист" + 0.005*"срок" + 0.005*"ит" + 0.005*"знание" + 0.004*"отдел" + 0.004*"руководитель" + 0.004*"уверенный"'),
#  (79,
#   '0.004*"фильм" + 0.004*"старое" + 0.004*"книга" + 0.004*"попасть" + 0.003*"какой-нибудь" + 0.003*"куча" + 0.003*"картинка" + 0.003*"пост" + 0.003*"называться" + 0.003*"всякий"')]

# %%
topics = [lda.print_topics()]

# %%
print(topics[0][0], '\n\n', topics[0][4], '\n\n', topics[0][17])
# Out:
# (5, '0.249*"нажать" + 0.159*"галактика" + 0.128*"тёмный" + 0.044*"кнопка" + 0.040*"тёмный_материя" + 0.031*"открытие" + 0.029*"горячее" + 0.025*"иначе" + 0.023*"центр" + 0.014*"объяснение"')
#
#  (24, '0.178*"test" + 0.076*"read" + 0.072*"write" + 0.069*"bytes" + 0.061*"date" + 0.049*"t" + 0.042*"архитектор" + 0.034*"server" + 0.033*"os" + 0.031*"sleep"')
#
#  (63, '0.013*"энергия" + 0.010*"теория" + 0.009*"университет" + 0.009*"научный" + 0.007*"учёный" + 0.005*"мировой" + 0.005*"наука" + 0.005*"институт" + 0.005*"центр" + 0.005*"технологический"')

# %% [markdown]
# модели на преобразованном корпусе:

# %%
lda = gensim.models.LdaMulticore(corpus, 100, id2word=words, eval_every=0)

# %%
lda.print_topics()
# Out:
# [(79,
#   '0.004*"игра" + 0.003*"microsoft" + 0.002*"уязвимость" + 0.002*"скидка" + 0.002*"windows" + 0.002*"кожа" + 0.002*"google" + 0.002*"сотрудник" + 0.002*"ноутбук" + 0.002*"программист"'),
#  (71,
#   '0.003*"ия" + 0.003*"игра" + 0.003*"ядро" + 0.002*"программист" + 0.002*"умение" + 0.002*"учёный" + 0.002*"соревнование" + 0.002*"российский" + 0.002*"предприниматель" + 0.002*"программирование"'),
#  (7,
#   '0.004*"игра" + 0.004*"сигнал" + 0.003*"усилитель" + 0.002*"игрок" + 0.002*"переменный" + 0.002*"метка" + 0.002*"бот" + 0.002*"гибкость" + 0.002*"документ" + 0.002*"наушник"'),
#  (73,
#   '0.003*"api" + 0.003*"игра" + 0.002*"изображение" + 0.002*"кристалл" + 0.002*"корпорация" + 0.002*"android" + 0.002*"контроллер" + 0.002*"бизнес" + 0.002*"кнопка" + 0.002*"iot"'),
#  (32,
#   '0.002*"windows" + 0.002*"бот" + 0.002*"трафик" + 0.002*"наушник" + 0.002*"сотрудник" + 0.002*"профессиональный" + 0.002*"игрок" + 0.002*"канал" + 0.002*"google" + 0.002*"документ"'),
#  (24,
#   '0.003*"тест" + 0.002*"false" + 0.002*"node.js" + 0.002*"матрица" + 0.002*"наса" + 0.002*"браузер" + 0.002*"испытание" + 0.002*"картинка" + 0.002*"частица" + 0.002*"ruby"'),
#  (29,
#   '0.003*"уязвимость" + 0.003*"игра" + 0.003*"windows" + 0.003*"сергей" + 0.003*"слушать" + 0.003*"уведомление" + 0.003*"php" + 0.003*"microsoft" + 0.003*"задержка" + 0.003*"ребёнок"'),
#  (98,
#   '0.004*"php" + 0.004*"вирус" + 0.003*"атака" + 0.003*"пациент" + 0.002*"обновление" + 0.002*"go" + 0.002*"игра" + 0.002*"обследование" + 0.002*"ассемблер" + 0.002*"хранилище"'),
#  (85,
#   '0.003*"тест" + 0.002*"игра" + 0.002*"модуль" + 0.002*"аппарат" + 0.002*"ядро" + 0.002*"космический" + 0.002*"подписка" + 0.002*"документ" + 0.002*"рекурсия" + 0.002*"rest"'),
#  (72,
#   '0.003*"субд" + 0.002*"вм" + 0.002*"виртуализация" + 0.002*"хакатон" + 0.002*"луна" + 0.002*"десктоп" + 0.002*"y" + 0.002*"виртуальный" + 0.002*"analysis" + 0.002*"математика"'),
#  (8,
#   '0.004*"звонок" + 0.004*"конференция" + 0.003*"кандидат" + 0.003*"телефон" + 0.003*"php" + 0.003*"секрет" + 0.003*"мозг" + 0.003*"контент" + 0.002*"папка" + 0.002*"mobile"'),
#  (66,
#   '0.003*"карта" + 0.003*"станция" + 0.002*"оценка" + 0.002*"сотрудник" + 0.002*"защита" + 0.002*"профессия" + 0.002*"hpe" + 0.002*"диплом" + 0.002*"космический" + 0.002*"пакет"'),
#  (83,
#   '0.004*"диск" + 0.004*"пароль" + 0.003*"город" + 0.003*"my" + 0.002*"бизнес-процесс" + 0.002*"приоритет" + 0.002*"ui" + 0.002*"linux" + 0.002*"луна" + 0.002*"навигация"'),
#  (26,
#   '0.003*"игра" + 0.002*"чпу" + 0.002*"станок" + 0.002*"ручка" + 0.002*"болезнь" + 0.002*"мониторинг" + 0.002*"слайд" + 0.002*"робот" + 0.002*"спринт" + 0.002*"автоматизация"'),
#  (35,
#   '0.003*"атака" + 0.003*"страна" + 0.002*"планирование" + 0.002*"uber" + 0.002*"звук" + 0.002*"усилитель" + 0.002*"ключ" + 0.002*"анализатор" + 0.002*"пациент" + 0.002*"партнёр"'),
#  (0,
#   '0.003*"бот" + 0.003*"java" + 0.002*"oracle" + 0.002*"видео" + 0.002*"dns" + 0.002*"т.е" + 0.002*"игра" + 0.002*"get" + 0.002*"ibm" + 0.002*"design"'),
#  (93,
#   '0.003*"gpu" + 0.002*"бот" + 0.002*"атом" + 0.002*"»" + 0.002*"изображение" + 0.002*"apple" + 0.002*"спектр" + 0.002*"здание" + 0.002*"станция" + 0.002*"сопротивление"'),
#  (36,
#   '0.003*"vmware" + 0.003*"бумажный" + 0.002*"database" + 0.002*"сенсорный" + 0.002*"робот" + 0.002*"экран" + 0.002*"позиция" + 0.002*"мозг" + 0.002*"движение" + 0.002*"виртуальный"'),
#  (12,
#   '0.004*"клетка" + 0.003*"игра" + 0.002*"программист" + 0.002*"луна" + 0.002*"new" + 0.002*"рак" + 0.002*"наушник" + 0.002*"документ" + 0.002*"заголовок" + 0.002*"чип"'),
#  (44,
#   '0.003*"дата-центр" + 0.003*"ггц" + 0.003*"диск" + 0.002*"windows" + 0.002*"договор" + 0.002*"oracle" + 0.002*"категория" + 0.002*"заказчик" + 0.002*"magic" + 0.002*"000"')]

# %%
lda = gensim.models.LdaMulticore(corpus, 200, id2word=words, passes=3, alpha='asymmetric', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(195,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (196,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (198,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (194,
#   '0.076*"переменный" + 0.074*"символ" + 0.050*"выражение" + 0.045*"массив" + 0.043*"аргумент" + 0.035*"синтаксис" + 0.033*"foo" + 0.020*"оператор" + 0.018*"go" + 0.015*"преобразование"'),
#  (199,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (191,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (190,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (197,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (193,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (184,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (9,
#   '0.040*"платёж" + 0.028*"цифровой" + 0.027*"платёжный" + 0.026*"облако" + 0.024*"оплата" + 0.022*"vps" + 0.020*"договор" + 0.018*"контекст" + 0.017*"мессенджер" + 0.017*"услуга"'),
#  (8,
#   '0.064*"станция" + 0.054*"ui" + 0.044*"конверсия" + 0.040*"cms" + 0.027*"тестовый" + 0.025*"интернет-магазин" + 0.016*"посетитель" + 0.012*"эффективность" + 0.011*"улучшать" + 0.011*"seo"'),
#  (7,
#   '0.048*"сигнал" + 0.035*"температура" + 0.031*"датчик" + 0.030*"питание" + 0.028*"корпус" + 0.024*"напряжение" + 0.024*"плата" + 0.021*"модуль" + 0.020*"ток" + 0.019*"диск"'),
#  (6,
#   '0.084*"блокчейн" + 0.052*"вакансия" + 0.038*"кандидат" + 0.038*"рейтинг" + 0.031*"аудитория" + 0.026*"bitcoin" + 0.022*"представитель" + 0.019*"стартап" + 0.017*"ценность" + 0.016*"город"'),
#  (5,
#   '0.125*"автомобиль" + 0.042*"raspberry_pi" + 0.032*"дорога" + 0.020*"килограмм" + 0.013*"производство" + 0.012*"pi" + 0.011*"весить" + 0.011*"microsd" + 0.010*"аккумулятор" + 0.008*"наклон"'),
#  (4,
#   '0.066*"apple" + 0.035*"ноутбук" + 0.030*"iphone" + 0.028*"nvidia" + 0.026*"инцидент" + 0.023*"шейдёр" + 0.020*"pixel" + 0.019*"microsoft" + 0.018*"рубль" + 0.016*"сотрудник"'),
#  (3,
#   '0.070*"робот" + 0.039*"хранение" + 0.037*"индекс" + 0.030*"ip" + 0.026*"бд" + 0.024*"таблица" + 0.023*"резервный_копирование" + 0.021*"mail.ru_group" + 0.020*"виртуальный" + 0.020*"подключение"'),
#  (2,
#   '0.011*"скрипт" + 0.011*"android" + 0.010*"ключ" + 0.010*"google" + 0.010*"php" + 0.010*"браузер" + 0.008*"загрузка" + 0.008*"компонент" + 0.007*"лекция" + 0.007*"курс"'),
#  (1,
#   '0.009*"услуга" + 0.008*"канал" + 0.008*"оборудование" + 0.008*"api" + 0.008*"сотрудник" + 0.008*"конференция" + 0.008*"инфраструктура" + 0.007*"оператор" + 0.007*"бизнес" + 0.007*"производительность"'),
#  (0,
#   '0.009*"игра" + 0.004*"тест" + 0.004*"windows" + 0.003*"камера" + 0.003*"книга" + 0.003*"учёный" + 0.003*"смартфон" + 0.003*"цена" + 0.003*"карта" + 0.003*"ядро"')]

# %%
lda = gensim.models.LdaModel(corpus, 150, id2word=words, passes=6, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(123,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (97,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (90,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (71,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (24,
#   '0.014*"интуиция" + 0.000*"предпочтение" + 0.000*"работник" + 0.000*"характеристика" + 0.000*"принятие" + 0.000*"тест" + 0.000*"иб" + 0.000*"психологический" + 0.000*"личность" + 0.000*"деловой"'),
#  (134,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (128,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (11,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (132,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (31,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"'),
#  (16,
#   '0.028*"массив" + 0.020*"умолчание" + 0.019*"r" + 0.019*"php" + 0.017*"переменный" + 0.014*"add" + 0.014*"use" + 0.014*"foo" + 0.014*"do" + 0.014*"шаблон"'),
#  (87,
#   '0.029*"архитектура" + 0.026*"фич" + 0.024*"предмет" + 0.022*"статус" + 0.019*"обсуждение" + 0.018*"повышение" + 0.015*"40" + 0.014*"штука" + 0.014*"возникнуть" + 0.014*"учебный"'),
#  (38,
#   '0.033*"двигатель" + 0.021*"исследователь" + 0.020*"учёный" + 0.018*"энергия" + 0.017*"январь" + 0.017*"февраль" + 0.017*"яркость" + 0.016*"воздух" + 0.016*"сопротивление" + 0.015*"сша"'),
#  (57,
#   '0.023*"ия" + 0.018*"максимальный" + 0.016*"пиксель" + 0.015*"тег" + 0.015*"компонент" + 0.014*"атрибут" + 0.013*"отображение" + 0.013*"зона" + 0.012*"вектор" + 0.012*"protected"'),
#  (101,
#   '0.029*"домен" + 0.029*"бот" + 0.017*"бесплатный" + 0.016*"официальный" + 0.016*"площадка" + 0.015*"движок" + 0.014*"право" + 0.013*"аудио" + 0.012*"скрипт" + 0.012*"генерация"'),
#  (80,
#   '0.030*"документ" + 0.021*"инцидент" + 0.021*"информационный" + 0.020*"представитель" + 0.016*"корпоративный" + 0.016*"закон" + 0.015*"заказчик" + 0.014*"утечка" + 0.014*"корпорация" + 0.012*"цифровой"'),
#  (142,
#   '0.017*"модуль" + 0.014*"загрузка" + 0.013*"сообщество" + 0.012*"android" + 0.012*"метр" + 0.011*"релиз" + 0.010*"открыть" + 0.010*"долгий" + 0.010*"вести" + 0.010*"бюджет"'),
#  (91,
#   '0.014*"обновление" + 0.013*"секунда" + 0.012*"стандарт" + 0.011*"поток" + 0.010*"дизайнер" + 0.010*"дефект" + 0.009*"раздел" + 0.009*"кнопка" + 0.009*"подборка" + 0.008*"конечный"'),
#  (36,
#   '0.012*"тест" + 0.010*"контекст" + 0.010*"производство" + 0.009*"электроника" + 0.009*"курс" + 0.008*"объём" + 0.008*"стоимость" + 0.008*"2017" + 0.008*"бизнес" + 0.008*"предприятие"'),
#  (67,
#   '0.005*"windows" + 0.005*"google" + 0.004*"сотрудник" + 0.004*"услуга" + 0.004*"программирование" + 0.004*"виртуальный" + 0.003*"социальный" + 0.003*"производительность" + 0.003*"защита" + 0.003*"адрес"')]

# %%
lda = gensim.models.LdaModel(corpus, 85, id2word=words, passes=1, alpha='auto', eval_every=0)

# %%
lda.print_topics()
# Out:
# [(32,
#   '0.012*"signal" + 0.008*"ssd" + 0.005*"basic" + 0.005*"tor" + 0.004*"ген" + 0.004*"отклик" + 0.003*"смерть" + 0.002*"клетка" + 0.002*"диск" + 0.002*"одновременный"'),
#  (22,
#   '0.009*"болезнь" + 0.007*"звонок" + 0.005*"номер" + 0.005*"one" + 0.005*"разрешать" + 0.005*"заболевание" + 0.004*"drive" + 0.004*"больной" + 0.003*"диагноз" + 0.003*"вещество"'),
#  (61,
#   '0.004*"safari" + 0.004*"webpack" + 0.004*"пространство" + 0.003*"text" + 0.003*"render" + 0.002*"grep" + 0.002*"район" + 0.002*"калибровка" + 0.002*"шрифт" + 0.002*"политика"'),
#  (45,
#   '0.007*"3d-печать" + 0.004*"hash" + 0.004*"3d-принтер" + 0.004*"школа" + 0.003*"регистратор" + 0.003*"void" + 0.003*"производство" + 0.003*"super" + 0.002*"печатать" + 0.002*"p"'),
#  (34,
#   '0.011*"стек" + 0.010*"php" + 0.006*"ddr4" + 0.005*"вт" + 0.004*"visual" + 0.004*"носитель" + 0.003*"беспилотный" + 0.003*"джон" + 0.003*"дрон" + 0.003*"visual_studio"'),
#  (21,
#   '0.007*"pass" + 0.006*"платёж" + 0.005*"курс" + 0.005*"погода" + 0.004*"ru" + 0.003*"получатель" + 0.003*"квантовый" + 0.002*"взлом" + 0.002*"баг" + 0.002*"регистрация"'),
#  (8,
#   '0.007*"нативный" + 0.005*"реклама" + 0.004*"геймер" + 0.004*"нажать" + 0.003*"жёсткий_диск" + 0.003*"менять" + 0.003*"кампания" + 0.003*"администрация" + 0.003*"здание" + 0.003*"размещать"'),
#  (82,
#   '0.008*"php" + 0.007*"дрон" + 0.005*"symfony" + 0.004*"камера" + 0.004*"javascript" + 0.003*"redis" + 0.003*"unix" + 0.003*"telegram" + 0.003*"орган" + 0.003*"учреждение"'),
#  (58,
#   '0.009*"лекция" + 0.004*"vpn" + 0.004*"cloud" + 0.004*"vision" + 0.003*"key" + 0.003*"розетка" + 0.003*"аудит" + 0.003*"dsl" + 0.003*"заголовок" + 0.003*"edition"'),
#  (39,
#   '0.006*"парсер" + 0.005*"сетка" + 0.005*"навык" + 0.005*"инструкция" + 0.004*"регистр" + 0.004*"текстура" + 0.004*"hpe" + 0.004*"res" + 0.004*"вебинар" + 0.003*"знание"'),
#  (51,
#   '0.024*"подборка" + 0.015*"загадка" + 0.013*"игра" + 0.013*"скачивание" + 0.013*"firewall" + 0.011*"иллюстрация" + 0.010*"подкаста" + 0.010*"делиться" + 0.010*"жанр" + 0.007*"→"'),
#  (30,
#   '0.013*"электроника" + 0.012*"репликация" + 0.009*"chrome" + 0.009*"зарядка" + 0.008*"взрослый" + 0.008*"математика" + 0.008*"иванов" + 0.007*"игра" + 0.007*"школьный" + 0.006*"seo"'),
#  (70,
#   '0.019*"мозг" + 0.012*"услуга" + 0.009*"хостинг" + 0.008*"социальный" + 0.007*"order" + 0.007*"scrum" + 0.007*"dropbox" + 0.006*"предоставление" + 0.006*"проектирование" + 0.006*"перевести"'),
#  (37,
#   '0.011*"помещение" + 0.011*"34" + 0.010*"define" + 0.009*"поезд" + 0.009*"кнут" + 0.008*"прям" + 0.006*"обеспечение" + 0.006*"agile" + 0.006*"нода" + 0.006*"business"'),
#  (46,
#   '0.016*"цифровой" + 0.010*"сотрудник" + 0.010*"датчик" + 0.009*"клетка" + 0.009*"google" + 0.009*"директор" + 0.009*"предприятие" + 0.008*"робот" + 0.007*"valve" + 0.007*"январь"'),
#  (19,
#   '0.020*"игра" + 0.014*"игрок" + 0.014*"бот" + 0.010*"узел" + 0.009*"twitter" + 0.008*"нативный" + 0.007*"объявление" + 0.006*"пиксель" + 0.006*"ожидание" + 0.005*"попадание"'),
#  (25,
#   '0.010*"домен" + 0.008*"дефект" + 0.008*"заказчик" + 0.008*"vpn" + 0.008*"windows" + 0.007*"вредоносный" + 0.006*"уязвимость" + 0.005*"долг" + 0.005*"шлюз" + 0.005*"утечка"'),
#  (68,
#   '0.006*"раздел" + 0.006*"загрузка" + 0.006*"подключение" + 0.005*"file" + 0.005*"скрипт" + 0.005*"документ" + 0.005*"публичный" + 0.005*"amp" + 0.004*"порт" + 0.004*"настроить"'),
#  (56,
#   '0.013*"браузер" + 0.006*"microsoft" + 0.005*"windows" + 0.004*"игра" + 0.004*"android" + 0.004*"метаданные" + 0.004*"локализация" + 0.004*"лицо" + 0.004*"перевод" + 0.004*"умолчание"'),
#  (14,
#   '0.006*"студент" + 0.006*"доклад" + 0.005*"мессенджер" + 0.004*"java" + 0.004*"кабель" + 0.003*"февраль" + 0.003*"2017" + 0.003*"сотрудник" + 0.003*"пообщаться" + 0.003*"16"')]

# %% [markdown]
# Первое, что бросилось в глаза после применения tf-idf — это появление множества дубликатов на нескольких вариантах настроек модели, вот таких:
#
# (31,
#   '0.000*"по-хорошему" + 0.000*"погружение" + 0.000*"морской" + 0.000*"отверстие" + 0.000*"отметка" + 0.000*"капля" + 0.000*"повредить" + 0.000*"58" + 0.000*"удар" + 0.000*"испытание"')
#
# Вероятно, это как-то связано с количеством проходов по корпусу, но до tf-idf этого не было.
#
# При этом сами темы стали более осмысленными — если однозначную тематику угадать все еще можно не всегда, то связи между словами в теме почти всегда можно найти, в отличие от результатов моделей до tf-idf:
#
# (7,
#   '0.048*"сигнал" + 0.035*"температура" + 0.031*"датчик" + 0.030*"питание" + 0.028*"корпус" + 0.024*"напряжение" + 0.024*"плата" + 0.021*"модуль" + 0.020*"ток" + 0.019*"диск"') – про hardware
#
#  (6,
#   '0.084*"блокчейн" + 0.052*"вакансия" + 0.038*"кандидат" + 0.038*"рейтинг" + 0.031*"аудитория" + 0.026*"bitcoin" + 0.022*"представитель" + 0.019*"стартап" + 0.017*"ценность" + 0.016*"город"') – про работу в блокчейне
#
# Некоторые из тем ухудшились, например, в более ранней
#
# (56,
#   '0.017*"автомобиль" + 0.016*"робот" + 0.010*"рубль" + 0.009*"телефон" + 0.009*"обзор" + 0.008*"производитель" + 0.007*"цена" + 0.007*"номер" + 0.006*"купить" + 0.006*"покупка"')
#
# легче понять, о чем речь, нежели в более поздней
#
# (5,
#   '0.125*"автомобиль" + 0.042*"raspberry_pi" + 0.032*"дорога" + 0.020*"килограмм" + 0.013*"производство" + 0.012*"pi" + 0.011*"весить" + 0.011*"microsd" + 0.010*"аккумулятор" + 0.008*"наклон"')
#
# .

# %%
stexts = [' '.join(text) for text in ngrammed_texts]

# %%
vectorizer = TfidfVectorizer(max_features=500, min_df=5, max_df=0.7, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 то  очень  какой  делать
# 1 файл  скрипт  пакет  настройка
# 2 игра  игрок  разработчик  уровень
# 3 сеть  связь  интернет  оператор
# 4 система  управление  безопасность  работа
# 5 lt  gt  компонент  элемент
# 6 приложение  мобильный  android  разработка
# 7 устройство  смартфон  производитель  телефон
# 8 год  2016  миллион  стать
# 9 public  new  void  класс
# 10 компания  сотрудник  рынок  бизнес
# 11 the  of  and  for
# 12 код  функция  переменный  значение
# 13 сервер  клиент  виртуальный  машина
# 14 сайт  страница  браузер  адрес
# 15 проект  команда  разработчик  разработка
# 16 объект  элемент  класс  метод
# 17 дать  база  запрос  база дать
# 18 технология  задача  решение  материал
# 19 тест  тестирование  результат  производительность
# 20 сигнал  связь  канал  значение
# 21 google  android  сервис  api
# 22 windows  microsoft  linux  версия
# 23 камера  видео  смартфон  изображение
# 24 amp  for  void  gt
# 25 язык  программирование  программист  книга
# 26 человек  исследование  жизнь  работа
# 27 пользователь  сообщение  сервис  ваш
# 28 звук  качество  материал  видео
# 29 рубль  цена  000  товар

# %%
model.reconstruction_err_
# Out:
# 49.74329980613673

# %%
vectorizer = TfidfVectorizer(max_features=1500, min_df=8, max_df=0.5, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 человек  книга  какой  какой то
# 1 файл  папка  скрипт  строка
# 2 игра  игрок  игровой  играть
# 3 сигнал  звук  частота  напряжение
# 4 устройство  камера  смартфон  экран
# 5 компания  сотрудник  рынок  бизнес
# 6 приложение  android  мобильный  пользователь
# 7 lt  gt  div  lt div
# 8 public  new  void  private
# 9 the  of  and  for
# 10 человек  учёный  мозг  исследование
# 11 космический  спутник  орбита  аппарат
# 12 сайт  страница  пользователь  реклама
# 13 сервер  запрос  база  сервис
# 14 уязвимость  атака  безопасность  пароль
# 15 windows  linux  microsoft  виртуальный
# 16 печать  принтер  3d  материал
# 17 доклад  конференция  участник  тема
# 18 функция  объект  значение  метод
# 19 язык  код  программирование  программа
# 20 css  javascript  react  js
# 21 тест  тестирование  код  тестировать
# 22 товар  рубль  цена  скидка
# 23 amp  amp amp  echo  for
# 24 бот  сообщение  пользователь  канал
# 25 дата центр  центр  дата  оборудование
# 26 вселенная  энергия  звезда  свет
# 27 проект  команда  задача  разработка
# 28 сеть  трафик  связь  интернет
# 29 робот  ия  машина  ребёнок

# %%
model.reconstruction_err_
# Out:
# 55.24894214850625

# %%
vectorizer = TfidfVectorizer(max_features=1200, min_df=21, max_df=0.35, ngram_range=(1,3))

# %%
X = vectorizer.fit_transform(stexts)

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=30, random_state=None, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
feat_names = vectorizer.get_feature_names()

# %%
top_words = model.components_.argsort()[:,:-5:-1]

for i in range(top_words.shape[0]):
    words = [feat_names[j] for j in top_words[i]]
    print(i, "  ".join(words))
# Out:
# 0 книга  что  какой то  что то
# 1 файл  папка  скрипт  команда
# 2 игра  игрок  игровой  играть
# 3 функция  объект  значение  метод
# 4 устройство  камера  смартфон  экран
# 5 приложение  android  мобильный  ios
# 6 lt  gt  div  lt div
# 7 public  new  void  private
# 8 windows  microsoft  linux  ядро
# 9 товар  рубль  цена  скидка
# 10 космический  земля  спутник  аппарат
# 11 сайт  страница  реклама  браузер
# 12 атака  уязвимость  безопасность  пароль
# 13 the  of  and  for
# 14 доклад  конференция  участник  тема
# 15 рынок  технология  бизнес  продукт
# 16 учёный  мозг  клетка  исследование
# 17 css  javascript  react  js
# 18 печать  принтер  3d  материал
# 19 язык  программирование  программа  программист
# 20 запрос  база  таблица  база дать
# 21 дата центр  центр  дата  оборудование
# 22 amp  amp amp  for  echo
# 23 сервер  виртуальный  машина  виртуальный машина
# 24 бот  сообщение  канал  google
# 25 клиент  услуга  письмо  бизнес
# 26 тест  тестирование  команда  тестовый
# 27 сигнал  звук  частота  напряжение
# 28 сеть  трафик  связь  интернет
# 29 робот  ия  ребёнок  машина

# %%
model.reconstruction_err_
# Out:
# 55.12926050688545

# %% [markdown]
# лучшей оказалась первая модель.

# %%
top_words = model.components_.argsort()[:,:-5:-1]
ready = []
for i in range(top_words.shape[0]):
    ready.append([feat_names[j] for j in top_words[i]])

# %%
print(ready[2], ready[3], ready[6])
# Out:
# ['игра', 'игрок', 'разработчик', 'уровень'] ['приложение', 'мобильный', 'android', 'разработка'] ['проект', 'команда', 'разработчик', 'разработка']

# %% [markdown]
# осмысленности в результатах куда больше, чем в LDA, четко прослеживаются связи между словами и наличие общих тем — в данном случае это игры, мобильная разработка, проектная работа в разработке.
